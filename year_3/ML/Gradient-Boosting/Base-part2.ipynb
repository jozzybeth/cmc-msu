# %% [markdown]
# # <img src="data:image/jpeg;base64,..." width="50"/>
#
# # Машинное обучение. ВМК МГУ

# %% [markdown]
# # Практическое задание 11: Градиентный бустинг деревьев - часть 2
#
# ## Уровень: <font color='SkyBlue'>**Базовый (Base)**</font>

# %% [markdown]
# # О формате сдачи
#
# 🔷 **<font color='plum'>При решении ноутбука используйте данный шаблон</font>**
#
#     ✅ Можно добавлять новые ячейки любых типов
#     ❌ Не нужно удалять текстовые ячейки c разметкой частей ноутбука и формулировками заданий
#
#
# 🔷 **<font color='plum'>При оценивании задач учитывается код</font>**
#
#     ✅ Задания, в которых необходим код, обычно помечаются фразами "Your code here"/"Ваш код" и аналогичными
#     ❌ Ответы на вопросы без сопутствующего кода оцениваются в 0 баллов
#     ❌ Наличе работоспособного кода в ноутбуке, если на сказано иного, обязательно
#
# 🔷 **<font color='plum'>При оценивании задач учитываются выводы</font>**
#
#     ✅ Задания, в которых необходимы выводы, обычно помечаются фразами Вывод"/"Ответ на вопрос"/"Ваш текст" и аналогичными
#     ✅ Обычно выводы подразумевают под собой текстовый ответ (можно писать markdown, latex).
#     ✅ Сопутствующие изображения, графики, таблички - приветствуются!
#     ❌ При отсутствии выводов задание не засчитается на полный балл
#
# -----------
# <font color="white" style="opacity:0.2024"></font>

# %% [markdown]
# __В этом задании вы..:__
#
# - Узнаете, настройка каких гиперпараметров в бустингах приведет к успеху
# - Изучите дополнительную библиотеку нахождения наилучших гиперпараметров
# - Примените все полученные знания для получения лучшего скора на датасете фильмов
#
# ----
#
# <font color="white" style="opacity:0.2024"></font>
# <font color=DarkOrange>**Примерное время выполнения (execution time/время выполнения, если нажать run all) всех ячеек ноутбука при правильной реализации: 60 минут </font>**

# %% [markdown]
# # Подготовка рабочей среды
#
# Сначала установим нужные нам версии библиотек. Мы гарантируем, что в данных версиях задание будет корректно отрабатывать.
#
# После установки нужных версий, **возможно,** нужно перезагрузить среду (runtime), но скорее всего вам это не понадобится
#
#
# На скачивание файла и установку понадобится не более 5 минут.
#
# <font color='OrangeRed'>**Важно!**</font>
#
# Устанавливать нужные версии нужно каждый раз, когда создается новый рантайм. Например, если вы 2 часа подряд делаете это задание, то подготовить библиотеки достаточно 1 раз. Но если вы, например, начали в понедельник, затем закрыли/выключили ноутбук, то при продолжении в среду, вам нужно будет запустить рантайм заново и следовательно заново установить библиотеки.
#
# <font color='OrangeRed'>**Важно!**</font>
# Если вы предпочитаете делать практические задания на своем личном ноутбуке, то проверьте, что вы установили рабочее окружение в [соответствии с гайдом](https://github.com/MSU-ML-COURSE/ML-COURSE-24-25/blob/main/tutorials/%D0%A2%D1%83%D1%82%D0%BE%D1%80%D0%B8%D0%B0%D0%BB%20%D0%BF%D0%BE%20%D1%83%D1%81%D1%82%D0%B0%D0%BD%D0%BE%D0%B2%D0%BA%D0%B5%20%D1%80%D0%B0%D0%B1%D0%BE%D1%87%D0%B5%D0%B3%D0%BE%20%D0%BE%D0%BA%D1%80%D1%83%D0%B6%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B2%20Python%20%D0%B4%D0%BB%D1%8F%20%D1%80%D0%B5%D1%88%D0%B5%D0%BD%D0%B8%D1%8F%20%D0%B7%D0%B0%D0%B4%D0%B0%D1%87%20(2).pdf)

# %%
# !!! Данный блок будет работать только в Google-Colab !!!
! gdown 10k8Hwn9kpK9SpK4IEj4-EaWQZqgYT5-Q
! pip install -r /content/requirements_2024_25_for_colab_small.txt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10k8Hwn9kpK9SpK4IEj4-EaWQZqgYT5-Q
# To: /content/requirements_2024_25_for_colab_small.txt
# 100% 375/375 [00:00<00:00, 1.53MB/s]
# Requirement already satisfied: catboost==1.2.7 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 1)) (1.2.7)
# Requirement already satisfied: gdown==5.1.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 2)) (5.1.0)
# Requirement already satisfied: h5py==3.11.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 3)) (3.11.0)
# Requirement already satisfied: hyperopt==0.2.7 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 4)) (0.2.7)
# Requirement already satisfied: ipympl==0.9.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 5)) (0.9.4)
# Requirement already satisfied: ipywidgets==7.7.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 6)) (7.7.1)
# Requirement already satisfied: lightgbm==4.4.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 7)) (4.4.0)
# Requirement already satisfied: matplotlib==3.7.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 8)) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 9)) (0.1.7)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 10)) (1.26.4)
# Requirement already satisfied: pandas==2.1.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 11)) (2.1.4)
# Requirement already satisfied: pep8==1.7.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 12)) (1.7.1)
# Requirement already satisfied: plotly==5.15.0 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 13)) (5.15.0)
# Requirement already satisfied: pycodestyle==2.12.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 14)) (2.12.1)
# Requirement already satisfied: pytest==7.4.4 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 15)) (7.4.4)
# Requirement already satisfied: scikit-image==0.23.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 16)) (0.23.2)
# Requirement already satisfied: scikit-learn==1.3.2 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 17)) (1.3.2)
# Requirement already satisfied: scipy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 18)) (1.13.1)
# Requirement already satisfied: seaborn==0.13.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 19)) (0.13.1)
# Requirement already satisfied: tqdm==4.66.5 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 20)) (4.66.5)
# Requirement already satisfied: umap-learn==0.5.6 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 21)) (0.5.6)
# Requirement already satisfied: xgboost==2.1.1 in /usr/local/lib/python3.11/dist-packages (from -r /content/requirements_2024_25_for_colab_small.txt (line 22)) (2.1.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->-r /content/requirements_2024_25_for_colab_small.txt (line 1)) (0.20.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost==1.2.7->-r /content/requirements_2024_25_for_colab_small.txt (line 1)) (1.17.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (4.13.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (3.18.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (2.32.3)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.11/dist-packages (from hyperopt==0.2.7->-r /content/requirements_2024_25_for_colab_small.txt (line 4)) (3.4.2)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from hyperopt==0.2.7->-r /content/requirements_2024_25_for_colab_small.txt (line 4)) (1.0.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from hyperopt==0.2.7->-r /content/requirements_2024_25_for_colab_small.txt (line 4)) (3.1.1)
# Requirement already satisfied: py4j in /usr/local/lib/python3.11/dist-packages (from hyperopt==0.2.7->-r /content/requirements_2024_25_for_colab_small.txt (line 4)) (0.10.9.7)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.11/dist-packages (from ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (0.2.0)
# Requirement already satisfied: ipython<9 in /usr/local/lib/python3.11/dist-packages (from ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (7.34.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (11.1.0)
# Requirement already satisfied: traitlets<6 in /usr/local/lib/python3.11/dist-packages (from ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (5.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (6.17.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (3.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 8)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 8)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 8)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 8)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 8)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 8)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib==3.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 8)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.1.4->-r /content/requirements_2024_25_for_colab_small.txt (line 11)) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas==2.1.4->-r /content/requirements_2024_25_for_colab_small.txt (line 11)) (2025.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly==5.15.0->-r /content/requirements_2024_25_for_colab_small.txt (line 13)) (9.0.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest==7.4.4->-r /content/requirements_2024_25_for_colab_small.txt (line 15)) (2.1.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from pytest==7.4.4->-r /content/requirements_2024_25_for_colab_small.txt (line 15)) (1.5.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.23.2->-r /content/requirements_2024_25_for_colab_small.txt (line 16)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.23.2->-r /content/requirements_2024_25_for_colab_small.txt (line 16)) (2025.3.13)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image==0.23.2->-r /content/requirements_2024_25_for_colab_small.txt (line 16)) (0.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.2->-r /content/requirements_2024_25_for_colab_small.txt (line 17)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.3.2->-r /content/requirements_2024_25_for_colab_small.txt (line 17)) (3.6.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.11/dist-packages (from umap-learn==0.5.6->-r /content/requirements_2024_25_for_colab_small.txt (line 21)) (0.60.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.11/dist-packages (from umap-learn==0.5.6->-r /content/requirements_2024_25_for_colab_small.txt (line 21)) (0.5.13)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost==2.1.1->-r /content/requirements_2024_25_for_colab_small.txt (line 22)) (2.21.5)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (6.1.12)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (4.9.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.2->umap-learn==0.5.6->-r /content/requirements_2024_25_for_colab_small.txt (line 21)) (0.43.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (6.5.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown==5.1.0->-r /content/requirements_2024_25_for_colab_small.txt (line 2)) (1.7.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (5.7.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (23.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9->ipympl==0.9.4->-r /content/requirements_2024_25_for_colab_small.txt (line 5)) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (4.3.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (4.23.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (0.23.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets==7.7.1->-r /content/requirements_2024_25_for_colab_small.txt (line 6)) (1.3.1)

# %%
import catboost
assert(catboost.__version__ == '1.2.7')

# %% [markdown]
# Теперь можно приступать к выполнению задания! :)

# %% [markdown]
# -----------
# <font color="white" style="opacity:0.2024"></font>

# %% [markdown]
# ## Введение
#
# Привет, ребятушки!
#
# Сегодня мы с вами продолжим изучать градиентный бустинг, а точнее - научимся выбивать из него наилучшее качество! Также решим задачку на фильмах с помощью полученных знаний.
#
# <font color='OrangeRed'>**Внимание!**</font> Во всех заданиях в качестве целевой метрики используется MAE (средняя абсолютная ошибка).
#
# Значение MAE вычисляется как
#
# $$
#   MAE = \sum_{i = 1}^N\dfrac{|a(x_i) - y_i|}{N},
# $$
#
# где $N$ - число объектов в тестовой выборке, $x_i$ - вектор признаков i-го объекта, $a(x_i)$ - предсказание на i-ом объекте, $y_i$ - значение целевого признака на i-м объекте.

# %% [markdown]
# ## Установка дополнительных библиотек.
#
# В этом задании нам понадобятся три бибиотеки, которые вы изучили в прошлом задании. Напомним документацию:
#
# <font color='plum'>**XGBoost**:</font> Документация [здесь](https://xgboost.readthedocs.io/en/stable/).<br />
# <font color='plum'>**LightGBM**:</font> Документация [здесь](https://lightgbm.readthedocs.io/en/latest/index.html). Также дополнительно про установку [тут](https://pypi.org/project/lightgbm/).<br />
# <font color='plum'>**Catboost**:</font> Документация [здесь](https://catboost.ai/en/docs/). Можно найти также некоторую информацию на русском [тут](https://habr.com/ru/company/otus/blog/527554/).<br />
# <font color='plum'>**HyperOpt**:</font> Документация [здесь](http://hyperopt.github.io/hyperopt/). <br />
#
#
# <font color='OrangeRed'>**Внимание!**</font> Вникать и подробно читать документацию к каждой библиотеке нет необходимости! Достаточно обращаться туда для нахождения примеров обучения.

# %% [markdown]
# ## Подготовка датасета
#
# Работать будем с тем же датасетом, что и в прошлом задании

# %% [markdown]
# При работе в google colab для скачивания датасета достаточно запустить следующую ячейку.
#
# При работе с ноутбуком <span style="color:red"> <font color="OrangeRed">на локальном компьютере</font></span> Вы можете скачать файл по [этой ссылке](https://drive.google.com/file/d/1gdDv2kTCEkF3ia1vvbvRFJM0YfqmPplb/view?usp=sharing) и чуть ниже заменить ` /content/dataframe_YesIndex_YesHeader_C.csv` (в строке с `read_csv`) на ваш локальный путь до файла.

# %%
# при локальном выполнении запускать эту ячейку НЕ НАДО
# !gdown 1gdDv2kTCEkF3ia1vvbvRFJM0YfqmPplb
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gdDv2kTCEkF3ia1vvbvRFJM0YfqmPplb
# To: /content/dataframe_YesIndex_YesHeader_C.csv
# 100% 568k/568k [00:00<00:00, 137MB/s]

# %%
# %matplotlib inline
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import mean_absolute_error, make_scorer

from hyperopt import hp, tpe, Trials
from hyperopt.fmin import fmin
from hyperopt.pyll import scope

from xgboost import XGBRegressor

from lightgbm import LGBMRegressor

from catboost import CatBoostRegressor

import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

import time

# %%
df = pd.read_csv('/content/dataframe_YesIndex_YesHeader_C.csv', index_col=0)
df.head()
# Out:
#    Engine Capacity  Cylinders  Drive Type  Fuel Tank Capacity  Fuel Economy  \
# 0              1.2          3           0                42.0           4.9
# 1              1.2          3           0                42.0           4.9
# 2              1.4          4           0                45.0           6.3
# 3              1.6          4           0                50.0           6.4
# 4              1.5          4           0                48.0           5.8
#
#    Fuel Type  Horsepower  Torque  Transmission  Top Speed  ...  Acceleration  \
# 0          0          76   100.0             0        170  ...          14.0
# 1          0          76   100.0             0        170  ...          14.0
# 2          0          75   118.0             1        156  ...          16.0
# 3          0         102   145.0             0        180  ...          11.0
# 4          0         112   150.0             0        170  ...          10.9
#
#    Length  Width  Height  Wheelbase  Trunk Capacity  \
# 0   4.245  1.670   1.515      2.550           450.0
# 1   4.245  1.670   1.515      2.550           450.0
# 2   3.864  1.716   1.721      2.513          2800.0
# 3   4.354  1.994   1.529      2.635           510.0
# 4   4.314  1.809   1.624      2.585           448.0
#
#                                      name    price  currency  Country
# 0  Mitsubishi Attrage 2021 1.2 GLX (Base)  34099.0         0        0
# 1  Mitsubishi Attrage 2021 1.2 GLX (Base)  34099.0         0        0
# 2         Fiat Fiorino 2021 1.4L Standard  41250.0         0        0
# 3             Renault Symbol 2021 1.6L PE  44930.0         0        0
# 4                     MG ZS 2021 1.5L STD  57787.0         0        0
#
# [5 rows x 21 columns]

# %% [markdown]
# Также, как и в прошлом задании, будем использовать дефолтные параметры для некоторых экспериментов:

# %%
test_parameters = {"n_estimators": 1000, "max_depth": 5, "learning_rate":0.1}

# %% [markdown]
# ### <font color='DarkOrange'>**Задание 0 [0 баллов]**</font>

# %% [markdown]
# Здесь нужно по аналогии с предыдущим заданием создать 3 датасета, а потом их разбить на тренировочное и тестовое множества. Дублируем ниже условие

# %% [markdown]
# **Данные**: датасет со стоимостью подержанных автомобилей
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. Изучить датасет, проверить наличие `пропусков.` Под пропусками подразумевается значение N/A вместо признака. При необходимости заменить их на среднее значение признака.
# 3. Добавить `столбец brand` с информацией о производителе автомобиля (для простоты можно взять первое слово в названии модели).
# 4. Решить, какие признаки Вы считаете `категориальными.` Конвертировать выбранные категориальные столбцы в тип category.
# 5. Создать `датасет А`, в котором выбранные категориальные признаки установлены как категориальные. Для этого необходимо создать вектор целевых значений Y (столбец цен автомобилей) и матрицу признаков X, в которой все категориальные переменные помечены как .astype('category'). Дополнительно стоит создать список с названиями и индексами столбцов категориальных переменных (поможет в будущем).
# 6. Создать `датасет B` без категориальных признаков. Для этого необходимо просто удалить из матрицы признаков все категориальные переменные.
# 7. Создать `датасет C`, в котором выбранные категориальные признаки закодированы через one-hot encoding. Для этого необходимо из матрицы признаков удалить выбранные категориальные переменные, а затем добавить новые признаки, соответствующие one-hot encoding этих категориальных переменных (со всей этой магией поможет простая функция `pd.get_dummies`).
# 8. Разбить датасеты на `тренировочное и тестовое множества`, используя `train_test_split(X, y, test_size=0.25, random_state=0)` (зафиксировав random_seed мы получим одинаковое разбиение на обучение/тест для всех трёх выборок).

# %%
datasets = {'A' : None, 'B': None, 'C': None}
# 1.
print('1. Количество  пропусков Nan/Null:', len(df[df.isnull().any(axis=1)]))
print('   Количество пропусков в  названии:', len(df.loc[(df.name == '') | (df.name == ' ')].name))
print()

# 2.
df['brand'] = df['name'].str.split().str[0]
print("2. После добавления столбца brand: ")
print(df.head())
print()

# 3.
category_names = ['Drive Type', 'Fuel Type', 'Transmission', 'name', 'Country', 'currency', 'brand']
print("3. Категориальные признаки: ", category_names)
for col in category_names:
  df[col] = df[col].astype('category')
print("   После конвертации")
df.info()
print()

# 4.
category_index = [df.columns.get_loc(col) for col in category_names]
datasets['A'] = {}
datasets['A']['X'] = df.drop(['price'], axis=1)
datasets['A']['y'] = df['price']

# 5.
datasets['B'] = {}
datasets['B']['X'] = df.drop(category_names, axis=1).drop(['price'], axis=1)
datasets['B']['y'] = df['price']

# 6.
datasets['C'] = {}
datasets['C']['X'] = pd.get_dummies(data=df.drop(['price'], axis=1), columns=category_names, dtype=int)
datasets['C']['y'] = df['price']

# 7.
for data in ['A', 'B', 'C']:
  X_train, X_test, y_train, y_test = train_test_split(datasets[data]['X'], datasets[data]['y'], test_size=0.25, random_state=0)
  datasets[data] = {}
  datasets[data]['X_train'] = X_train
  datasets[data]['X_test'] = X_test
  datasets[data]['y_train'] = y_train
  datasets[data]['y_test'] = y_test
# Out:
# 1. Количество  пропусков Nan/Null: 0
#    Количество пропусков в  названии: 0
#
# 2. После добавления столбца brand:
#    Engine Capacity  Cylinders  Drive Type  Fuel Tank Capacity  Fuel Economy  \
# 0              1.2          3           0                42.0           4.9
# 1              1.2          3           0                42.0           4.9
# 2              1.4          4           0                45.0           6.3
# 3              1.6          4           0                50.0           6.4
# 4              1.5          4           0                48.0           5.8
#
#    Fuel Type  Horsepower  Torque  Transmission  Top Speed  ...  Length  Width  \
# 0          0          76   100.0             0        170  ...   4.245  1.670
# 1          0          76   100.0             0        170  ...   4.245  1.670
# 2          0          75   118.0             1        156  ...   3.864  1.716
# 3          0         102   145.0             0        180  ...   4.354  1.994
# 4          0         112   150.0             0        170  ...   4.314  1.809
#
#    Height  Wheelbase  Trunk Capacity                                    name  \
# 0   1.515      2.550           450.0  Mitsubishi Attrage 2021 1.2 GLX (Base)
# 1   1.515      2.550           450.0  Mitsubishi Attrage 2021 1.2 GLX (Base)
# 2   1.721      2.513          2800.0         Fiat Fiorino 2021 1.4L Standard
# 3   1.529      2.635           510.0             Renault Symbol 2021 1.6L PE
# 4   1.624      2.585           448.0                     MG ZS 2021 1.5L STD
#
#      price currency  Country       brand
# 0  34099.0        0        0  Mitsubishi
# 1  34099.0        0        0  Mitsubishi
# 2  41250.0        0        0        Fiat
# 3  44930.0        0        0     Renault
# 4  57787.0        0        0          MG
#
# [5 rows x 22 columns]
#
# 3. Категориальные признаки:  ['Drive Type', 'Fuel Type', 'Transmission', 'name', 'Country', 'currency', 'brand']
#    После конвертации
# <class 'pandas.core.frame.DataFrame'>
# Index: 4560 entries, 0 to 5667
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Engine Capacity     4560 non-null   float64
#  1   Cylinders           4560 non-null   int64
#  2   Drive Type          4560 non-null   category
#  3   Fuel Tank Capacity  4560 non-null   float64
#  4   Fuel Economy        4560 non-null   float64
#  5   Fuel Type           4560 non-null   category
#  6   Horsepower          4560 non-null   int64
#  7   Torque              4560 non-null   float64
#  8   Transmission        4560 non-null   category
#  9   Top Speed           4560 non-null   int64
#  10  Seating Capacity    4560 non-null   int64
#  11  Acceleration        4560 non-null   float64
#  12  Length              4560 non-null   float64
#  13  Width               4560 non-null   float64
#  14  Height              4560 non-null   float64
#  15  Wheelbase           4560 non-null   float64
#  16  Trunk Capacity      4560 non-null   float64
#  17  name                4560 non-null   category
#  18  price               4560 non-null   float64
#  19  currency            4560 non-null   category
#  20  Country             4560 non-null   category
#  21  brand               4560 non-null   category
# dtypes: category(7), float64(11), int64(4)
# memory usage: 687.1 KB

# %% [markdown]
# <font color='OrangeRed'>**Внимание!**</font> Некоторые библиотеки требует дополнительной предобработки данных перед использованием моделей из них. Подробнее вы можете найти информацию об этом в соответствующих заданиях прошлого ноутбука (часть 1)

# %% [markdown]
# ## Оптимизация параметров
#
# Итак, в прошлом задании мы с вами научились пользоваться библиотеками для градиентного бустинга. Пришло время заняться самой интересной (нет) частью исследований, а именно подбором параметров!
#
# ## Как правильно перебирать параметры
#
# В этом ноутбуке мы будем несколько раз заниматься поиском оптимальных параметров для градиентного бустинга, перебирая задания по заданной сетке. В этом задании от Вас не будет требоваться найти самые лучшие параметры, но всё равно важно правильно составлять сетку для перебора. Для этого нужно понимать суть параметров и их смысл.
#
#
# При настройке моделей градиентного бустинга важно правильно подбирать гиперпараметры, так как они значительно влияют на качество предсказаний. Большая часть параметров так или иначе пересекается, но у каждой библиотеки они могут называться по-своему.
#
# Ниже приведена таблица основных параметров, которые стоит перебирать для каждой из библиотек.
#
# ## 🚀 XGBoost (XGBClassifier, XGBRegressor)
#
# | Параметр           | Описание | Диапазон перебора |
# |--------------------|----------|------------------|
# | `n_estimators`    | Количество деревьев в ансамбле | `100` – `1000` |
# | `learning_rate`   | Темп обучения | `0.001` – `1` |
# | `max_depth`       | Максимальная глубина деревьев | `3` – `10` (шаг 1) |
# | `subsample`       | Доля данных, используемая при обучении каждого дерева (для борьбы с переобучением) | `0.5` – `1.0` (шаг 0.1) |
# | `colsample_bytree` | Доля признаков, используемых для построения каждого дерева | `0.5` – `1.0` (шаг 0.1) |
#
# ## 🐈 CatBoost (CatBoostClassifier, CatBoostRegressor)
#
# | Параметр          | Описание | Диапазон перебора |
# |-------------------|----------|------------------|
# | `iterations`     | Количество деревьев | `500` – `5000` |
# | `learning_rate`  | Темп обучения | `0.001` – `1`|
# | `depth`         | Глубина деревьев | `4` – `10` (шаг 1) |
# | `l2_leaf_reg`   | Коэффициент L2-регуляризации (защита от переобучения) | `3` – `10` (шаг 1) |
# | `bagging_temperature` | Контроль случайности при выборке объектов (чем выше, тем случайнее выборка) | `0` – `1` (шаг 0.2) |
#
# ## 📊 Sklearn (GradientBoostingClassifier, GradientBoostingRegressor)
#
# | Параметр            | Описание | Диапазон перебора |
# |---------------------|----------|------------------|
# | `n_estimators`     | Количество деревьев | `100` – `1000` |
# | `learning_rate`    | Темп обучения | `0.001` – `1` |
# | `max_depth`        | Максимальная глубина деревьев | `3` – `10` (шаг 1) |
# | `min_samples_split` | Минимальное число образцов для разбиения узла | `2` – `10` (шаг 2) |
# | `subsample`        | Доля выборки данных для каждого дерева | `0.5` – `1.0` (шаг 0.1) |
#
#
# Следует также учесть, что:
#
#
# Для <font color='CornflowerBlue'>**learning_rate**</font> сетка перебора должна быть логарифмической, т.е. перебирать порядковые значения (к примеру, [1e-3, 1e-2, 1e-1, 1]). В большинстве случаев достаточно перебрать значения от 1e-5 до 1.<br />
#
# <font color='CornflowerBlue'>**max_depth**</font> -- максимальная глубина деревьев в ансамбле. Вообще говоря, эта величина зависит от числа признаков, но обычно лучше растить небольшие деревья. К примеру, библиотека CatBoost рекомендует перебирать значения до 10 (и уточняется, что обычно оптимальная глубина лежит от 6 до 10).<br />
#
# <font color='CornflowerBlue'>**n_estimators**</font> -- количество деревьев в ансамбле. Обычно стоит перебирать с каким-то крупным шагом (можно по логарифмической сетке). Здесь важно найти баланс между производительностью, временем обучения и качеством. Обычно нескольких тысяч деревьев бывает достаточно.<br />
#
# <font color='MediumTurquoise'>**Pro tip:**</font>
# Учтите, что в реальных задачах необходимо следить за тем, что оптимальные значения параметров не попадают на границы интервалов, т.е. что вы нашли хотя бы локальный минимум. Если Вы перебрали значения параметра от 1 до 10 и оказалось, что 10 - оптимальное значение, значит следует перебрать и бОльшие числа, чтобы убедиться, что качество не улучшается дальше (или по крайней мере убедиться, что рост качества сильно замедляется и на сильное улучшения рассчитывать не стоит.

# %% [markdown]
# ### <font color='DarkOrange'>**Задание 1 [2 баллa]**</font>
# **Данные**: датасет со стоимостью поддержанных автомобилей
# **Метрика**: MAE
# **Цели**: В данном задании следует выполнить следующие пункты:
#
#
#
# 1. Взять `две любые` библиотеки градиентного бустинга (можете взять самые быстрые)
# 2. Составить `сетку перебора параметров`, включающую параметры из таблиц выше.
# 3. Осуществите перебор параметров по вашей сетке при помощи `GridSearchCV` на `датасетах B и C`.
# 4. Замерьте `время` перебора.
# 5. Посчитайте `качество` модели обученной с оптимальными (с позиции кросс-валидации) параметрами на `тренировочном` и `тестовом` множествах.
# 4. Сделайте `выводы` о полезности перебора параметров.
#
#
# <font color='OrangeRed'>**Обратите внимание!**</font>
#
# 1. Для всех библиотек вы можете воспользоваться классом `GridSearchCV`, реализованном в `sklearn`, осуществляющего кросс-валидацию всех параметров и поиска модели с лучшим качеством. Обратите внимание, что этот класс позволяет установить количество разбиений датасета, что достаточно сильно влияет на время работы. Также вы можете воспользоваться `n_jobs=-1` для распараллеливания процесса перебора.
#
# <font color='OrangeRed'>**Обратите внимание!**</font>
#
# Если Вы устанавливаете `n_jobs` для `GridSearchCV`, то `не надо` использовать этот параметр для обучаемых регрессоров! Результат может быть плачевным в плане времени...
#
#
# 2. В `catboost` существует своя реализация перебора параметров, которым можно также воспользоваться (речь о `grid_search`).

# %% [markdown]
# <font color='OrangeRed'>**Обратите внимание!**</font>
#
# По какой-то причине, которую мне не удалось выяснить, иногда `catboost в google colab` работает очень медленно при переборе параметров. Если в соответствующем задании время обучения catboost занимает не многим более 10 секунд, то в случае кросс-валидации оно возрастает до 5 минут (соответственно, 5 минут в каждом из узлов). Поэтому используйте catboost на свой страх и риск :)

# %%
df_optimized = pd.DataFrame(columns=['Library', 'Dataset', 'Training time', 'Train MAE', 'Test MAE'])

parameters = {
    'n_estimators': [100, 500, 800],
    'max_depth': [5, 7, 9, 11],
    'learning_rate': np.logspace(np.log10(0.001), np.log10(0.5), num=3),
}

lib = 'LGBMRegressor'
for data in ['B', 'C']:
  grid = GridSearchCV(estimator=LGBMRegressor(), param_grid=parameters, scoring='neg_mean_absolute_error', n_jobs=-1, cv=4)
  t = time.time()
  grid.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  time_fit = time.time() - t
  model = LGBMRegressor(**grid.best_params_)
  model.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  pred_train = model.predict(datasets[data]['X_train'])
  pred_test = model.predict(datasets[data]['X_test'])
  mae_train = mean_absolute_error(datasets[data]['y_train'], pred_train)
  mae_test = mean_absolute_error(datasets[data]['y_test'], pred_test)
  result = [lib, data, time_fit, mae_train, mae_test]
  df_optimized.loc[len(df_optimized)] = result
  print(f'{lib} best params on {data}: {grid.best_params_}')
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000525 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2065
# [LightGBM] [Info] Number of data points in the train set: 3420, number of used features: 14
# [LightGBM] [Info] Start training from score 151584.135380
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000414 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2065
# [LightGBM] [Info] Number of data points in the train set: 3420, number of used features: 14
# [LightGBM] [Info] Start training from score 151584.135380
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor best params on B: {'learning_rate': 0.5, 'max_depth': 5, 'n_estimators': 100}
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001105 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2179
# [LightGBM] [Info] Number of data points in the train set: 3420, number of used features: 71
# [LightGBM] [Info] Start training from score 151584.135380
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000986 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2179
# [LightGBM] [Info] Number of data points in the train set: 3420, number of used features: 71
# [LightGBM] [Info] Start training from score 151584.135380
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor best params on C: {'learning_rate': 0.5, 'max_depth': 11, 'n_estimators': 800}

# %%
parameters = {
    'n_estimators': [1000],
    'max_depth': [3, 4, 5, 6, 7, 8],
    'learning_rate': [1e-2, 1e-1, 1],
}

lib = 'XGBRegressor'
for data in ['B', 'C']:
  grid = GridSearchCV(estimator=XGBRegressor(), param_grid=parameters, scoring='neg_mean_absolute_error', n_jobs=-1, cv=4)
  t = time.time()
  grid.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  time_fit = time.time() - t
  model = XGBRegressor(**grid.best_params_)
  model.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  pred_train = model.predict(datasets[data]['X_train'])
  pred_test = model.predict(datasets[data]['X_test'])
  mae_train = mean_absolute_error(datasets[data]['y_train'], pred_train)
  mae_test = mean_absolute_error(datasets[data]['y_test'], pred_test)
  result = [lib, data, time_fit, mae_train, mae_test]
  df_optimized.loc[len(df_optimized)] = result
  print(f'{lib} best params on {data}: {grid.best_params_}')
# Out:
# XGBRegressor best params on B: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# XGBRegressor best params on C: {'learning_rate': 0.1, 'max_depth': 8, 'n_estimators': 1000}

# %%
df_optimized
# Out:
#          Library Dataset  Training time      Train MAE       Test MAE
# 0  LGBMRegressor       B      55.603656  101259.054313  122961.471818
# 1  LGBMRegressor       C      70.510745    3553.080652   26635.403039
# 2   XGBRegressor       B      87.464163   98999.037739  121811.095211
# 3   XGBRegressor       C     772.703233    4529.487308   18065.853661

# %% [markdown]
# **<font color='MediumOrchid'>Ваши выводы:</font>**
#
# Перебор параметров может помочь найти лучшую комбинацию, однако для этого необходим маленький шаг, что увеличивает число комбинаций и время нахождения параметров. Если же шаг будет слишком большим и будет перебираться мало параметров, то мы можем пропустить наилучший вариант.

# %% [markdown]
# ### <font color='DarkOrange'>**Задание 1 [2 балла]**</font>
# **Данные**: датасет со стоимостью поддержанных автомобилей
# **Метрика**: MAE
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. Выполнить задание 1 с использованием `всех библиотек` (для каждой библиотеки можно использовать свою сетку перебора). Разрешается использовать маленькие сетки с небольшим числом узлов, но не менее 10.
# 1. Вывести ниже результаты работы с нашими дефолтными `test_parameters` параметрами, а также с оптимальными.
# 1. Вы будете получать <font color='DarkOrange'>**0.5 баллa**</font> за каждую библиотеку с использованием которой точность ваших оптимальных параметров превзойдет качество наших дефолтных параметров. Таким образом, максимальный балл за задание равен числу библиотек, <font color='DarkOrange'>**2 балла.**</font>

# %%
parameters = {
    'iterations': [2000, 5000],
    'depth': [4, 6, 8],
    'learning_rate': [1e-2, 1e-1],
}

lib = 'CatBoostRegressor'
for data in ['B', 'C']:
  grid = GridSearchCV(estimator=CatBoostRegressor(), param_grid=parameters, scoring='neg_mean_absolute_error', n_jobs=-1, cv=4)
  t = time.time()
  grid.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  time_fit = time.time() - t
  model = CatBoostRegressor(**grid.best_params_)
  model.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  pred_train = model.predict(datasets[data]['X_train'])
  pred_test = model.predict(datasets[data]['X_test'])
  mae_train = mean_absolute_error(datasets[data]['y_train'], pred_train)
  mae_test = mean_absolute_error(datasets[data]['y_test'], pred_test)
  result = [lib, data, time_fit, mae_train, mae_test]
  df_optimized.loc[len(df_optimized)] = result
  print(f'{lib} best params on {data}: {grid.best_params_}')
# Out:
# /usr/local/lib/python3.11/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Выходные данные были обрезаны до нескольких последних строк (5000).
# 1:	learn: 334632.8968587	total: 39.9ms	remaining: 1m 39s
# 2:	learn: 319766.3396835	total: 55.5ms	remaining: 1m 32s
# 3:	learn: 304720.8506791	total: 78.2ms	remaining: 1m 37s
# 4:	learn: 291710.0262265	total: 93.8ms	remaining: 1m 33s
# 5:	learn: 275744.8186382	total: 109ms	remaining: 1m 30s
# 6:	learn: 260615.0243997	total: 128ms	remaining: 1m 31s
# 7:	learn: 249850.5208986	total: 147ms	remaining: 1m 32s
# 8:	learn: 237179.1021638	total: 164ms	remaining: 1m 31s
# 9:	learn: 226460.4842353	total: 181ms	remaining: 1m 30s
# 10:	learn: 218251.7170147	total: 185ms	remaining: 1m 24s
# 11:	learn: 206780.2465468	total: 217ms	remaining: 1m 30s
# 12:	learn: 198677.9970856	total: 250ms	remaining: 1m 35s
# 13:	learn: 191740.8011246	total: 256ms	remaining: 1m 31s
# 14:	learn: 185239.1944006	total: 285ms	remaining: 1m 34s
# 15:	learn: 176587.9825542	total: 301ms	remaining: 1m 33s
# 16:	learn: 168139.7333460	total: 318ms	remaining: 1m 33s
# 17:	learn: 161826.8980309	total: 328ms	remaining: 1m 30s
# 18:	learn: 156335.2543373	total: 345ms	remaining: 1m 30s
# 19:	learn: 151543.8802248	total: 349ms	remaining: 1m 26s
# 20:	learn: 146939.7703921	total: 364ms	remaining: 1m 26s
# 21:	learn: 140389.0378808	total: 379ms	remaining: 1m 25s
# 22:	learn: 133768.4897625	total: 395ms	remaining: 1m 25s
# 23:	learn: 129454.0753239	total: 404ms	remaining: 1m 23s
# 24:	learn: 124144.2092958	total: 431ms	remaining: 1m 25s
# 25:	learn: 121416.2253410	total: 446ms	remaining: 1m 25s
# 26:	learn: 118627.8387056	total: 480ms	remaining: 1m 28s
# 27:	learn: 116306.5453980	total: 484ms	remaining: 1m 25s
# 28:	learn: 111762.2034928	total: 505ms	remaining: 1m 26s
# 29:	learn: 107421.7008615	total: 521ms	remaining: 1m 26s
# 30:	learn: 105558.5944926	total: 524ms	remaining: 1m 24s
# 31:	learn: 102367.4306666	total: 540ms	remaining: 1m 23s
# 32:	learn: 98637.7755038	total: 556ms	remaining: 1m 23s
# 33:	learn: 95937.7104323	total: 572ms	remaining: 1m 23s
# 34:	learn: 93816.4428235	total: 589ms	remaining: 1m 23s
# 35:	learn: 92500.1506344	total: 593ms	remaining: 1m 21s
# 36:	learn: 90246.7479307	total: 610ms	remaining: 1m 21s
# 37:	learn: 88000.4865543	total: 631ms	remaining: 1m 22s
# 38:	learn: 86722.1455584	total: 651ms	remaining: 1m 22s
# 39:	learn: 85572.6516354	total: 667ms	remaining: 1m 22s
# 40:	learn: 83863.2136556	total: 673ms	remaining: 1m 21s
# 41:	learn: 82181.3037452	total: 698ms	remaining: 1m 22s
# 42:	learn: 79748.3837765	total: 720ms	remaining: 1m 22s
# 43:	learn: 78301.3837871	total: 731ms	remaining: 1m 22s
# 44:	learn: 77102.5126454	total: 754ms	remaining: 1m 23s
# 45:	learn: 75685.7508933	total: 780ms	remaining: 1m 23s
# 46:	learn: 73936.1123078	total: 796ms	remaining: 1m 23s
# 47:	learn: 72912.7513654	total: 811ms	remaining: 1m 23s
# 48:	learn: 72178.4577802	total: 842ms	remaining: 1m 25s
# 49:	learn: 71251.2643345	total: 855ms	remaining: 1m 24s
# 50:	learn: 70546.3065486	total: 871ms	remaining: 1m 24s
# 51:	learn: 68700.4976166	total: 887ms	remaining: 1m 24s
# 52:	learn: 67951.7691409	total: 911ms	remaining: 1m 25s
# 53:	learn: 66738.3109907	total: 921ms	remaining: 1m 24s
# 54:	learn: 65185.4059458	total: 937ms	remaining: 1m 24s
# 55:	learn: 64664.9235663	total: 953ms	remaining: 1m 24s
# 56:	learn: 64134.8969755	total: 959ms	remaining: 1m 23s
# 57:	learn: 63441.5091654	total: 965ms	remaining: 1m 22s
# 58:	learn: 62059.6248112	total: 991ms	remaining: 1m 23s
# 59:	learn: 61326.4276992	total: 1.01s	remaining: 1m 22s
# 60:	learn: 60812.3016188	total: 1.02s	remaining: 1m 23s
# 61:	learn: 60106.2773069	total: 1.05s	remaining: 1m 23s
# 62:	learn: 59844.0432770	total: 1.06s	remaining: 1m 23s
# 63:	learn: 59214.5753049	total: 1.07s	remaining: 1m 22s
# 64:	learn: 58905.6086551	total: 1.09s	remaining: 1m 22s
# 65:	learn: 58061.8310403	total: 1.1s	remaining: 1m 22s
# 66:	learn: 57421.4025460	total: 1.12s	remaining: 1m 22s
# 67:	learn: 57179.4285432	total: 1.14s	remaining: 1m 22s
# 68:	learn: 56825.7224911	total: 1.16s	remaining: 1m 22s
# 69:	learn: 56312.6702783	total: 1.17s	remaining: 1m 22s
# 70:	learn: 55849.3971542	total: 1.19s	remaining: 1m 22s
# 71:	learn: 55509.7507917	total: 1.2s	remaining: 1m 22s
# 72:	learn: 55254.7446206	total: 1.22s	remaining: 1m 22s
# 73:	learn: 54994.9288197	total: 1.23s	remaining: 1m 21s
# 74:	learn: 54032.9770515	total: 1.25s	remaining: 1m 21s
# 75:	learn: 53828.3757863	total: 1.26s	remaining: 1m 21s
# 76:	learn: 53610.0910952	total: 1.28s	remaining: 1m 22s
# 77:	learn: 53431.6778092	total: 1.3s	remaining: 1m 22s
# 78:	learn: 52991.3869103	total: 1.32s	remaining: 1m 22s
# 79:	learn: 52156.6229776	total: 1.35s	remaining: 1m 22s
# 80:	learn: 51556.6959429	total: 1.37s	remaining: 1m 23s
# 81:	learn: 51380.9512155	total: 1.4s	remaining: 1m 23s
# 82:	learn: 51287.7091990	total: 1.4s	remaining: 1m 22s
# 83:	learn: 51148.2290011	total: 1.42s	remaining: 1m 23s
# 84:	learn: 50972.8140726	total: 1.44s	remaining: 1m 23s
# 85:	learn: 50136.2881281	total: 1.46s	remaining: 1m 23s
# 86:	learn: 49400.6483469	total: 1.48s	remaining: 1m 23s
# 87:	learn: 49249.1096256	total: 1.49s	remaining: 1m 23s
# 88:	learn: 49071.2075137	total: 1.52s	remaining: 1m 24s
# 89:	learn: 48908.1631440	total: 1.54s	remaining: 1m 23s
# 90:	learn: 48219.6445395	total: 1.57s	remaining: 1m 24s
# 91:	learn: 48077.4585421	total: 1.59s	remaining: 1m 24s
# 92:	learn: 47932.7583730	total: 1.61s	remaining: 1m 25s
# 93:	learn: 47810.4429741	total: 1.63s	remaining: 1m 25s
# 94:	learn: 47679.8733405	total: 1.66s	remaining: 1m 25s
# 95:	learn: 46972.4582246	total: 1.68s	remaining: 1m 25s
# 96:	learn: 46255.0862977	total: 1.69s	remaining: 1m 25s
# 97:	learn: 46145.1095433	total: 1.71s	remaining: 1m 25s
# 98:	learn: 45344.3009851	total: 1.73s	remaining: 1m 25s
# 99:	learn: 45249.2561579	total: 1.74s	remaining: 1m 25s
# 100:	learn: 45157.5608936	total: 1.76s	remaining: 1m 25s
# 101:	learn: 44569.1295608	total: 1.78s	remaining: 1m 25s
# 102:	learn: 44485.0038118	total: 1.79s	remaining: 1m 25s
# 103:	learn: 44398.2539720	total: 1.81s	remaining: 1m 25s
# 104:	learn: 44161.6153334	total: 1.83s	remaining: 1m 25s
# 105:	learn: 44039.3135173	total: 1.85s	remaining: 1m 25s
# 106:	learn: 43938.0161375	total: 1.87s	remaining: 1m 25s
# 107:	learn: 43211.6265324	total: 1.89s	remaining: 1m 25s
# 108:	learn: 43144.4127541	total: 1.9s	remaining: 1m 25s
# 109:	learn: 43080.4229932	total: 1.93s	remaining: 1m 25s
# 110:	learn: 43012.1970973	total: 1.95s	remaining: 1m 26s
# 111:	learn: 42819.0214793	total: 1.98s	remaining: 1m 26s
# 112:	learn: 42097.0602361	total: 2.02s	remaining: 1m 27s
# 113:	learn: 41904.7306167	total: 2.03s	remaining: 1m 27s
# 114:	learn: 41274.1473607	total: 2.05s	remaining: 1m 27s
# 115:	learn: 41021.7724231	total: 2.07s	remaining: 1m 27s
# 116:	learn: 40523.6907456	total: 2.09s	remaining: 1m 27s
# 117:	learn: 40467.0193213	total: 2.1s	remaining: 1m 26s
# 118:	learn: 40412.9489077	total: 2.12s	remaining: 1m 26s
# 119:	learn: 40263.7956694	total: 2.13s	remaining: 1m 26s
# 120:	learn: 40212.6104221	total: 2.15s	remaining: 1m 26s
# 121:	learn: 39713.5401346	total: 2.18s	remaining: 1m 27s
# 122:	learn: 39159.8130434	total: 2.21s	remaining: 1m 27s
# 123:	learn: 39110.9351857	total: 2.23s	remaining: 1m 27s
# 124:	learn: 39064.3280396	total: 2.25s	remaining: 1m 27s
# 125:	learn: 38677.8130051	total: 2.26s	remaining: 1m 27s
# 126:	learn: 38545.8454758	total: 2.28s	remaining: 1m 27s
# 127:	learn: 38501.0073900	total: 2.29s	remaining: 1m 27s
# 128:	learn: 38456.5058580	total: 2.31s	remaining: 1m 27s
# 129:	learn: 38231.5934336	total: 2.33s	remaining: 1m 27s
# 130:	learn: 38121.8779230	total: 2.34s	remaining: 1m 27s
# 131:	learn: 38028.3428267	total: 2.36s	remaining: 1m 26s
# 132:	learn: 37924.5202317	total: 2.38s	remaining: 1m 26s
# 133:	learn: 37412.1080132	total: 2.4s	remaining: 1m 27s
# 134:	learn: 37324.4309710	total: 2.42s	remaining: 1m 27s
# 135:	learn: 36853.7082823	total: 2.44s	remaining: 1m 27s
# 136:	learn: 36808.7292524	total: 2.46s	remaining: 1m 27s
# 137:	learn: 36349.3206687	total: 2.48s	remaining: 1m 27s
# 138:	learn: 36310.6373874	total: 2.5s	remaining: 1m 27s
# 139:	learn: 36272.1529529	total: 2.53s	remaining: 1m 27s
# 140:	learn: 35888.5188911	total: 2.56s	remaining: 1m 28s
# 141:	learn: 35848.5353833	total: 2.6s	remaining: 1m 28s
# 142:	learn: 35438.8073842	total: 2.62s	remaining: 1m 28s
# 143:	learn: 35403.4987703	total: 2.64s	remaining: 1m 29s
# 144:	learn: 35159.0849937	total: 2.67s	remaining: 1m 29s
# 145:	learn: 35124.4474565	total: 2.68s	remaining: 1m 29s
# 146:	learn: 35089.9685357	total: 2.7s	remaining: 1m 29s
# 147:	learn: 34681.1854864	total: 2.71s	remaining: 1m 28s
# 148:	learn: 34503.2840475	total: 2.74s	remaining: 1m 29s
# 149:	learn: 34469.6346830	total: 2.75s	remaining: 1m 29s
# 150:	learn: 34438.4276376	total: 2.77s	remaining: 1m 29s
# 151:	learn: 34059.7148782	total: 2.79s	remaining: 1m 29s
# 152:	learn: 34028.2045709	total: 2.82s	remaining: 1m 29s
# 153:	learn: 33998.2274992	total: 2.83s	remaining: 1m 29s
# 154:	learn: 33813.2122658	total: 2.85s	remaining: 1m 29s
# 155:	learn: 33712.0575420	total: 2.87s	remaining: 1m 29s
# 156:	learn: 33438.2942470	total: 2.89s	remaining: 1m 29s
# 157:	learn: 33375.9173717	total: 2.9s	remaining: 1m 29s
# 158:	learn: 33346.7398301	total: 2.92s	remaining: 1m 28s
# 159:	learn: 33140.2857116	total: 2.94s	remaining: 1m 28s
# 160:	learn: 33055.3089030	total: 2.96s	remaining: 1m 28s
# 161:	learn: 33027.4947255	total: 2.97s	remaining: 1m 28s
# 162:	learn: 33001.8223104	total: 2.99s	remaining: 1m 28s
# 163:	learn: 32974.7608182	total: 3.01s	remaining: 1m 28s
# 164:	learn: 32948.7504315	total: 3.03s	remaining: 1m 28s
# 165:	learn: 32609.1180363	total: 3.05s	remaining: 1m 28s
# 166:	learn: 32287.0433379	total: 3.08s	remaining: 1m 29s
# 167:	learn: 32261.6766867	total: 3.1s	remaining: 1m 29s
# 168:	learn: 32223.0545140	total: 3.12s	remaining: 1m 29s
# 169:	learn: 31962.5319664	total: 3.15s	remaining: 1m 29s
# 170:	learn: 31892.8505955	total: 3.17s	remaining: 1m 29s
# 171:	learn: 31642.1706684	total: 3.19s	remaining: 1m 29s
# 172:	learn: 31587.3224676	total: 3.21s	remaining: 1m 29s
# 173:	learn: 31552.0719590	total: 3.22s	remaining: 1m 29s
# 174:	learn: 31295.2708121	total: 3.24s	remaining: 1m 29s
# 175:	learn: 31050.3568118	total: 3.26s	remaining: 1m 29s
# 176:	learn: 31022.9635254	total: 3.27s	remaining: 1m 29s
# 177:	learn: 30804.3382147	total: 3.3s	remaining: 1m 29s
# 178:	learn: 30781.2971440	total: 3.32s	remaining: 1m 29s
# 179:	learn: 30705.5639180	total: 3.34s	remaining: 1m 29s
# 180:	learn: 30657.3580214	total: 3.37s	remaining: 1m 29s
# 181:	learn: 30546.5264697	total: 3.39s	remaining: 1m 29s
# 182:	learn: 30518.9009324	total: 3.4s	remaining: 1m 29s
# 183:	learn: 30496.8441418	total: 3.42s	remaining: 1m 29s
# 184:	learn: 30452.4573088	total: 3.44s	remaining: 1m 29s
# 185:	learn: 30360.7561962	total: 3.45s	remaining: 1m 29s
# 186:	learn: 30251.2403014	total: 3.47s	remaining: 1m 29s
# 187:	learn: 30033.4213199	total: 3.48s	remaining: 1m 29s
# 188:	learn: 30011.7752658	total: 3.5s	remaining: 1m 29s
# 189:	learn: 29965.1389806	total: 3.52s	remaining: 1m 29s
# 190:	learn: 29924.3946501	total: 3.54s	remaining: 1m 29s
# 191:	learn: 29748.8452964	total: 3.56s	remaining: 1m 29s
# 192:	learn: 29713.3426655	total: 3.59s	remaining: 1m 29s
# 193:	learn: 29493.0934998	total: 3.62s	remaining: 1m 29s
# 194:	learn: 29349.0935899	total: 3.64s	remaining: 1m 29s
# 195:	learn: 29327.8610496	total: 3.67s	remaining: 1m 29s
# 196:	learn: 29185.6369652	total: 3.69s	remaining: 1m 30s
# 197:	learn: 29066.9691104	total: 3.73s	remaining: 1m 30s
# 198:	learn: 29046.3671649	total: 3.76s	remaining: 1m 30s
# 199:	learn: 29009.0154298	total: 3.77s	remaining: 1m 30s
# 200:	learn: 28988.9984646	total: 3.79s	remaining: 1m 30s
# 201:	learn: 28912.1069915	total: 3.81s	remaining: 1m 30s
# 202:	learn: 28875.4177362	total: 3.82s	remaining: 1m 30s
# 203:	learn: 28674.5648567	total: 3.84s	remaining: 1m 30s
# 204:	learn: 28647.5189062	total: 3.86s	remaining: 1m 30s
# 205:	learn: 28627.6258068	total: 3.87s	remaining: 1m 30s
# 206:	learn: 28443.0864098	total: 3.89s	remaining: 1m 30s
# 207:	learn: 28411.1097178	total: 3.92s	remaining: 1m 30s
# 208:	learn: 28386.8316791	total: 3.94s	remaining: 1m 30s
# 209:	learn: 28367.3214931	total: 3.97s	remaining: 1m 30s
# 210:	learn: 28336.9096270	total: 3.99s	remaining: 1m 30s
# 211:	learn: 28205.4007390	total: 4s	remaining: 1m 30s
# 212:	learn: 28186.8361460	total: 4.02s	remaining: 1m 30s
# 213:	learn: 28078.4187881	total: 4.03s	remaining: 1m 30s
# 214:	learn: 28046.3313254	total: 4.05s	remaining: 1m 30s
# 215:	learn: 28014.2213802	total: 4.07s	remaining: 1m 30s
# 216:	learn: 27995.6998351	total: 4.08s	remaining: 1m 30s
# 217:	learn: 27977.5271223	total: 4.1s	remaining: 1m 29s
# 218:	learn: 27799.9419661	total: 4.12s	remaining: 1m 29s
# 219:	learn: 27781.4005564	total: 4.14s	remaining: 1m 29s
# 220:	learn: 27714.3716232	total: 4.16s	remaining: 1m 29s
# 221:	learn: 27696.2717656	total: 4.18s	remaining: 1m 29s
# 222:	learn: 27663.7504162	total: 4.2s	remaining: 1m 29s
# 223:	learn: 27505.3773157	total: 4.21s	remaining: 1m 29s
# 224:	learn: 27488.2320662	total: 4.24s	remaining: 1m 30s
# 225:	learn: 27471.1682066	total: 4.26s	remaining: 1m 30s
# 226:	learn: 27348.3061668	total: 4.29s	remaining: 1m 30s
# 227:	learn: 27232.6854361	total: 4.31s	remaining: 1m 30s
# 228:	learn: 27003.1682310	total: 4.33s	remaining: 1m 30s
# 229:	learn: 26974.3246458	total: 4.35s	remaining: 1m 30s
# 230:	learn: 26957.7093943	total: 4.37s	remaining: 1m 30s
# 231:	learn: 26879.2408596	total: 4.39s	remaining: 1m 30s
# 232:	learn: 26851.2806662	total: 4.4s	remaining: 1m 30s
# 233:	learn: 26686.0424462	total: 4.42s	remaining: 1m 30s
# 234:	learn: 26650.6989257	total: 4.43s	remaining: 1m 29s
# 235:	learn: 26624.6785092	total: 4.45s	remaining: 1m 29s
# 236:	learn: 26482.5953980	total: 4.48s	remaining: 1m 29s
# 237:	learn: 26442.8472742	total: 4.5s	remaining: 1m 29s
# 238:	learn: 26387.0195228	total: 4.51s	remaining: 1m 29s
# 239:	learn: 26370.2359721	total: 4.53s	remaining: 1m 29s
# 240:	learn: 26339.6636555	total: 4.55s	remaining: 1m 29s
# 241:	learn: 26304.3976026	total: 4.57s	remaining: 1m 29s
# 242:	learn: 26279.5186862	total: 4.59s	remaining: 1m 29s
# 243:	learn: 26250.8439675	total: 4.62s	remaining: 1m 30s
# 244:	learn: 26125.1967656	total: 4.65s	remaining: 1m 30s
# 245:	learn: 26109.3419872	total: 4.67s	remaining: 1m 30s
# 246:	learn: 25999.9123118	total: 4.68s	remaining: 1m 30s
# 247:	learn: 25984.5830393	total: 4.7s	remaining: 1m 30s
# 248:	learn: 25956.9161913	total: 4.72s	remaining: 1m 30s
# 249:	learn: 25930.6110609	total: 4.74s	remaining: 1m 29s
# 250:	learn: 25915.8933182	total: 4.75s	remaining: 1m 29s
# 251:	learn: 25890.6643789	total: 4.77s	remaining: 1m 29s
# 252:	learn: 25850.6691102	total: 4.79s	remaining: 1m 29s
# 253:	learn: 25738.7332057	total: 4.83s	remaining: 1m 30s
# 254:	learn: 25724.1267798	total: 4.85s	remaining: 1m 30s
# 255:	learn: 25710.0780627	total: 4.87s	remaining: 1m 30s
# 256:	learn: 25675.4733382	total: 4.9s	remaining: 1m 30s
# 257:	learn: 25661.7748824	total: 4.91s	remaining: 1m 30s
# 258:	learn: 25576.4967719	total: 4.93s	remaining: 1m 30s
# 259:	learn: 25563.2252769	total: 4.94s	remaining: 1m 30s
# 260:	learn: 25458.5650628	total: 4.96s	remaining: 1m 30s
# 261:	learn: 25437.9587927	total: 4.98s	remaining: 1m 29s
# 262:	learn: 25424.8348278	total: 4.99s	remaining: 1m 29s
# 263:	learn: 25324.5545189	total: 5.01s	remaining: 1m 29s
# 264:	learn: 25311.2329626	total: 5.02s	remaining: 1m 29s
# 265:	learn: 25298.5196378	total: 5.05s	remaining: 1m 29s
# 266:	learn: 25205.0087471	total: 5.08s	remaining: 1m 30s
# 267:	learn: 25193.3116930	total: 5.1s	remaining: 1m 30s
# 268:	learn: 25101.2172393	total: 5.12s	remaining: 1m 30s
# 269:	learn: 25088.3873899	total: 5.13s	remaining: 1m 29s
# 270:	learn: 25064.0658235	total: 5.15s	remaining: 1m 29s
# 271:	learn: 25051.6295829	total: 5.16s	remaining: 1m 29s
# 272:	learn: 24902.0916699	total: 5.18s	remaining: 1m 29s
# 273:	learn: 24890.0007979	total: 5.2s	remaining: 1m 29s
# 274:	learn: 24877.7218228	total: 5.21s	remaining: 1m 29s
# 275:	learn: 24865.7776513	total: 5.22s	remaining: 1m 29s
# 276:	learn: 24785.4312432	total: 5.24s	remaining: 1m 29s
# 277:	learn: 24773.6969042	total: 5.27s	remaining: 1m 29s
# 278:	learn: 24752.9258742	total: 5.28s	remaining: 1m 29s
# 279:	learn: 24714.0711677	total: 5.31s	remaining: 1m 29s
# 280:	learn: 24701.6213056	total: 5.33s	remaining: 1m 29s
# 281:	learn: 24668.2897195	total: 5.34s	remaining: 1m 29s
# 282:	learn: 24656.1030339	total: 5.36s	remaining: 1m 29s
# 283:	learn: 24644.3976153	total: 5.38s	remaining: 1m 29s
# 284:	learn: 24632.7802026	total: 5.41s	remaining: 1m 29s
# 285:	learn: 24621.6998126	total: 5.44s	remaining: 1m 29s
# 286:	learn: 24597.3237595	total: 5.47s	remaining: 1m 29s
# 287:	learn: 24586.7453638	total: 5.49s	remaining: 1m 29s
# 288:	learn: 24531.7267485	total: 5.51s	remaining: 1m 29s
# 289:	learn: 24486.6890203	total: 5.53s	remaining: 1m 29s
# 290:	learn: 24454.3815450	total: 5.54s	remaining: 1m 29s
# 291:	learn: 24431.6181196	total: 5.56s	remaining: 1m 29s
# 292:	learn: 24340.9479740	total: 5.58s	remaining: 1m 29s
# 293:	learn: 24265.6096970	total: 5.6s	remaining: 1m 29s
# 294:	learn: 24244.8892869	total: 5.63s	remaining: 1m 29s
# 295:	learn: 24206.0960399	total: 5.66s	remaining: 1m 29s
# 296:	learn: 24184.5572061	total: 5.7s	remaining: 1m 30s
# 297:	learn: 24160.1287170	total: 5.72s	remaining: 1m 30s
# 298:	learn: 24125.7284505	total: 5.73s	remaining: 1m 30s
# 299:	learn: 24099.3247078	total: 5.75s	remaining: 1m 30s
# 300:	learn: 24059.2849877	total: 5.76s	remaining: 1m 29s
# 301:	learn: 24037.0565543	total: 5.78s	remaining: 1m 29s
# 302:	learn: 24025.8249956	total: 5.79s	remaining: 1m 29s
# 303:	learn: 23900.6625227	total: 5.81s	remaining: 1m 29s
# 304:	learn: 23882.1441348	total: 5.83s	remaining: 1m 29s
# 305:	learn: 23865.5223454	total: 5.84s	remaining: 1m 29s
# 306:	learn: 23845.8013214	total: 5.86s	remaining: 1m 29s
# 307:	learn: 23834.7460422	total: 5.88s	remaining: 1m 29s
# 308:	learn: 23766.6960524	total: 5.89s	remaining: 1m 29s
# 309:	learn: 23745.7252343	total: 5.92s	remaining: 1m 29s
# 310:	learn: 23726.3786906	total: 5.94s	remaining: 1m 29s
# 311:	learn: 23710.6857792	total: 5.96s	remaining: 1m 29s
# 312:	learn: 23561.8304411	total: 5.99s	remaining: 1m 29s
# 313:	learn: 23548.8097066	total: 6s	remaining: 1m 29s
# 314:	learn: 23537.6241201	total: 6.03s	remaining: 1m 29s
# 315:	learn: 23526.8681376	total: 6.06s	remaining: 1m 29s
# 316:	learn: 23517.0972429	total: 6.08s	remaining: 1m 29s
# 317:	learn: 23404.3109863	total: 6.09s	remaining: 1m 29s
# 318:	learn: 23357.1238161	total: 6.11s	remaining: 1m 29s
# 319:	learn: 23346.7985036	total: 6.13s	remaining: 1m 29s
# 320:	learn: 23320.1312615	total: 6.15s	remaining: 1m 29s
# 321:	learn: 23306.1635126	total: 6.16s	remaining: 1m 29s
# 322:	learn: 23201.6746551	total: 6.18s	remaining: 1m 29s
# 323:	learn: 23180.8942925	total: 6.2s	remaining: 1m 29s
# 324:	learn: 23170.9619676	total: 6.22s	remaining: 1m 29s
# 325:	learn: 23148.4117324	total: 6.24s	remaining: 1m 29s
# 326:	learn: 23095.1704144	total: 6.26s	remaining: 1m 29s
# 327:	learn: 23085.1882554	total: 6.28s	remaining: 1m 29s
# 328:	learn: 23075.3216432	total: 6.3s	remaining: 1m 29s
# 329:	learn: 23057.4885606	total: 6.31s	remaining: 1m 29s
# 330:	learn: 23047.9788795	total: 6.33s	remaining: 1m 29s
# 331:	learn: 23000.6817423	total: 6.35s	remaining: 1m 29s
# 332:	learn: 22964.9366227	total: 6.37s	remaining: 1m 29s
# 333:	learn: 22955.1238035	total: 6.38s	remaining: 1m 29s
# 334:	learn: 22881.1176056	total: 6.4s	remaining: 1m 29s
# 335:	learn: 22871.6920537	total: 6.41s	remaining: 1m 29s
# 336:	learn: 22853.9921602	total: 6.43s	remaining: 1m 29s
# 337:	learn: 22700.7682228	total: 6.45s	remaining: 1m 28s
# 338:	learn: 22691.2197303	total: 6.47s	remaining: 1m 28s
# 339:	learn: 22633.3805492	total: 6.48s	remaining: 1m 28s
# 340:	learn: 22623.9490993	total: 6.51s	remaining: 1m 28s
# 341:	learn: 22614.7263092	total: 6.54s	remaining: 1m 29s
# 342:	learn: 22606.0195964	total: 6.56s	remaining: 1m 29s
# 343:	learn: 22597.1757239	total: 6.59s	remaining: 1m 29s
# 344:	learn: 22538.2291345	total: 6.61s	remaining: 1m 29s
# 345:	learn: 22522.7467952	total: 6.64s	remaining: 1m 29s
# 346:	learn: 22508.4897489	total: 6.66s	remaining: 1m 29s
# 347:	learn: 22499.4790609	total: 6.67s	remaining: 1m 29s
# 348:	learn: 22480.6295880	total: 6.7s	remaining: 1m 29s
# 349:	learn: 22404.6172358	total: 6.72s	remaining: 1m 29s
# 350:	learn: 22387.4571024	total: 6.73s	remaining: 1m 29s
# 351:	learn: 22369.5487570	total: 6.76s	remaining: 1m 29s
# 352:	learn: 22263.4559109	total: 6.78s	remaining: 1m 29s
# 353:	learn: 22254.6986466	total: 6.8s	remaining: 1m 29s
# 354:	learn: 22245.8310266	total: 6.82s	remaining: 1m 29s
# 355:	learn: 22136.7560864	total: 6.83s	remaining: 1m 29s
# 356:	learn: 22120.2432298	total: 6.85s	remaining: 1m 29s
# 357:	learn: 22094.8806174	total: 6.88s	remaining: 1m 29s
# 358:	learn: 22086.0718941	total: 6.89s	remaining: 1m 29s
# 359:	learn: 22065.5712029	total: 6.91s	remaining: 1m 29s
# 360:	learn: 22052.4923457	total: 6.92s	remaining: 1m 28s
# 361:	learn: 22034.5778423	total: 6.93s	remaining: 1m 28s
# 362:	learn: 21938.6062988	total: 6.95s	remaining: 1m 28s
# 363:	learn: 21910.6167823	total: 6.97s	remaining: 1m 28s
# 364:	learn: 21888.5978491	total: 6.99s	remaining: 1m 28s
# 365:	learn: 21871.3167756	total: 7.01s	remaining: 1m 28s
# 366:	learn: 21782.5310644	total: 7.03s	remaining: 1m 28s
# 367:	learn: 21773.6655281	total: 7.04s	remaining: 1m 28s
# 368:	learn: 21760.8783825	total: 7.06s	remaining: 1m 28s
# 369:	learn: 21729.2207885	total: 7.08s	remaining: 1m 28s
# 370:	learn: 21720.1312358	total: 7.11s	remaining: 1m 28s
# 371:	learn: 21711.6808555	total: 7.13s	remaining: 1m 28s
# 372:	learn: 21685.9223707	total: 7.15s	remaining: 1m 28s
# 373:	learn: 21668.6713638	total: 7.17s	remaining: 1m 28s
# 374:	learn: 21645.1259833	total: 7.19s	remaining: 1m 28s
# 375:	learn: 21637.0133022	total: 7.21s	remaining: 1m 28s
# 376:	learn: 21578.9848358	total: 7.23s	remaining: 1m 28s
# 377:	learn: 21484.6205751	total: 7.25s	remaining: 1m 28s
# 378:	learn: 21474.1926182	total: 7.27s	remaining: 1m 28s
# 379:	learn: 21465.9359785	total: 7.28s	remaining: 1m 28s
# 380:	learn: 21442.0505840	total: 7.3s	remaining: 1m 28s
# 381:	learn: 21419.8830569	total: 7.32s	remaining: 1m 28s
# 382:	learn: 21362.9258591	total: 7.34s	remaining: 1m 28s
# 383:	learn: 21354.7171002	total: 7.36s	remaining: 1m 28s
# 384:	learn: 21306.2293826	total: 7.37s	remaining: 1m 28s
# 385:	learn: 21287.8776902	total: 7.39s	remaining: 1m 28s
# 386:	learn: 21279.9079090	total: 7.41s	remaining: 1m 28s
# 387:	learn: 21264.9168862	total: 7.43s	remaining: 1m 28s
# 388:	learn: 21257.0462880	total: 7.46s	remaining: 1m 28s
# 389:	learn: 21247.0562962	total: 7.47s	remaining: 1m 28s
# 390:	learn: 21133.1408951	total: 7.49s	remaining: 1m 28s
# 391:	learn: 21125.2243421	total: 7.5s	remaining: 1m 28s
# 392:	learn: 21117.5320555	total: 7.52s	remaining: 1m 28s
# 393:	learn: 21106.5376772	total: 7.54s	remaining: 1m 28s
# 394:	learn: 21080.1796730	total: 7.56s	remaining: 1m 28s
# 395:	learn: 21062.9759871	total: 7.58s	remaining: 1m 28s
# 396:	learn: 21046.3816067	total: 7.61s	remaining: 1m 28s
# 397:	learn: 21035.0016274	total: 7.63s	remaining: 1m 28s
# 398:	learn: 21002.8150193	total: 7.65s	remaining: 1m 28s
# 399:	learn: 20995.2065138	total: 7.68s	remaining: 1m 28s
# 400:	learn: 20975.3660693	total: 7.7s	remaining: 1m 28s
# 401:	learn: 20890.9842438	total: 7.72s	remaining: 1m 28s
# 402:	learn: 20872.3562721	total: 7.74s	remaining: 1m 28s
# 403:	learn: 20864.7930746	total: 7.77s	remaining: 1m 28s
# 404:	learn: 20851.6156685	total: 7.79s	remaining: 1m 28s
# 405:	learn: 20837.4396930	total: 7.81s	remaining: 1m 28s
# 406:	learn: 20815.0233605	total: 7.83s	remaining: 1m 28s
# 407:	learn: 20807.6604163	total: 7.84s	remaining: 1m 28s
# 408:	learn: 20784.1904709	total: 7.86s	remaining: 1m 28s
# 409:	learn: 20703.0183869	total: 7.88s	remaining: 1m 28s
# 410:	learn: 20599.9747498	total: 7.9s	remaining: 1m 28s
# 411:	learn: 20574.4791939	total: 7.92s	remaining: 1m 28s
# 412:	learn: 20561.1898428	total: 7.94s	remaining: 1m 28s
# 413:	learn: 20513.3750838	total: 7.95s	remaining: 1m 28s
# 414:	learn: 20505.9604633	total: 7.97s	remaining: 1m 28s
# 415:	learn: 20492.7645716	total: 7.99s	remaining: 1m 28s
# 416:	learn: 20481.4554189	total: 8.01s	remaining: 1m 27s
# 417:	learn: 20474.2223894	total: 8.03s	remaining: 1m 28s
# 418:	learn: 20357.7666721	total: 8.05s	remaining: 1m 27s
# 419:	learn: 20334.7060190	total: 8.06s	remaining: 1m 27s
# 420:	learn: 20318.8096683	total: 8.08s	remaining: 1m 27s
# 421:	learn: 20267.0297490	total: 8.1s	remaining: 1m 27s
# 422:	learn: 20259.8263587	total: 8.11s	remaining: 1m 27s
# 423:	learn: 20250.0512442	total: 8.13s	remaining: 1m 27s
# 424:	learn: 20236.0328245	total: 8.15s	remaining: 1m 27s
# 425:	learn: 20229.0089652	total: 8.16s	remaining: 1m 27s
# 426:	learn: 20149.9378173	total: 8.18s	remaining: 1m 27s
# 427:	learn: 20143.0313306	total: 8.2s	remaining: 1m 27s
# 428:	learn: 20052.7645433	total: 8.23s	remaining: 1m 27s
# 429:	learn: 20032.9524797	total: 8.26s	remaining: 1m 27s
# 430:	learn: 19948.5035835	total: 8.28s	remaining: 1m 27s
# 431:	learn: 19941.6002488	total: 8.29s	remaining: 1m 27s
# 432:	learn: 19925.3033446	total: 8.31s	remaining: 1m 27s
# 433:	learn: 19911.9483741	total: 8.34s	remaining: 1m 27s
# 434:	learn: 19897.1212509	total: 8.36s	remaining: 1m 27s
# 435:	learn: 19871.1834891	total: 8.38s	remaining: 1m 27s
# 436:	learn: 19856.7063965	total: 8.4s	remaining: 1m 27s
# 437:	learn: 19849.9272029	total: 8.41s	remaining: 1m 27s
# 438:	learn: 19843.2819600	total: 8.43s	remaining: 1m 27s
# 439:	learn: 19834.2203802	total: 8.45s	remaining: 1m 27s
# 440:	learn: 19807.6772856	total: 8.48s	remaining: 1m 27s
# 441:	learn: 19794.9511978	total: 8.51s	remaining: 1m 27s
# 442:	learn: 19673.9983218	total: 8.54s	remaining: 1m 27s
# 443:	learn: 19653.1252217	total: 8.58s	remaining: 1m 28s
# 444:	learn: 19634.9797806	total: 8.62s	remaining: 1m 28s
# 445:	learn: 19628.5820943	total: 8.63s	remaining: 1m 28s
# 446:	learn: 19609.0863480	total: 8.65s	remaining: 1m 28s
# 447:	learn: 19525.1701664	total: 8.67s	remaining: 1m 28s
# 448:	learn: 19501.4692621	total: 8.68s	remaining: 1m 28s
# 449:	learn: 19495.0770989	total: 8.71s	remaining: 1m 28s
# 450:	learn: 19484.3393039	total: 8.72s	remaining: 1m 27s
# 451:	learn: 19465.1361623	total: 8.74s	remaining: 1m 27s
# 452:	learn: 19458.6296131	total: 8.77s	remaining: 1m 28s
# 453:	learn: 19442.3629307	total: 8.79s	remaining: 1m 28s
# 454:	learn: 19435.9357163	total: 8.81s	remaining: 1m 27s
# 455:	learn: 19416.1085484	total: 8.83s	remaining: 1m 28s
# 456:	learn: 19399.7536230	total: 8.86s	remaining: 1m 28s
# 457:	learn: 19378.9156735	total: 8.88s	remaining: 1m 28s
# 458:	learn: 19359.2760210	total: 8.91s	remaining: 1m 28s
# 459:	learn: 19349.7822765	total: 8.93s	remaining: 1m 28s
# 460:	learn: 19337.8255035	total: 8.95s	remaining: 1m 28s
# 461:	learn: 19329.6085564	total: 8.97s	remaining: 1m 28s
# 462:	learn: 19317.3225760	total: 8.99s	remaining: 1m 28s
# 463:	learn: 19310.9574175	total: 9s	remaining: 1m 28s
# 464:	learn: 19292.6770285	total: 9.04s	remaining: 1m 28s
# 465:	learn: 19277.7858437	total: 9.06s	remaining: 1m 28s
# 466:	learn: 19269.0224159	total: 9.1s	remaining: 1m 28s
# 467:	learn: 19262.6914966	total: 9.14s	remaining: 1m 28s
# 468:	learn: 19256.6098549	total: 9.18s	remaining: 1m 28s
# 469:	learn: 19246.9973477	total: 9.21s	remaining: 1m 28s
# 470:	learn: 19230.4922138	total: 9.24s	remaining: 1m 28s
# 471:	learn: 19224.2509309	total: 9.27s	remaining: 1m 28s
# 472:	learn: 19218.0603625	total: 9.29s	remaining: 1m 28s
# 473:	learn: 19212.1786087	total: 9.33s	remaining: 1m 29s
# 474:	learn: 19206.1308537	total: 9.37s	remaining: 1m 29s
# 475:	learn: 19190.4057893	total: 9.4s	remaining: 1m 29s
# 476:	learn: 19179.4512413	total: 9.44s	remaining: 1m 29s
# 477:	learn: 19090.3767750	total: 9.48s	remaining: 1m 29s
# 478:	learn: 19052.4825857	total: 9.51s	remaining: 1m 29s
# 479:	learn: 19046.3336986	total: 9.54s	remaining: 1m 29s
# 480:	learn: 19029.7273244	total: 9.58s	remaining: 1m 30s
# 481:	learn: 19014.1188680	total: 9.61s	remaining: 1m 30s
# 482:	learn: 19008.5083749	total: 9.63s	remaining: 1m 30s
# 483:	learn: 19002.5339920	total: 9.67s	remaining: 1m 30s
# 484:	learn: 18987.3462644	total: 9.71s	remaining: 1m 30s
# 485:	learn: 18975.1809816	total: 9.74s	remaining: 1m 30s
# 486:	learn: 18954.5273549	total: 9.78s	remaining: 1m 30s
# 487:	learn: 18943.3165680	total: 9.81s	remaining: 1m 30s
# 488:	learn: 18925.4286605	total: 9.84s	remaining: 1m 30s
# 489:	learn: 18909.0118309	total: 9.87s	remaining: 1m 30s
# 490:	learn: 18843.5168932	total: 9.9s	remaining: 1m 30s
# 491:	learn: 18833.1872050	total: 9.94s	remaining: 1m 31s
# 492:	learn: 18767.0709587	total: 9.97s	remaining: 1m 31s
# 493:	learn: 18758.3513914	total: 10s	remaining: 1m 31s
# 494:	learn: 18752.3257750	total: 10s	remaining: 1m 31s
# 495:	learn: 18746.4092802	total: 10.1s	remaining: 1m 31s
# 496:	learn: 18681.5301841	total: 10.1s	remaining: 1m 31s
# 497:	learn: 18668.7660230	total: 10.1s	remaining: 1m 31s
# 498:	learn: 18662.9046537	total: 10.2s	remaining: 1m 31s
# 499:	learn: 18649.7855624	total: 10.2s	remaining: 1m 31s
# 500:	learn: 18644.0101012	total: 10.2s	remaining: 1m 31s
# 501:	learn: 18588.6312501	total: 10.3s	remaining: 1m 32s
# 502:	learn: 18524.5104245	total: 10.3s	remaining: 1m 32s
# 503:	learn: 18510.5697601	total: 10.3s	remaining: 1m 32s
# 504:	learn: 18496.5186020	total: 10.4s	remaining: 1m 32s
# 505:	learn: 18487.2577011	total: 10.4s	remaining: 1m 32s
# 506:	learn: 18481.7217513	total: 10.4s	remaining: 1m 32s
# 507:	learn: 18473.2686833	total: 10.4s	remaining: 1m 32s
# 508:	learn: 18467.5759791	total: 10.5s	remaining: 1m 32s
# 509:	learn: 18462.1443980	total: 10.5s	remaining: 1m 32s
# 510:	learn: 18456.6720117	total: 10.5s	remaining: 1m 32s
# 511:	learn: 18447.1313178	total: 10.6s	remaining: 1m 32s
# 512:	learn: 18437.8517162	total: 10.6s	remaining: 1m 32s
# 513:	learn: 18432.7402306	total: 10.7s	remaining: 1m 33s
# 514:	learn: 18417.9890811	total: 10.7s	remaining: 1m 33s
# 515:	learn: 18409.0227994	total: 10.7s	remaining: 1m 33s
# 516:	learn: 18391.6908390	total: 10.8s	remaining: 1m 33s
# 517:	learn: 18386.7312709	total: 10.8s	remaining: 1m 33s
# 518:	learn: 18381.5230774	total: 10.8s	remaining: 1m 33s
# 519:	learn: 18373.8523636	total: 10.9s	remaining: 1m 33s
# 520:	learn: 18356.6908701	total: 10.9s	remaining: 1m 33s
# 521:	learn: 18348.0598679	total: 10.9s	remaining: 1m 33s
# 522:	learn: 18331.2765990	total: 11s	remaining: 1m 33s
# 523:	learn: 18306.1855991	total: 11s	remaining: 1m 33s
# 524:	learn: 18300.8832145	total: 11s	remaining: 1m 33s
# 525:	learn: 18221.4996360	total: 11s	remaining: 1m 33s
# 526:	learn: 18146.8921973	total: 11.1s	remaining: 1m 34s
# 527:	learn: 18105.1450087	total: 11.1s	remaining: 1m 34s
# 528:	learn: 18048.4509317	total: 11.2s	remaining: 1m 34s
# 529:	learn: 18040.9804493	total: 11.2s	remaining: 1m 34s
# 530:	learn: 18035.5350473	total: 11.2s	remaining: 1m 34s
# 531:	learn: 17967.5874522	total: 11.3s	remaining: 1m 34s
# 532:	learn: 17962.1880458	total: 11.3s	remaining: 1m 34s
# 533:	learn: 17916.0750164	total: 11.3s	remaining: 1m 34s
# 534:	learn: 17906.1962352	total: 11.4s	remaining: 1m 34s
# 535:	learn: 17898.2238317	total: 11.4s	remaining: 1m 34s
# 536:	learn: 17814.4601056	total: 11.4s	remaining: 1m 34s
# 537:	learn: 17809.3519385	total: 11.5s	remaining: 1m 35s
# 538:	learn: 17804.0807074	total: 11.5s	remaining: 1m 35s
# 539:	learn: 17787.2686630	total: 11.5s	remaining: 1m 35s
# 540:	learn: 17777.6639527	total: 11.6s	remaining: 1m 35s
# 541:	learn: 17740.1390383	total: 11.6s	remaining: 1m 35s
# 542:	learn: 17734.9500578	total: 11.6s	remaining: 1m 35s
# 543:	learn: 17727.4841619	total: 11.7s	remaining: 1m 35s
# 544:	learn: 17683.6443867	total: 11.7s	remaining: 1m 35s
# 545:	learn: 17676.0788331	total: 11.7s	remaining: 1m 35s
# 546:	learn: 17671.2500590	total: 11.7s	remaining: 1m 35s
# 547:	learn: 17655.3554841	total: 11.8s	remaining: 1m 35s
# 548:	learn: 17650.8567423	total: 11.8s	remaining: 1m 35s
# 549:	learn: 17640.0034140	total: 11.8s	remaining: 1m 35s
# 550:	learn: 17626.4110392	total: 11.9s	remaining: 1m 35s
# 551:	learn: 17618.9567995	total: 11.9s	remaining: 1m 35s
# 552:	learn: 17599.3378018	total: 11.9s	remaining: 1m 35s
# 553:	learn: 17545.5326176	total: 12s	remaining: 1m 35s
# 554:	learn: 17540.4514679	total: 12s	remaining: 1m 36s
# 555:	learn: 17525.9463377	total: 12s	remaining: 1m 35s
# 556:	learn: 17521.5475940	total: 12s	remaining: 1m 35s
# 557:	learn: 17516.5685357	total: 12s	remaining: 1m 35s
# 558:	learn: 17502.7288246	total: 12.1s	remaining: 1m 35s
# 559:	learn: 17498.4053173	total: 12.1s	remaining: 1m 35s
# 560:	learn: 17493.8605705	total: 12.1s	remaining: 1m 35s
# 561:	learn: 17486.7026483	total: 12.1s	remaining: 1m 35s
# 562:	learn: 17482.5353721	total: 12.1s	remaining: 1m 35s
# 563:	learn: 17478.0359071	total: 12.1s	remaining: 1m 35s
# 564:	learn: 17424.7869738	total: 12.2s	remaining: 1m 35s
# 565:	learn: 17411.3555653	total: 12.2s	remaining: 1m 35s
# 566:	learn: 17407.1127977	total: 12.2s	remaining: 1m 35s
# 567:	learn: 17402.7534365	total: 12.2s	remaining: 1m 35s
# 568:	learn: 17387.8333578	total: 12.2s	remaining: 1m 35s
# 569:	learn: 17376.5065135	total: 12.3s	remaining: 1m 35s
# 570:	learn: 17362.6474378	total: 12.3s	remaining: 1m 35s
# 571:	learn: 17355.4980168	total: 12.3s	remaining: 1m 35s
# 572:	learn: 17351.0259626	total: 12.3s	remaining: 1m 35s
# 573:	learn: 17340.1085441	total: 12.3s	remaining: 1m 34s
# 574:	learn: 17330.6739446	total: 12.3s	remaining: 1m 34s
# 575:	learn: 17317.1063896	total: 12.3s	remaining: 1m 34s
# 576:	learn: 17294.1704058	total: 12.4s	remaining: 1m 34s
# 577:	learn: 17280.0467755	total: 12.4s	remaining: 1m 34s
# 578:	learn: 17269.1396601	total: 12.4s	remaining: 1m 34s
# 579:	learn: 17265.5118626	total: 12.4s	remaining: 1m 34s
# 580:	learn: 17252.1441787	total: 12.5s	remaining: 1m 34s
# 581:	learn: 17248.2653955	total: 12.5s	remaining: 1m 34s
# 582:	learn: 17237.0828125	total: 12.5s	remaining: 1m 34s
# 583:	learn: 17222.9476242	total: 12.5s	remaining: 1m 34s
# 584:	learn: 17215.7224718	total: 12.6s	remaining: 1m 34s
# 585:	learn: 17192.8977533	total: 12.6s	remaining: 1m 34s
# 586:	learn: 17188.5111655	total: 12.6s	remaining: 1m 34s
# 587:	learn: 17184.0532935	total: 12.6s	remaining: 1m 34s
# 588:	learn: 17179.3201167	total: 12.6s	remaining: 1m 34s
# 589:	learn: 17166.2030922	total: 12.7s	remaining: 1m 34s
# 590:	learn: 17154.6212665	total: 12.7s	remaining: 1m 34s
# 591:	learn: 17145.9122290	total: 12.7s	remaining: 1m 34s
# 592:	learn: 17142.1001971	total: 12.7s	remaining: 1m 34s
# 593:	learn: 17137.6504477	total: 12.7s	remaining: 1m 34s
# 594:	learn: 17133.6191342	total: 12.8s	remaining: 1m 34s
# 595:	learn: 17123.1835747	total: 12.8s	remaining: 1m 34s
# 596:	learn: 17108.1921319	total: 12.8s	remaining: 1m 34s
# 597:	learn: 17096.8603463	total: 12.8s	remaining: 1m 34s
# 598:	learn: 17023.5504598	total: 12.8s	remaining: 1m 34s
# 599:	learn: 17017.4256049	total: 12.8s	remaining: 1m 34s
# 600:	learn: 16968.3786327	total: 12.9s	remaining: 1m 34s
# 601:	learn: 16915.6205323	total: 12.9s	remaining: 1m 34s
# 602:	learn: 16910.6991078	total: 12.9s	remaining: 1m 33s
# 603:	learn: 16906.4669812	total: 12.9s	remaining: 1m 33s
# 604:	learn: 16902.0866029	total: 12.9s	remaining: 1m 33s
# 605:	learn: 16897.4130001	total: 12.9s	remaining: 1m 33s
# 606:	learn: 16892.8706500	total: 13s	remaining: 1m 33s
# 607:	learn: 16888.5345330	total: 13s	remaining: 1m 33s
# 608:	learn: 16884.4915254	total: 13s	remaining: 1m 33s
# 609:	learn: 16880.5156967	total: 13s	remaining: 1m 33s
# 610:	learn: 16859.9891679	total: 13.1s	remaining: 1m 33s
# 611:	learn: 16854.1865453	total: 13.1s	remaining: 1m 33s
# 612:	learn: 16850.3154125	total: 13.1s	remaining: 1m 33s
# 613:	learn: 16844.5714919	total: 13.1s	remaining: 1m 33s
# 614:	learn: 16840.2554605	total: 13.1s	remaining: 1m 33s
# 615:	learn: 16836.2908097	total: 13.2s	remaining: 1m 33s
# 616:	learn: 16811.5252477	total: 13.2s	remaining: 1m 33s
# 617:	learn: 16807.6144354	total: 13.2s	remaining: 1m 33s
# 618:	learn: 16789.9597814	total: 13.2s	remaining: 1m 33s
# 619:	learn: 16777.3163797	total: 13.2s	remaining: 1m 33s
# 620:	learn: 16723.6783243	total: 13.3s	remaining: 1m 33s
# 621:	learn: 16719.9766456	total: 13.3s	remaining: 1m 33s
# 622:	learn: 16715.7390535	total: 13.3s	remaining: 1m 33s
# 623:	learn: 16712.0264582	total: 13.3s	remaining: 1m 33s
# 624:	learn: 16707.9619690	total: 13.3s	remaining: 1m 33s
# 625:	learn: 16703.9772341	total: 13.4s	remaining: 1m 33s
# 626:	learn: 16684.8860736	total: 13.4s	remaining: 1m 33s
# 627:	learn: 16674.0985866	total: 13.4s	remaining: 1m 33s
# 628:	learn: 16670.4434312	total: 13.4s	remaining: 1m 33s
# 629:	learn: 16650.8502207	total: 13.4s	remaining: 1m 33s
# 630:	learn: 16647.1257321	total: 13.4s	remaining: 1m 33s
# 631:	learn: 16643.2469798	total: 13.4s	remaining: 1m 32s
# 632:	learn: 16632.5991540	total: 13.5s	remaining: 1m 32s
# 633:	learn: 16620.4376474	total: 13.5s	remaining: 1m 32s
# 634:	learn: 16616.4987405	total: 13.5s	remaining: 1m 32s
# 635:	learn: 16604.1967717	total: 13.5s	remaining: 1m 32s
# 636:	learn: 16600.8249861	total: 13.6s	remaining: 1m 32s
# 637:	learn: 16588.3124230	total: 13.6s	remaining: 1m 32s
# 638:	learn: 16584.8372345	total: 13.6s	remaining: 1m 32s
# 639:	learn: 16557.9751309	total: 13.6s	remaining: 1m 32s
# 640:	learn: 16551.8895331	total: 13.7s	remaining: 1m 32s
# 641:	learn: 16542.2390997	total: 13.7s	remaining: 1m 32s
# 642:	learn: 16536.3096690	total: 13.7s	remaining: 1m 32s
# 643:	learn: 16530.6979189	total: 13.7s	remaining: 1m 32s
# 644:	learn: 16492.2727056	total: 13.7s	remaining: 1m 32s
# 645:	learn: 16488.2532880	total: 13.7s	remaining: 1m 32s
# 646:	learn: 16477.2013425	total: 13.8s	remaining: 1m 32s
# 647:	learn: 16465.8333334	total: 13.8s	remaining: 1m 32s
# 648:	learn: 16458.1030052	total: 13.8s	remaining: 1m 32s
# 649:	learn: 16446.6263118	total: 13.8s	remaining: 1m 32s
# 650:	learn: 16434.3843131	total: 13.8s	remaining: 1m 32s
# 651:	learn: 16423.6637200	total: 13.9s	remaining: 1m 32s
# 652:	learn: 16417.9110096	total: 13.9s	remaining: 1m 32s
# 653:	learn: 16412.9952120	total: 13.9s	remaining: 1m 32s
# 654:	learn: 16403.8954689	total: 13.9s	remaining: 1m 32s
# 655:	learn: 16382.8958953	total: 13.9s	remaining: 1m 32s
# 656:	learn: 16372.3779871	total: 14s	remaining: 1m 32s
# 657:	learn: 16368.3730873	total: 14s	remaining: 1m 32s
# 658:	learn: 16357.5414371	total: 14s	remaining: 1m 32s
# 659:	learn: 16345.2743487	total: 14s	remaining: 1m 32s
# 660:	learn: 16326.6544898	total: 14s	remaining: 1m 32s
# 661:	learn: 16312.5335682	total: 14.1s	remaining: 1m 32s
# 662:	learn: 16270.4512678	total: 14.1s	remaining: 1m 32s
# 663:	learn: 16261.9883275	total: 14.1s	remaining: 1m 32s
# 664:	learn: 16258.0838131	total: 14.1s	remaining: 1m 31s
# 665:	learn: 16197.4090411	total: 14.1s	remaining: 1m 32s
# 666:	learn: 16185.5641400	total: 14.2s	remaining: 1m 32s
# 667:	learn: 16174.4197489	total: 14.2s	remaining: 1m 32s
# 668:	learn: 16164.8913896	total: 14.2s	remaining: 1m 32s
# 669:	learn: 16160.9845682	total: 14.2s	remaining: 1m 31s
# 670:	learn: 16148.5330702	total: 14.3s	remaining: 1m 31s
# 671:	learn: 16143.3892352	total: 14.3s	remaining: 1m 31s
# 672:	learn: 16136.5080459	total: 14.3s	remaining: 1m 31s
# 673:	learn: 16112.0385549	total: 14.3s	remaining: 1m 31s
# 674:	learn: 16108.2561297	total: 14.3s	remaining: 1m 31s
# 675:	learn: 16063.4838908	total: 14.3s	remaining: 1m 31s
# 676:	learn: 16053.0342448	total: 14.4s	remaining: 1m 31s
# 677:	learn: 16043.7695744	total: 14.4s	remaining: 1m 31s
# 678:	learn: 16033.9288251	total: 14.4s	remaining: 1m 31s
# 679:	learn: 16020.8456299	total: 14.4s	remaining: 1m 31s
# 680:	learn: 16013.1278926	total: 14.4s	remaining: 1m 31s
# 681:	learn: 15995.4601924	total: 14.5s	remaining: 1m 31s
# 682:	learn: 15991.7551690	total: 14.5s	remaining: 1m 31s
# 683:	learn: 15979.2621985	total: 14.5s	remaining: 1m 31s
# 684:	learn: 15971.1309816	total: 14.5s	remaining: 1m 31s
# 685:	learn: 15963.8681579	total: 14.5s	remaining: 1m 31s
# 686:	learn: 15954.0541594	total: 14.5s	remaining: 1m 31s
# 687:	learn: 15937.8874597	total: 14.6s	remaining: 1m 31s
# 688:	learn: 15934.2951011	total: 14.6s	remaining: 1m 31s
# 689:	learn: 15926.0002055	total: 14.6s	remaining: 1m 31s
# 690:	learn: 15915.7695266	total: 14.6s	remaining: 1m 31s
# 691:	learn: 15908.8006391	total: 14.6s	remaining: 1m 31s
# 692:	learn: 15903.0110316	total: 14.7s	remaining: 1m 31s
# 693:	learn: 15899.5010732	total: 14.7s	remaining: 1m 31s
# 694:	learn: 15896.0174571	total: 14.7s	remaining: 1m 31s
# 695:	learn: 15883.4387420	total: 14.7s	remaining: 1m 31s
# 696:	learn: 15872.8671547	total: 14.8s	remaining: 1m 31s
# 697:	learn: 15863.0584042	total: 14.8s	remaining: 1m 31s
# 698:	learn: 15855.9462910	total: 14.8s	remaining: 1m 31s
# 699:	learn: 15847.6918953	total: 14.8s	remaining: 1m 31s
# 700:	learn: 15819.9653374	total: 14.8s	remaining: 1m 31s
# 701:	learn: 15810.8836359	total: 14.9s	remaining: 1m 30s
# 702:	learn: 15801.8708884	total: 14.9s	remaining: 1m 30s
# 703:	learn: 15798.0092112	total: 14.9s	remaining: 1m 30s
# 704:	learn: 15792.6093951	total: 14.9s	remaining: 1m 30s
# 705:	learn: 15760.7311288	total: 14.9s	remaining: 1m 30s
# 706:	learn: 15757.0428265	total: 15s	remaining: 1m 30s
# 707:	learn: 15749.3206199	total: 15s	remaining: 1m 30s
# 708:	learn: 15745.8085286	total: 15s	remaining: 1m 30s
# 709:	learn: 15742.3931277	total: 15s	remaining: 1m 30s
# 710:	learn: 15739.0167737	total: 15.1s	remaining: 1m 30s
# 711:	learn: 15733.9186234	total: 15.1s	remaining: 1m 30s
# 712:	learn: 15724.7654217	total: 15.1s	remaining: 1m 30s
# 713:	learn: 15721.4241836	total: 15.1s	remaining: 1m 30s
# 714:	learn: 15713.8807942	total: 15.1s	remaining: 1m 30s
# 715:	learn: 15710.3237099	total: 15.1s	remaining: 1m 30s
# 716:	learn: 15701.8243574	total: 15.2s	remaining: 1m 30s
# 717:	learn: 15698.2426098	total: 15.2s	remaining: 1m 30s
# 718:	learn: 15694.8408518	total: 15.2s	remaining: 1m 30s
# 719:	learn: 15682.8362577	total: 15.2s	remaining: 1m 30s
# 720:	learn: 15674.1696106	total: 15.2s	remaining: 1m 30s
# 721:	learn: 15666.6219386	total: 15.3s	remaining: 1m 30s
# 722:	learn: 15657.9477358	total: 15.3s	remaining: 1m 30s
# 723:	learn: 15626.9763554	total: 15.3s	remaining: 1m 30s
# 724:	learn: 15619.1529153	total: 15.3s	remaining: 1m 30s
# 725:	learn: 15576.0077164	total: 15.3s	remaining: 1m 30s
# 726:	learn: 15572.9833939	total: 15.4s	remaining: 1m 30s
# 727:	learn: 15569.6121356	total: 15.4s	remaining: 1m 30s
# 728:	learn: 15564.0361804	total: 15.4s	remaining: 1m 30s
# 729:	learn: 15515.5396235	total: 15.4s	remaining: 1m 30s
# 730:	learn: 15504.6346399	total: 15.4s	remaining: 1m 30s
# 731:	learn: 15494.9786170	total: 15.5s	remaining: 1m 30s
# 732:	learn: 15434.6198851	total: 15.5s	remaining: 1m 30s
# 733:	learn: 15427.4917846	total: 15.5s	remaining: 1m 30s
# 734:	learn: 15423.7686657	total: 15.5s	remaining: 1m 30s
# 735:	learn: 15415.1563449	total: 15.5s	remaining: 1m 30s
# 736:	learn: 15408.7385584	total: 15.6s	remaining: 1m 30s
# 737:	learn: 15402.9702107	total: 15.6s	remaining: 1m 30s
# 738:	learn: 15399.4959031	total: 15.6s	remaining: 1m 29s
# 739:	learn: 15391.0413320	total: 15.6s	remaining: 1m 29s
# 740:	learn: 15341.6114372	total: 15.6s	remaining: 1m 29s
# 741:	learn: 15338.0341268	total: 15.7s	remaining: 1m 29s
# 742:	learn: 15327.8657766	total: 15.7s	remaining: 1m 29s
# 743:	learn: 15320.0639739	total: 15.7s	remaining: 1m 29s
# 744:	learn: 15313.4193466	total: 15.7s	remaining: 1m 29s
# 745:	learn: 15309.9815000	total: 15.7s	remaining: 1m 29s
# 746:	learn: 15296.2125266	total: 15.7s	remaining: 1m 29s
# 747:	learn: 15292.8833937	total: 15.8s	remaining: 1m 29s
# 748:	learn: 15282.7857832	total: 15.8s	remaining: 1m 29s
# 749:	learn: 15277.2094157	total: 15.8s	remaining: 1m 29s
# 750:	learn: 15268.9424907	total: 15.8s	remaining: 1m 29s
# 751:	learn: 15265.3933643	total: 15.8s	remaining: 1m 29s
# 752:	learn: 15259.9171697	total: 15.9s	remaining: 1m 29s
# 753:	learn: 15255.0562597	total: 15.9s	remaining: 1m 29s
# 754:	learn: 15195.6035320	total: 15.9s	remaining: 1m 29s
# 755:	learn: 15168.2435145	total: 15.9s	remaining: 1m 29s
# 756:	learn: 15164.4629884	total: 16s	remaining: 1m 29s
# 757:	learn: 15153.2585450	total: 16s	remaining: 1m 29s
# 758:	learn: 15093.8261878	total: 16s	remaining: 1m 29s
# 759:	learn: 15071.8199846	total: 16s	remaining: 1m 29s
# 760:	learn: 15068.3903254	total: 16s	remaining: 1m 29s
# 761:	learn: 15062.9109726	total: 16.1s	remaining: 1m 29s
# 762:	learn: 15055.3859337	total: 16.1s	remaining: 1m 29s
# 763:	learn: 15050.6917778	total: 16.1s	remaining: 1m 29s
# 764:	learn: 15040.2159094	total: 16.1s	remaining: 1m 29s
# 765:	learn: 15036.6061737	total: 16.1s	remaining: 1m 29s
# 766:	learn: 15033.3091405	total: 16.2s	remaining: 1m 29s
# 767:	learn: 15025.9504498	total: 16.2s	remaining: 1m 29s
# 768:	learn: 15022.6265664	total: 16.2s	remaining: 1m 29s
# 769:	learn: 15019.2866177	total: 16.2s	remaining: 1m 29s
# 770:	learn: 15016.0637799	total: 16.2s	remaining: 1m 28s
# 771:	learn: 15009.6064137	total: 16.2s	remaining: 1m 28s
# 772:	learn: 15002.6148661	total: 16.3s	remaining: 1m 28s
# 773:	learn: 14950.8939818	total: 16.3s	remaining: 1m 28s
# 774:	learn: 14947.7336463	total: 16.3s	remaining: 1m 28s
# 775:	learn: 14939.6825004	total: 16.3s	remaining: 1m 28s
# 776:	learn: 14936.4904582	total: 16.3s	remaining: 1m 28s
# 777:	learn: 14921.3966282	total: 16.4s	remaining: 1m 28s
# 778:	learn: 14916.4871668	total: 16.4s	remaining: 1m 28s
# 779:	learn: 14907.1982603	total: 16.4s	remaining: 1m 28s
# 780:	learn: 14894.9426892	total: 16.4s	remaining: 1m 28s
# 781:	learn: 14857.3026644	total: 16.4s	remaining: 1m 28s
# 782:	learn: 14817.8320146	total: 16.5s	remaining: 1m 28s
# 783:	learn: 14811.1869685	total: 16.5s	remaining: 1m 28s
# 784:	learn: 14807.9962868	total: 16.5s	remaining: 1m 28s
# 785:	learn: 14802.0077899	total: 16.5s	remaining: 1m 28s
# 786:	learn: 14798.7725723	total: 16.6s	remaining: 1m 28s
# 787:	learn: 14792.6168213	total: 16.6s	remaining: 1m 28s
# 788:	learn: 14781.0512208	total: 16.6s	remaining: 1m 28s
# 789:	learn: 14777.9709923	total: 16.6s	remaining: 1m 28s
# 790:	learn: 14774.7762987	total: 16.6s	remaining: 1m 28s
# 791:	learn: 14768.2640008	total: 16.7s	remaining: 1m 28s
# 792:	learn: 14762.5868482	total: 16.7s	remaining: 1m 28s
# 793:	learn: 14754.0805040	total: 16.7s	remaining: 1m 28s
# 794:	learn: 14745.1275442	total: 16.7s	remaining: 1m 28s
# 795:	learn: 14742.1783828	total: 16.7s	remaining: 1m 28s
# 796:	learn: 14738.9253165	total: 16.8s	remaining: 1m 28s
# 797:	learn: 14733.9834196	total: 16.8s	remaining: 1m 28s
# 798:	learn: 14724.4562968	total: 16.8s	remaining: 1m 28s
# 799:	learn: 14721.6711613	total: 16.8s	remaining: 1m 28s
# 800:	learn: 14710.3650303	total: 16.8s	remaining: 1m 28s
# 801:	learn: 14707.1498969	total: 16.8s	remaining: 1m 28s
# 802:	learn: 14667.4720952	total: 16.9s	remaining: 1m 28s
# 803:	learn: 14664.2999281	total: 16.9s	remaining: 1m 28s
# 804:	learn: 14655.6673899	total: 16.9s	remaining: 1m 28s
# 805:	learn: 14652.3323287	total: 16.9s	remaining: 1m 28s
# 806:	learn: 14642.6295292	total: 16.9s	remaining: 1m 27s
# 807:	learn: 14637.4863533	total: 17s	remaining: 1m 28s
# 808:	learn: 14634.2700019	total: 17s	remaining: 1m 28s
# 809:	learn: 14624.4207077	total: 17s	remaining: 1m 28s
# 810:	learn: 14585.2682336	total: 17s	remaining: 1m 28s
# 811:	learn: 14546.4524854	total: 17.1s	remaining: 1m 28s
# 812:	learn: 14539.5426772	total: 17.1s	remaining: 1m 28s
# 813:	learn: 14526.3027063	total: 17.1s	remaining: 1m 28s
# 814:	learn: 14523.1813599	total: 17.1s	remaining: 1m 27s
# 815:	learn: 14516.9986105	total: 17.1s	remaining: 1m 27s
# 816:	learn: 14514.0500555	total: 17.2s	remaining: 1m 27s
# 817:	learn: 14511.1905344	total: 17.2s	remaining: 1m 27s
# 818:	learn: 14506.4847675	total: 17.2s	remaining: 1m 27s
# 819:	learn: 14494.4293695	total: 17.2s	remaining: 1m 27s
# 820:	learn: 14488.9414159	total: 17.2s	remaining: 1m 27s
# 821:	learn: 14480.6610253	total: 17.3s	remaining: 1m 27s
# 822:	learn: 14473.0521436	total: 17.3s	remaining: 1m 27s
# 823:	learn: 14448.4173464	total: 17.3s	remaining: 1m 27s
# 824:	learn: 14445.2523354	total: 17.3s	remaining: 1m 27s
# 825:	learn: 14442.4780169	total: 17.3s	remaining: 1m 27s
# 826:	learn: 14422.5491337	total: 17.3s	remaining: 1m 27s
# 827:	learn: 14409.6205041	total: 17.4s	remaining: 1m 27s
# 828:	learn: 14398.9632058	total: 17.4s	remaining: 1m 27s
# 829:	learn: 14396.4139358	total: 17.4s	remaining: 1m 27s
# 830:	learn: 14366.0411901	total: 17.4s	remaining: 1m 27s
# 831:	learn: 14363.1848799	total: 17.4s	remaining: 1m 27s
# 832:	learn: 14356.1576466	total: 17.5s	remaining: 1m 27s
# 833:	learn: 14343.8589011	total: 17.5s	remaining: 1m 27s
# 834:	learn: 14335.9411650	total: 17.5s	remaining: 1m 27s
# 835:	learn: 14297.2852351	total: 17.5s	remaining: 1m 27s
# 836:	learn: 14292.5913181	total: 17.6s	remaining: 1m 27s
# 837:	learn: 14289.4766937	total: 17.6s	remaining: 1m 27s
# 838:	learn: 14283.0295111	total: 17.6s	remaining: 1m 27s
# 839:	learn: 14279.9353880	total: 17.7s	remaining: 1m 27s
# ...
# 4721:	learn: 4162.4180795	total: 1m 30s	remaining: 5.34s
# 4722:	learn: 4162.2448759	total: 1m 30s	remaining: 5.33s
# 4723:	learn: 4162.0725596	total: 1m 30s	remaining: 5.31s
# 4724:	learn: 4161.8403974	total: 1m 30s	remaining: 5.29s
# 4725:	learn: 4161.5511275	total: 1m 30s	remaining: 5.27s
# 4726:	learn: 4161.3510700	total: 1m 30s	remaining: 5.25s
# 4727:	learn: 4160.1754984	total: 1m 30s	remaining: 5.23s
# 4728:	learn: 4159.9725221	total: 1m 30s	remaining: 5.21s
# 4729:	learn: 4159.1173770	total: 1m 30s	remaining: 5.19s
# 4730:	learn: 4158.8885066	total: 1m 30s	remaining: 5.17s
# 4731:	learn: 4158.4312556	total: 1m 30s	remaining: 5.15s
# 4732:	learn: 4158.2148188	total: 1m 30s	remaining: 5.13s
# 4733:	learn: 4158.0805679	total: 1m 30s	remaining: 5.11s
# 4734:	learn: 4156.2363510	total: 1m 31s	remaining: 5.09s
# 4735:	learn: 4156.0195707	total: 1m 31s	remaining: 5.07s
# 4736:	learn: 4155.1185436	total: 1m 31s	remaining: 5.05s
# 4737:	learn: 4154.8671098	total: 1m 31s	remaining: 5.03s
# 4738:	learn: 4154.6310958	total: 1m 31s	remaining: 5.01s
# 4739:	learn: 4154.4531100	total: 1m 31s	remaining: 5s
# 4740:	learn: 4154.1066516	total: 1m 31s	remaining: 4.98s
# 4741:	learn: 4153.8730461	total: 1m 31s	remaining: 4.96s
# 4742:	learn: 4153.6635157	total: 1m 31s	remaining: 4.94s
# 4743:	learn: 4153.4555760	total: 1m 31s	remaining: 4.92s
# 4744:	learn: 4153.1210468	total: 1m 31s	remaining: 4.9s
# 4745:	learn: 4151.9984125	total: 1m 31s	remaining: 4.88s
# 4746:	learn: 4151.8200340	total: 1m 31s	remaining: 4.86s
# 4747:	learn: 4151.6206002	total: 1m 31s	remaining: 4.84s
# 4748:	learn: 4144.6338758	total: 1m 31s	remaining: 4.82s
# 4749:	learn: 4144.4133894	total: 1m 31s	remaining: 4.8s
# 4750:	learn: 4144.1558122	total: 1m 31s	remaining: 4.78s
# 4751:	learn: 4144.0012008	total: 1m 31s	remaining: 4.76s
# 4752:	learn: 4143.8417146	total: 1m 31s	remaining: 4.74s
# 4753:	learn: 4143.6344388	total: 1m 31s	remaining: 4.72s
# 4754:	learn: 4142.7884654	total: 1m 31s	remaining: 4.71s
# 4755:	learn: 4142.3649537	total: 1m 31s	remaining: 4.69s
# 4756:	learn: 4142.1131199	total: 1m 31s	remaining: 4.67s
# 4757:	learn: 4140.2464111	total: 1m 31s	remaining: 4.65s
# 4758:	learn: 4139.3379721	total: 1m 31s	remaining: 4.63s
# 4759:	learn: 4139.2038604	total: 1m 31s	remaining: 4.61s
# 4760:	learn: 4138.9599643	total: 1m 31s	remaining: 4.59s
# 4761:	learn: 4138.7654390	total: 1m 31s	remaining: 4.57s
# 4762:	learn: 4138.6483079	total: 1m 31s	remaining: 4.55s
# 4763:	learn: 4137.6588439	total: 1m 31s	remaining: 4.53s
# 4764:	learn: 4137.4316256	total: 1m 31s	remaining: 4.51s
# 4765:	learn: 4137.1132577	total: 1m 31s	remaining: 4.49s
# 4766:	learn: 4136.3217386	total: 1m 31s	remaining: 4.47s
# 4767:	learn: 4136.0414628	total: 1m 31s	remaining: 4.46s
# 4768:	learn: 4130.1685045	total: 1m 31s	remaining: 4.43s
# 4769:	learn: 4129.6126606	total: 1m 31s	remaining: 4.42s
# 4770:	learn: 4129.3470994	total: 1m 31s	remaining: 4.4s
# 4771:	learn: 4128.6941913	total: 1m 31s	remaining: 4.38s
# 4772:	learn: 4119.4564749	total: 1m 31s	remaining: 4.36s
# 4773:	learn: 4119.2049285	total: 1m 31s	remaining: 4.34s
# 4774:	learn: 4118.4272347	total: 1m 31s	remaining: 4.32s
# 4775:	learn: 4118.2487983	total: 1m 31s	remaining: 4.3s
# 4776:	learn: 4117.9497853	total: 1m 31s	remaining: 4.28s
# 4777:	learn: 4117.1240575	total: 1m 31s	remaining: 4.26s
# 4778:	learn: 4116.8834550	total: 1m 31s	remaining: 4.24s
# 4779:	learn: 4115.7379168	total: 1m 31s	remaining: 4.22s
# 4780:	learn: 4114.4675050	total: 1m 31s	remaining: 4.2s
# 4781:	learn: 4108.6032800	total: 1m 31s	remaining: 4.18s
# 4782:	learn: 4108.3481275	total: 1m 31s	remaining: 4.17s
# 4783:	learn: 4107.6040277	total: 1m 31s	remaining: 4.14s
# 4784:	learn: 4107.4507545	total: 1m 31s	remaining: 4.13s
# 4785:	learn: 4107.1470288	total: 1m 31s	remaining: 4.11s
# 4786:	learn: 4106.7725163	total: 1m 31s	remaining: 4.09s
# 4787:	learn: 4106.5950500	total: 1m 31s	remaining: 4.07s
# 4788:	learn: 4105.9217708	total: 1m 31s	remaining: 4.05s
# 4789:	learn: 4105.3251001	total: 1m 31s	remaining: 4.03s
# 4790:	learn: 4105.1269610	total: 1m 31s	remaining: 4.01s
# 4791:	learn: 4104.9613879	total: 1m 31s	remaining: 3.99s
# 4792:	learn: 4104.7693048	total: 1m 31s	remaining: 3.97s
# 4793:	learn: 4104.4044158	total: 1m 31s	remaining: 3.95s
# 4794:	learn: 4104.1423005	total: 1m 32s	remaining: 3.93s
# 4795:	learn: 4103.6501207	total: 1m 32s	remaining: 3.91s
# 4796:	learn: 4103.4186298	total: 1m 32s	remaining: 3.9s
# 4797:	learn: 4103.2067234	total: 1m 32s	remaining: 3.88s
# 4798:	learn: 4102.5705568	total: 1m 32s	remaining: 3.86s
# 4799:	learn: 4102.5106037	total: 1m 32s	remaining: 3.84s
# 4800:	learn: 4102.3282058	total: 1m 32s	remaining: 3.82s
# 4801:	learn: 4102.1782126	total: 1m 32s	remaining: 3.8s
# 4802:	learn: 4101.9855895	total: 1m 32s	remaining: 3.78s
# 4803:	learn: 4101.8509546	total: 1m 32s	remaining: 3.76s
# 4804:	learn: 4101.6859152	total: 1m 32s	remaining: 3.74s
# 4805:	learn: 4101.4710339	total: 1m 32s	remaining: 3.72s
# 4806:	learn: 4101.2321392	total: 1m 32s	remaining: 3.7s
# 4807:	learn: 4101.0335896	total: 1m 32s	remaining: 3.68s
# 4808:	learn: 4100.8673173	total: 1m 32s	remaining: 3.66s
# 4809:	learn: 4100.7014783	total: 1m 32s	remaining: 3.64s
# 4810:	learn: 4100.5328156	total: 1m 32s	remaining: 3.63s
# 4811:	learn: 4098.8204008	total: 1m 32s	remaining: 3.6s
# 4812:	learn: 4098.6160586	total: 1m 32s	remaining: 3.59s
# 4813:	learn: 4098.4472515	total: 1m 32s	remaining: 3.57s
# 4814:	learn: 4097.7331230	total: 1m 32s	remaining: 3.55s
# 4815:	learn: 4097.5810608	total: 1m 32s	remaining: 3.53s
# 4816:	learn: 4097.2629758	total: 1m 32s	remaining: 3.51s
# 4817:	learn: 4092.5119747	total: 1m 32s	remaining: 3.49s
# 4818:	learn: 4092.0598068	total: 1m 32s	remaining: 3.47s
# 4819:	learn: 4091.8122863	total: 1m 32s	remaining: 3.45s
# 4820:	learn: 4090.5693841	total: 1m 32s	remaining: 3.43s
# 4821:	learn: 4085.4745131	total: 1m 32s	remaining: 3.41s
# 4822:	learn: 4085.2040837	total: 1m 32s	remaining: 3.39s
# 4823:	learn: 4084.9668125	total: 1m 32s	remaining: 3.37s
# 4824:	learn: 4084.0551989	total: 1m 32s	remaining: 3.35s
# 4825:	learn: 4083.8593520	total: 1m 32s	remaining: 3.34s
# 4826:	learn: 4082.5411958	total: 1m 32s	remaining: 3.32s
# 4827:	learn: 4082.0159481	total: 1m 32s	remaining: 3.3s
# 4828:	learn: 4081.5171186	total: 1m 32s	remaining: 3.28s
# 4829:	learn: 4081.3438969	total: 1m 32s	remaining: 3.26s
# 4830:	learn: 4081.1532865	total: 1m 32s	remaining: 3.24s
# 4831:	learn: 4080.2074438	total: 1m 32s	remaining: 3.22s
# 4832:	learn: 4080.0212042	total: 1m 32s	remaining: 3.2s
# 4833:	learn: 4076.2268368	total: 1m 32s	remaining: 3.18s
# 4834:	learn: 4074.5585867	total: 1m 32s	remaining: 3.16s
# 4835:	learn: 4074.3224640	total: 1m 32s	remaining: 3.14s
# 4836:	learn: 4066.9130064	total: 1m 32s	remaining: 3.12s
# 4837:	learn: 4066.7287491	total: 1m 32s	remaining: 3.1s
# 4838:	learn: 4066.4477614	total: 1m 32s	remaining: 3.08s
# 4839:	learn: 4065.1482811	total: 1m 32s	remaining: 3.07s
# 4840:	learn: 4064.8940986	total: 1m 32s	remaining: 3.05s
# 4841:	learn: 4064.6899509	total: 1m 32s	remaining: 3.03s
# 4842:	learn: 4064.4265211	total: 1m 32s	remaining: 3.01s
# 4843:	learn: 4064.2333002	total: 1m 32s	remaining: 2.99s
# 4844:	learn: 4064.0460207	total: 1m 32s	remaining: 2.97s
# 4845:	learn: 4063.6950852	total: 1m 32s	remaining: 2.95s
# 4846:	learn: 4063.5165843	total: 1m 32s	remaining: 2.93s
# 4847:	learn: 4063.2660439	total: 1m 32s	remaining: 2.91s
# 4848:	learn: 4063.0383761	total: 1m 32s	remaining: 2.89s
# 4849:	learn: 4061.7581977	total: 1m 32s	remaining: 2.87s
# 4850:	learn: 4061.2996563	total: 1m 32s	remaining: 2.85s
# 4851:	learn: 4055.7335097	total: 1m 32s	remaining: 2.83s
# 4852:	learn: 4055.4873038	total: 1m 32s	remaining: 2.82s
# 4853:	learn: 4049.3763855	total: 1m 32s	remaining: 2.8s
# 4854:	learn: 4041.1313303	total: 1m 33s	remaining: 2.78s
# 4855:	learn: 4040.8722232	total: 1m 33s	remaining: 2.76s
# 4856:	learn: 4040.6631804	total: 1m 33s	remaining: 2.74s
# 4857:	learn: 4039.6085324	total: 1m 33s	remaining: 2.72s
# 4858:	learn: 4039.3701798	total: 1m 33s	remaining: 2.7s
# 4859:	learn: 4039.1547602	total: 1m 33s	remaining: 2.68s
# 4860:	learn: 4038.9240971	total: 1m 33s	remaining: 2.66s
# 4861:	learn: 4038.7165012	total: 1m 33s	remaining: 2.64s
# 4862:	learn: 4038.5710299	total: 1m 33s	remaining: 2.62s
# 4863:	learn: 4037.5909435	total: 1m 33s	remaining: 2.6s
# 4864:	learn: 4036.6893855	total: 1m 33s	remaining: 2.59s
# 4865:	learn: 4036.0358053	total: 1m 33s	remaining: 2.57s
# 4866:	learn: 4035.9233568	total: 1m 33s	remaining: 2.55s
# 4867:	learn: 4035.7375802	total: 1m 33s	remaining: 2.53s
# 4868:	learn: 4029.5362503	total: 1m 33s	remaining: 2.51s
# 4869:	learn: 4029.3688620	total: 1m 33s	remaining: 2.49s
# 4870:	learn: 4029.1242430	total: 1m 33s	remaining: 2.47s
# 4871:	learn: 4028.5234391	total: 1m 33s	remaining: 2.45s
# 4872:	learn: 4027.8403520	total: 1m 33s	remaining: 2.43s
# 4873:	learn: 4026.9533422	total: 1m 33s	remaining: 2.41s
# 4874:	learn: 4023.7035986	total: 1m 33s	remaining: 2.39s
# 4875:	learn: 4023.0431749	total: 1m 33s	remaining: 2.37s
# 4876:	learn: 4022.7971530	total: 1m 33s	remaining: 2.35s
# 4877:	learn: 4022.5957740	total: 1m 33s	remaining: 2.34s
# 4878:	learn: 4020.4849463	total: 1m 33s	remaining: 2.32s
# 4879:	learn: 4020.2660615	total: 1m 33s	remaining: 2.3s
# 4880:	learn: 4020.0493595	total: 1m 33s	remaining: 2.28s
# 4881:	learn: 4019.9316550	total: 1m 33s	remaining: 2.26s
# 4882:	learn: 4019.6736661	total: 1m 33s	remaining: 2.24s
# 4883:	learn: 4018.5473798	total: 1m 33s	remaining: 2.22s
# 4884:	learn: 4018.0197030	total: 1m 33s	remaining: 2.2s
# 4885:	learn: 4011.6840896	total: 1m 33s	remaining: 2.18s
# 4886:	learn: 4010.8142641	total: 1m 33s	remaining: 2.16s
# 4887:	learn: 4010.5098931	total: 1m 33s	remaining: 2.14s
# 4888:	learn: 4009.7858994	total: 1m 33s	remaining: 2.13s
# 4889:	learn: 4009.5615165	total: 1m 33s	remaining: 2.11s
# 4890:	learn: 4009.3260932	total: 1m 33s	remaining: 2.09s
# 4891:	learn: 4009.0874252	total: 1m 33s	remaining: 2.07s
# 4892:	learn: 4008.8500141	total: 1m 33s	remaining: 2.05s
# 4893:	learn: 4008.7279276	total: 1m 33s	remaining: 2.03s
# 4894:	learn: 4007.8208282	total: 1m 33s	remaining: 2.01s
# 4895:	learn: 4007.5648466	total: 1m 33s	remaining: 1.99s
# 4896:	learn: 4007.2507432	total: 1m 33s	remaining: 1.97s
# 4897:	learn: 4005.4384977	total: 1m 33s	remaining: 1.95s
# 4898:	learn: 4004.9497275	total: 1m 33s	remaining: 1.93s
# 4899:	learn: 4004.7758332	total: 1m 33s	remaining: 1.91s
# 4900:	learn: 4004.0756730	total: 1m 33s	remaining: 1.89s
# 4901:	learn: 4003.8995890	total: 1m 33s	remaining: 1.88s
# 4902:	learn: 4003.7247932	total: 1m 33s	remaining: 1.86s
# 4903:	learn: 4003.5451716	total: 1m 33s	remaining: 1.84s
# 4904:	learn: 4002.8479739	total: 1m 33s	remaining: 1.82s
# 4905:	learn: 4002.6525463	total: 1m 33s	remaining: 1.8s
# 4906:	learn: 4001.8374459	total: 1m 33s	remaining: 1.78s
# 4907:	learn: 4000.9444741	total: 1m 33s	remaining: 1.76s
# 4908:	learn: 4000.7487638	total: 1m 33s	remaining: 1.74s
# 4909:	learn: 4000.6201875	total: 1m 33s	remaining: 1.72s
# 4910:	learn: 3999.6443004	total: 1m 33s	remaining: 1.7s
# 4911:	learn: 3999.3803381	total: 1m 33s	remaining: 1.68s
# 4912:	learn: 3998.3267579	total: 1m 33s	remaining: 1.66s
# 4913:	learn: 3991.6431837	total: 1m 34s	remaining: 1.65s
# 4914:	learn: 3991.4665064	total: 1m 34s	remaining: 1.63s
# 4915:	learn: 3990.9060796	total: 1m 34s	remaining: 1.61s
# 4916:	learn: 3985.2497214	total: 1m 34s	remaining: 1.59s
# 4917:	learn: 3985.0348276	total: 1m 34s	remaining: 1.57s
# 4918:	learn: 3984.0045400	total: 1m 34s	remaining: 1.55s
# 4919:	learn: 3983.7694868	total: 1m 34s	remaining: 1.53s
# 4920:	learn: 3982.6756001	total: 1m 34s	remaining: 1.51s
# 4921:	learn: 3974.9956841	total: 1m 34s	remaining: 1.49s
# 4922:	learn: 3974.7849703	total: 1m 34s	remaining: 1.47s
# 4923:	learn: 3974.1643285	total: 1m 34s	remaining: 1.45s
# 4924:	learn: 3973.9558959	total: 1m 34s	remaining: 1.43s
# 4925:	learn: 3969.8978454	total: 1m 34s	remaining: 1.42s
# 4926:	learn: 3969.6763744	total: 1m 34s	remaining: 1.4s
# 4927:	learn: 3969.4515294	total: 1m 34s	remaining: 1.38s
# 4928:	learn: 3968.6766985	total: 1m 34s	remaining: 1.36s
# 4929:	learn: 3967.9385401	total: 1m 34s	remaining: 1.34s
# 4930:	learn: 3967.8522647	total: 1m 34s	remaining: 1.32s
# 4931:	learn: 3967.7012587	total: 1m 34s	remaining: 1.3s
# 4932:	learn: 3967.0196937	total: 1m 34s	remaining: 1.28s
# 4933:	learn: 3966.8253004	total: 1m 34s	remaining: 1.26s
# 4934:	learn: 3966.2690762	total: 1m 34s	remaining: 1.24s
# 4935:	learn: 3965.3916825	total: 1m 34s	remaining: 1.22s
# 4936:	learn: 3965.1595394	total: 1m 34s	remaining: 1.2s
# 4937:	learn: 3965.0516053	total: 1m 34s	remaining: 1.19s
# 4938:	learn: 3964.7761571	total: 1m 34s	remaining: 1.17s
# 4939:	learn: 3964.5996109	total: 1m 34s	remaining: 1.15s
# 4940:	learn: 3964.4470343	total: 1m 34s	remaining: 1.13s
# 4941:	learn: 3964.2455932	total: 1m 34s	remaining: 1.11s
# 4942:	learn: 3963.0943695	total: 1m 34s	remaining: 1.09s
# 4943:	learn: 3962.9377267	total: 1m 34s	remaining: 1.07s
# 4944:	learn: 3962.7590077	total: 1m 34s	remaining: 1.05s
# 4945:	learn: 3962.6562295	total: 1m 34s	remaining: 1.03s
# 4946:	learn: 3962.5302737	total: 1m 34s	remaining: 1.01s
# 4947:	learn: 3962.3300816	total: 1m 34s	remaining: 994ms
# 4948:	learn: 3961.6057099	total: 1m 34s	remaining: 975ms
# 4949:	learn: 3961.4508640	total: 1m 34s	remaining: 956ms
# 4950:	learn: 3954.6493040	total: 1m 34s	remaining: 936ms
# 4951:	learn: 3954.4673347	total: 1m 34s	remaining: 917ms
# 4952:	learn: 3954.1448636	total: 1m 34s	remaining: 898ms
# 4953:	learn: 3953.9177994	total: 1m 34s	remaining: 879ms
# 4954:	learn: 3952.9168946	total: 1m 34s	remaining: 860ms
# 4955:	learn: 3952.4849317	total: 1m 34s	remaining: 841ms
# 4956:	learn: 3952.2380813	total: 1m 34s	remaining: 822ms
# 4957:	learn: 3951.7075574	total: 1m 34s	remaining: 802ms
# 4958:	learn: 3951.5712065	total: 1m 34s	remaining: 783ms
# 4959:	learn: 3951.3497102	total: 1m 34s	remaining: 764ms
# 4960:	learn: 3950.2545024	total: 1m 34s	remaining: 745ms
# 4961:	learn: 3950.0228874	total: 1m 34s	remaining: 726ms
# 4962:	learn: 3949.1837971	total: 1m 34s	remaining: 707ms
# 4963:	learn: 3942.6352981	total: 1m 34s	remaining: 688ms
# 4964:	learn: 3941.3932045	total: 1m 34s	remaining: 669ms
# 4965:	learn: 3940.7113534	total: 1m 34s	remaining: 649ms
# 4966:	learn: 3940.5252203	total: 1m 34s	remaining: 630ms
# 4967:	learn: 3940.1555792	total: 1m 34s	remaining: 611ms
# 4968:	learn: 3939.9916984	total: 1m 34s	remaining: 592ms
# 4969:	learn: 3939.8135239	total: 1m 34s	remaining: 573ms
# 4970:	learn: 3938.9107253	total: 1m 34s	remaining: 554ms
# 4971:	learn: 3937.8554924	total: 1m 34s	remaining: 535ms
# 4972:	learn: 3937.6281320	total: 1m 34s	remaining: 516ms
# 4973:	learn: 3937.5209460	total: 1m 34s	remaining: 497ms
# 4974:	learn: 3937.0961083	total: 1m 35s	remaining: 477ms
# 4975:	learn: 3936.8853378	total: 1m 35s	remaining: 458ms
# 4976:	learn: 3936.7762044	total: 1m 35s	remaining: 439ms
# 4977:	learn: 3936.5894180	total: 1m 35s	remaining: 420ms
# 4978:	learn: 3935.4649241	total: 1m 35s	remaining: 401ms
# 4979:	learn: 3934.9124656	total: 1m 35s	remaining: 382ms
# 4980:	learn: 3934.4420395	total: 1m 35s	remaining: 363ms
# 4981:	learn: 3934.0903869	total: 1m 35s	remaining: 344ms
# 4982:	learn: 3932.4347393	total: 1m 35s	remaining: 325ms
# 4983:	learn: 3932.2191372	total: 1m 35s	remaining: 305ms
# 4984:	learn: 3932.0575708	total: 1m 35s	remaining: 286ms
# 4985:	learn: 3931.1979314	total: 1m 35s	remaining: 267ms
# 4986:	learn: 3930.5054048	total: 1m 35s	remaining: 248ms
# 4987:	learn: 3929.3533073	total: 1m 35s	remaining: 229ms
# 4988:	learn: 3928.1849685	total: 1m 35s	remaining: 210ms
# 4989:	learn: 3927.6134289	total: 1m 35s	remaining: 191ms
# 4990:	learn: 3927.4135302	total: 1m 35s	remaining: 172ms
# 4991:	learn: 3927.1597812	total: 1m 35s	remaining: 153ms
# 4992:	learn: 3926.0409099	total: 1m 35s	remaining: 134ms
# 4993:	learn: 3925.8720688	total: 1m 35s	remaining: 115ms
# 4994:	learn: 3925.3966117	total: 1m 35s	remaining: 95.4ms
# 4995:	learn: 3915.5988861	total: 1m 35s	remaining: 76.3ms
# 4996:	learn: 3915.3771964	total: 1m 35s	remaining: 57.3ms
# 4997:	learn: 3914.8238151	total: 1m 35s	remaining: 38.2ms
# 4998:	learn: 3913.7744799	total: 1m 35s	remaining: 19.1ms
# 4999:	learn: 3913.0110811	total: 1m 35s	remaining: 0us
# CatBoostRegressor best params on C: {'depth': 8, 'iterations': 5000, 'learning_rate': 0.1}

# %%
df_catboost = pd.DataFrame(columns=['Library', 'Dataset','Train MAE', 'Test MAE'])

lib = 'CatBoost'
for data in ['B', 'C']:
  model = CatBoostRegressor(**test_parameters)
  model.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  pred_train = model.predict(datasets[data]['X_train'])
  pred_test = model.predict(datasets[data]['X_test'])
  mae_train = mean_absolute_error(datasets[data]['y_train'], pred_train)
  mae_test = mean_absolute_error(datasets[data]['y_test'], pred_test)
  result = [lib, data, mae_train, mae_test]
  df_catboost.loc[len(df_catboost)] = result

df_catboost
# Out:
# 0:	learn: 362376.6628125	total: 1.79ms	remaining: 1.79s
# 1:	learn: 350007.0933801	total: 3.43ms	remaining: 1.71s
# 2:	learn: 338226.4308205	total: 4.96ms	remaining: 1.65s
# 3:	learn: 328148.5246270	total: 6.5ms	remaining: 1.62s
# 4:	learn: 318234.5081668	total: 8.07ms	remaining: 1.61s
# 5:	learn: 309287.4311549	total: 9.59ms	remaining: 1.59s
# 6:	learn: 300979.2561272	total: 11.1ms	remaining: 1.58s
# 7:	learn: 293581.0787520	total: 12.7ms	remaining: 1.57s
# 8:	learn: 287181.8458439	total: 14.2ms	remaining: 1.56s
# 9:	learn: 281693.0734819	total: 15.6ms	remaining: 1.55s
# 10:	learn: 276190.1965660	total: 17.3ms	remaining: 1.56s
# 11:	learn: 271223.3900088	total: 18.9ms	remaining: 1.56s
# 12:	learn: 267044.7338556	total: 20.3ms	remaining: 1.54s
# 13:	learn: 263226.6963296	total: 21.8ms	remaining: 1.54s
# 14:	learn: 259646.3632156	total: 23.3ms	remaining: 1.53s
# 15:	learn: 256581.5749603	total: 25ms	remaining: 1.53s
# 16:	learn: 253584.1128182	total: 26.4ms	remaining: 1.53s
# 17:	learn: 251190.7642243	total: 27.9ms	remaining: 1.52s
# 18:	learn: 248447.9766024	total: 29.4ms	remaining: 1.52s
# 19:	learn: 246002.5743768	total: 30.8ms	remaining: 1.51s
# 20:	learn: 243969.8371758	total: 32.4ms	remaining: 1.51s
# 21:	learn: 242270.9736351	total: 33.9ms	remaining: 1.51s
# 22:	learn: 240589.3623446	total: 35.4ms	remaining: 1.5s
# 23:	learn: 239057.1424195	total: 36.9ms	remaining: 1.5s
# 24:	learn: 237828.3017649	total: 38.4ms	remaining: 1.5s
# 25:	learn: 236605.2433328	total: 40ms	remaining: 1.5s
# 26:	learn: 235555.1746404	total: 41.4ms	remaining: 1.49s
# 27:	learn: 234648.9627105	total: 43ms	remaining: 1.49s
# 28:	learn: 233667.6085387	total: 44.6ms	remaining: 1.49s
# 29:	learn: 232851.9133303	total: 46.1ms	remaining: 1.49s
# 30:	learn: 232298.8097856	total: 47.6ms	remaining: 1.49s
# 31:	learn: 231516.0988722	total: 49.2ms	remaining: 1.49s
# 32:	learn: 230781.5279641	total: 50.6ms	remaining: 1.48s
# 33:	learn: 230206.5460493	total: 52.1ms	remaining: 1.48s
# 34:	learn: 229790.7556043	total: 53.6ms	remaining: 1.48s
# 35:	learn: 228922.3539978	total: 55.1ms	remaining: 1.47s
# 36:	learn: 228472.1065964	total: 56.6ms	remaining: 1.47s
# 37:	learn: 228033.6428583	total: 58.1ms	remaining: 1.47s
# 38:	learn: 227702.0467179	total: 59.2ms	remaining: 1.46s
# 39:	learn: 227267.4796530	total: 60.8ms	remaining: 1.46s
# 40:	learn: 226960.3654178	total: 62.3ms	remaining: 1.46s
# 41:	learn: 226796.7252903	total: 64ms	remaining: 1.46s
# 42:	learn: 226548.5982472	total: 65.6ms	remaining: 1.46s
# 43:	learn: 226412.4009471	total: 67ms	remaining: 1.46s
# 44:	learn: 226242.3957759	total: 68.5ms	remaining: 1.45s
# 45:	learn: 225884.4293395	total: 70ms	remaining: 1.45s
# 46:	learn: 225710.0747076	total: 71.5ms	remaining: 1.45s
# 47:	learn: 225480.7052595	total: 73ms	remaining: 1.45s
# 48:	learn: 225199.7274190	total: 74.6ms	remaining: 1.45s
# 49:	learn: 224938.7323126	total: 76.1ms	remaining: 1.45s
# 50:	learn: 224821.7549087	total: 77.7ms	remaining: 1.45s
# 51:	learn: 224484.8455484	total: 79.2ms	remaining: 1.44s
# 52:	learn: 224240.9093324	total: 80.8ms	remaining: 1.44s
# 53:	learn: 224083.6537879	total: 82.3ms	remaining: 1.44s
# 54:	learn: 223787.8533436	total: 83.9ms	remaining: 1.44s
# 55:	learn: 223552.3016926	total: 85.5ms	remaining: 1.44s
# 56:	learn: 223385.9854079	total: 87ms	remaining: 1.44s
# 57:	learn: 222931.7877980	total: 88.6ms	remaining: 1.44s
# 58:	learn: 222772.4809050	total: 90ms	remaining: 1.44s
# 59:	learn: 222549.8935644	total: 91.6ms	remaining: 1.43s
# 60:	learn: 222398.5386375	total: 93.2ms	remaining: 1.43s
# 61:	learn: 222195.3118400	total: 94.7ms	remaining: 1.43s
# 62:	learn: 222019.8081031	total: 96.1ms	remaining: 1.43s
# 63:	learn: 221850.4879552	total: 97.6ms	remaining: 1.43s
# 64:	learn: 221623.5773462	total: 99.6ms	remaining: 1.43s
# 65:	learn: 221527.1126988	total: 101ms	remaining: 1.43s
# 66:	learn: 221319.4358287	total: 103ms	remaining: 1.43s
# 67:	learn: 221256.4147890	total: 104ms	remaining: 1.43s
# 68:	learn: 221159.5363941	total: 106ms	remaining: 1.43s
# 69:	learn: 221070.2893411	total: 107ms	remaining: 1.42s
# 70:	learn: 220910.2900758	total: 109ms	remaining: 1.42s
# 71:	learn: 220730.1418692	total: 110ms	remaining: 1.42s
# 72:	learn: 220664.7655237	total: 111ms	remaining: 1.42s
# 73:	learn: 220519.9665459	total: 113ms	remaining: 1.41s
# 74:	learn: 220322.9837798	total: 114ms	remaining: 1.41s
# 75:	learn: 220142.4010266	total: 116ms	remaining: 1.41s
# 76:	learn: 220045.2731428	total: 117ms	remaining: 1.41s
# 77:	learn: 219944.2194050	total: 119ms	remaining: 1.41s
# 78:	learn: 219793.5095325	total: 120ms	remaining: 1.4s
# 79:	learn: 219646.2418722	total: 122ms	remaining: 1.4s
# 80:	learn: 219539.5821158	total: 123ms	remaining: 1.4s
# 81:	learn: 219491.1817675	total: 125ms	remaining: 1.4s
# 82:	learn: 219186.2149666	total: 126ms	remaining: 1.39s
# 83:	learn: 219086.1065971	total: 128ms	remaining: 1.39s
# 84:	learn: 219021.1911007	total: 129ms	remaining: 1.39s
# 85:	learn: 218950.4295417	total: 131ms	remaining: 1.39s
# 86:	learn: 218829.7411170	total: 132ms	remaining: 1.39s
# 87:	learn: 218745.3182508	total: 134ms	remaining: 1.38s
# 88:	learn: 218642.4243840	total: 135ms	remaining: 1.38s
# 89:	learn: 218577.6534328	total: 142ms	remaining: 1.43s
# 90:	learn: 218485.8759998	total: 143ms	remaining: 1.43s
# 91:	learn: 218429.8360326	total: 145ms	remaining: 1.43s
# 92:	learn: 218293.7366412	total: 146ms	remaining: 1.42s
# 93:	learn: 218079.7484198	total: 148ms	remaining: 1.42s
# 94:	learn: 218002.2017308	total: 149ms	remaining: 1.42s
# 95:	learn: 217867.1274952	total: 150ms	remaining: 1.42s
# 96:	learn: 217779.1214625	total: 152ms	remaining: 1.41s
# 97:	learn: 217642.6371515	total: 154ms	remaining: 1.41s
# 98:	learn: 217493.9106224	total: 155ms	remaining: 1.41s
# 99:	learn: 217455.1802967	total: 156ms	remaining: 1.41s
# 100:	learn: 217335.9044371	total: 158ms	remaining: 1.41s
# 101:	learn: 217266.7970033	total: 159ms	remaining: 1.4s
# 102:	learn: 217199.0789132	total: 161ms	remaining: 1.4s
# 103:	learn: 217079.6285354	total: 162ms	remaining: 1.4s
# 104:	learn: 216938.9333262	total: 164ms	remaining: 1.4s
# 105:	learn: 216852.5057582	total: 166ms	remaining: 1.4s
# 106:	learn: 216799.0128707	total: 167ms	remaining: 1.39s
# 107:	learn: 216712.1891241	total: 169ms	remaining: 1.39s
# 108:	learn: 216625.5930179	total: 170ms	remaining: 1.39s
# 109:	learn: 216507.4549738	total: 172ms	remaining: 1.39s
# 110:	learn: 216399.5295838	total: 175ms	remaining: 1.4s
# 111:	learn: 216318.6911656	total: 177ms	remaining: 1.4s
# 112:	learn: 216256.4454794	total: 179ms	remaining: 1.4s
# 113:	learn: 216173.2977299	total: 180ms	remaining: 1.4s
# 114:	learn: 216086.2268021	total: 181ms	remaining: 1.4s
# 115:	learn: 216009.5063087	total: 183ms	remaining: 1.39s
# 116:	learn: 215932.9321830	total: 184ms	remaining: 1.39s
# 117:	learn: 215896.2129891	total: 186ms	remaining: 1.39s
# 118:	learn: 215848.8071026	total: 187ms	remaining: 1.39s
# 119:	learn: 215799.7207449	total: 189ms	remaining: 1.38s
# 120:	learn: 215741.3108479	total: 190ms	remaining: 1.38s
# 121:	learn: 215672.3319633	total: 192ms	remaining: 1.38s
# 122:	learn: 215597.2068398	total: 193ms	remaining: 1.38s
# 123:	learn: 215580.3818978	total: 197ms	remaining: 1.39s
# 124:	learn: 215533.7686970	total: 198ms	remaining: 1.39s
# 125:	learn: 215457.0421819	total: 200ms	remaining: 1.39s
# 126:	learn: 215421.1062275	total: 201ms	remaining: 1.38s
# 127:	learn: 215351.1155169	total: 203ms	remaining: 1.38s
# 128:	learn: 215253.2900140	total: 204ms	remaining: 1.38s
# 129:	learn: 215190.1490349	total: 206ms	remaining: 1.38s
# 130:	learn: 215125.3159388	total: 207ms	remaining: 1.37s
# 131:	learn: 215027.9593825	total: 209ms	remaining: 1.37s
# 132:	learn: 214969.0872032	total: 210ms	remaining: 1.37s
# 133:	learn: 214884.4501670	total: 211ms	remaining: 1.37s
# 134:	learn: 214825.3495891	total: 213ms	remaining: 1.36s
# 135:	learn: 214789.6385164	total: 214ms	remaining: 1.36s
# 136:	learn: 214722.1559500	total: 216ms	remaining: 1.36s
# 137:	learn: 214626.9914767	total: 217ms	remaining: 1.36s
# 138:	learn: 214563.0505042	total: 219ms	remaining: 1.35s
# 139:	learn: 214498.8974969	total: 220ms	remaining: 1.35s
# 140:	learn: 214439.8156652	total: 222ms	remaining: 1.35s
# 141:	learn: 214403.1833039	total: 224ms	remaining: 1.35s
# 142:	learn: 214366.4505924	total: 225ms	remaining: 1.35s
# 143:	learn: 214328.0724418	total: 226ms	remaining: 1.35s
# 144:	learn: 214290.6853664	total: 228ms	remaining: 1.34s
# 145:	learn: 214248.0254340	total: 229ms	remaining: 1.34s
# 146:	learn: 214222.9012240	total: 231ms	remaining: 1.34s
# 147:	learn: 214191.8168954	total: 232ms	remaining: 1.34s
# 148:	learn: 214144.7753515	total: 234ms	remaining: 1.33s
# 149:	learn: 214089.9968134	total: 235ms	remaining: 1.33s
# 150:	learn: 214051.1384142	total: 237ms	remaining: 1.33s
# 151:	learn: 213998.9414982	total: 238ms	remaining: 1.33s
# 152:	learn: 213962.7907178	total: 240ms	remaining: 1.33s
# 153:	learn: 213904.0801146	total: 241ms	remaining: 1.32s
# 154:	learn: 213875.3749650	total: 243ms	remaining: 1.32s
# 155:	learn: 213844.9031665	total: 244ms	remaining: 1.32s
# 156:	learn: 213774.2639295	total: 246ms	remaining: 1.32s
# 157:	learn: 213739.3871308	total: 247ms	remaining: 1.32s
# 158:	learn: 213691.4096118	total: 249ms	remaining: 1.31s
# 159:	learn: 213659.2849876	total: 250ms	remaining: 1.31s
# 160:	learn: 213604.9399480	total: 251ms	remaining: 1.31s
# 161:	learn: 213581.4372732	total: 253ms	remaining: 1.31s
# 162:	learn: 213532.4974709	total: 254ms	remaining: 1.31s
# 163:	learn: 213481.1062801	total: 256ms	remaining: 1.3s
# 164:	learn: 213416.8025182	total: 257ms	remaining: 1.3s
# 165:	learn: 213387.0612068	total: 259ms	remaining: 1.3s
# 166:	learn: 213376.0132953	total: 260ms	remaining: 1.3s
# 167:	learn: 213327.7670870	total: 262ms	remaining: 1.3s
# 168:	learn: 213306.9268180	total: 263ms	remaining: 1.29s
# 169:	learn: 213282.4386644	total: 265ms	remaining: 1.29s
# 170:	learn: 213238.9650316	total: 266ms	remaining: 1.29s
# 171:	learn: 213193.7173144	total: 268ms	remaining: 1.29s
# 172:	learn: 213162.3848814	total: 269ms	remaining: 1.29s
# 173:	learn: 213124.7432000	total: 271ms	remaining: 1.28s
# 174:	learn: 213082.4626158	total: 272ms	remaining: 1.28s
# 175:	learn: 213074.0165524	total: 274ms	remaining: 1.28s
# 176:	learn: 213016.8459978	total: 276ms	remaining: 1.28s
# 177:	learn: 212964.0784904	total: 277ms	remaining: 1.28s
# 178:	learn: 212927.4927767	total: 279ms	remaining: 1.28s
# 179:	learn: 212908.4824856	total: 280ms	remaining: 1.27s
# 180:	learn: 212882.0178403	total: 281ms	remaining: 1.27s
# 181:	learn: 212851.4342717	total: 283ms	remaining: 1.27s
# 182:	learn: 212834.4472752	total: 284ms	remaining: 1.27s
# 183:	learn: 212800.1230101	total: 287ms	remaining: 1.27s
# 184:	learn: 212767.5870264	total: 289ms	remaining: 1.27s
# 185:	learn: 212739.2392183	total: 291ms	remaining: 1.27s
# 186:	learn: 212731.5289279	total: 292ms	remaining: 1.27s
# 187:	learn: 212699.9842779	total: 294ms	remaining: 1.27s
# 188:	learn: 212669.9652078	total: 295ms	remaining: 1.27s
# 189:	learn: 212641.1876115	total: 297ms	remaining: 1.26s
# 190:	learn: 212628.9544072	total: 299ms	remaining: 1.27s
# 191:	learn: 212581.1670308	total: 300ms	remaining: 1.26s
# 192:	learn: 212557.6776569	total: 302ms	remaining: 1.26s
# 193:	learn: 212531.0562684	total: 303ms	remaining: 1.26s
# 194:	learn: 212498.6505089	total: 305ms	remaining: 1.26s
# 195:	learn: 212470.2350620	total: 307ms	remaining: 1.26s
# 196:	learn: 212463.9152761	total: 308ms	remaining: 1.25s
# 197:	learn: 212434.6750494	total: 310ms	remaining: 1.25s
# 198:	learn: 212409.2063832	total: 311ms	remaining: 1.25s
# 199:	learn: 212378.2165713	total: 313ms	remaining: 1.25s
# 200:	learn: 212336.5186658	total: 314ms	remaining: 1.25s
# 201:	learn: 212315.7395910	total: 315ms	remaining: 1.25s
# 202:	learn: 212272.8265855	total: 317ms	remaining: 1.24s
# 203:	learn: 212252.0895341	total: 319ms	remaining: 1.24s
# 204:	learn: 212218.9607490	total: 320ms	remaining: 1.24s
# 205:	learn: 212182.7444160	total: 322ms	remaining: 1.24s
# 206:	learn: 212170.0649373	total: 323ms	remaining: 1.24s
# 207:	learn: 212133.5599745	total: 325ms	remaining: 1.24s
# 208:	learn: 212108.4499321	total: 326ms	remaining: 1.24s
# 209:	learn: 212092.0539782	total: 328ms	remaining: 1.23s
# 210:	learn: 212067.0540117	total: 329ms	remaining: 1.23s
# 211:	learn: 212053.6440274	total: 332ms	remaining: 1.23s
# 212:	learn: 212021.3649376	total: 334ms	remaining: 1.23s
# 213:	learn: 211993.6534935	total: 339ms	remaining: 1.25s
# 214:	learn: 211968.2313379	total: 341ms	remaining: 1.25s
# 215:	learn: 211962.6913646	total: 343ms	remaining: 1.24s
# 216:	learn: 211950.6502896	total: 345ms	remaining: 1.25s
# 217:	learn: 211914.4009187	total: 347ms	remaining: 1.25s
# 218:	learn: 211898.4071822	total: 349ms	remaining: 1.24s
# 219:	learn: 211882.7095361	total: 350ms	remaining: 1.24s
# 220:	learn: 211875.1188829	total: 352ms	remaining: 1.24s
# 221:	learn: 211868.3943969	total: 353ms	remaining: 1.24s
# 222:	learn: 211840.5831882	total: 355ms	remaining: 1.24s
# 223:	learn: 211815.4193174	total: 356ms	remaining: 1.23s
# 224:	learn: 211790.3921109	total: 358ms	remaining: 1.23s
# 225:	learn: 211766.2674462	total: 359ms	remaining: 1.23s
# 226:	learn: 211750.0141921	total: 361ms	remaining: 1.23s
# 227:	learn: 211686.5928077	total: 362ms	remaining: 1.23s
# 228:	learn: 211675.4706997	total: 364ms	remaining: 1.22s
# 229:	learn: 211634.6575992	total: 365ms	remaining: 1.22s
# 230:	learn: 211630.4064720	total: 366ms	remaining: 1.22s
# 231:	learn: 211624.6273631	total: 371ms	remaining: 1.23s
# 232:	learn: 211599.3632614	total: 373ms	remaining: 1.23s
# 233:	learn: 211589.6997890	total: 375ms	remaining: 1.23s
# 234:	learn: 211552.7764259	total: 377ms	remaining: 1.23s
# 235:	learn: 211530.6110492	total: 378ms	remaining: 1.22s
# 236:	learn: 211524.2740322	total: 380ms	remaining: 1.22s
# 237:	learn: 211516.9301047	total: 381ms	remaining: 1.22s
# 238:	learn: 211498.0032346	total: 383ms	remaining: 1.22s
# 239:	learn: 211486.4855623	total: 384ms	remaining: 1.22s
# 240:	learn: 211472.2368573	total: 386ms	remaining: 1.22s
# 241:	learn: 211463.1739521	total: 387ms	remaining: 1.21s
# 242:	learn: 211436.4304361	total: 389ms	remaining: 1.21s
# 243:	learn: 211417.8227579	total: 390ms	remaining: 1.21s
# 244:	learn: 211402.2878284	total: 393ms	remaining: 1.21s
# 245:	learn: 211389.3292783	total: 395ms	remaining: 1.21s
# 246:	learn: 211377.4295544	total: 396ms	remaining: 1.21s
# 247:	learn: 211367.8875377	total: 398ms	remaining: 1.21s
# 248:	learn: 211334.2150614	total: 399ms	remaining: 1.2s
# 249:	learn: 211318.9922327	total: 401ms	remaining: 1.2s
# 250:	learn: 211305.1034319	total: 402ms	remaining: 1.2s
# 251:	learn: 211275.3270879	total: 403ms	remaining: 1.2s
# 252:	learn: 211257.9235224	total: 405ms	remaining: 1.2s
# 253:	learn: 211228.4614254	total: 407ms	remaining: 1.19s
# 254:	learn: 211189.2563571	total: 408ms	remaining: 1.19s
# 255:	learn: 211168.8472816	total: 409ms	remaining: 1.19s
# 256:	learn: 211141.6804567	total: 411ms	remaining: 1.19s
# 257:	learn: 211128.1798842	total: 413ms	remaining: 1.19s
# 258:	learn: 211124.2503225	total: 414ms	remaining: 1.18s
# 259:	learn: 211117.9529274	total: 415ms	remaining: 1.18s
# 260:	learn: 211102.4498864	total: 417ms	remaining: 1.18s
# 261:	learn: 211094.9883120	total: 418ms	remaining: 1.18s
# 262:	learn: 211081.4252371	total: 420ms	remaining: 1.18s
# 263:	learn: 211063.2952117	total: 421ms	remaining: 1.17s
# 264:	learn: 211045.4210252	total: 423ms	remaining: 1.17s
# 265:	learn: 211029.4849851	total: 424ms	remaining: 1.17s
# 266:	learn: 211013.7768656	total: 426ms	remaining: 1.17s
# 267:	learn: 210983.7447765	total: 427ms	remaining: 1.17s
# 268:	learn: 210973.8521923	total: 429ms	remaining: 1.17s
# 269:	learn: 210950.3432578	total: 430ms	remaining: 1.16s
# 270:	learn: 210932.3246009	total: 432ms	remaining: 1.16s
# 271:	learn: 210913.9443789	total: 433ms	remaining: 1.16s
# 272:	learn: 210896.0575785	total: 434ms	remaining: 1.16s
# 273:	learn: 210883.9307083	total: 436ms	remaining: 1.15s
# 274:	learn: 210859.9008434	total: 437ms	remaining: 1.15s
# 275:	learn: 210846.3693994	total: 439ms	remaining: 1.15s
# 276:	learn: 210829.2396824	total: 440ms	remaining: 1.15s
# 277:	learn: 210809.4425254	total: 442ms	remaining: 1.15s
# 278:	learn: 210783.5068400	total: 443ms	remaining: 1.14s
# 279:	learn: 210764.4878918	total: 445ms	remaining: 1.14s
# 280:	learn: 210752.0667192	total: 446ms	remaining: 1.14s
# 281:	learn: 210733.4953801	total: 447ms	remaining: 1.14s
# 282:	learn: 210718.3868947	total: 449ms	remaining: 1.14s
# 283:	learn: 210698.7762020	total: 450ms	remaining: 1.14s
# 284:	learn: 210693.4588967	total: 452ms	remaining: 1.13s
# 285:	learn: 210677.0421026	total: 453ms	remaining: 1.13s
# 286:	learn: 210664.7122936	total: 455ms	remaining: 1.13s
# 287:	learn: 210645.9482943	total: 456ms	remaining: 1.13s
# 288:	learn: 210625.6700936	total: 458ms	remaining: 1.13s
# 289:	learn: 210617.6919125	total: 459ms	remaining: 1.12s
# 290:	learn: 210595.4600774	total: 461ms	remaining: 1.12s
# 291:	learn: 210569.1467134	total: 462ms	remaining: 1.12s
# 292:	learn: 210560.2890086	total: 464ms	remaining: 1.12s
# 293:	learn: 210553.4300581	total: 465ms	remaining: 1.12s
# 294:	learn: 210532.2411489	total: 468ms	remaining: 1.12s
# 295:	learn: 210528.3890545	total: 469ms	remaining: 1.11s
# 296:	learn: 210519.4508276	total: 470ms	remaining: 1.11s
# 297:	learn: 210510.7514495	total: 472ms	remaining: 1.11s
# 298:	learn: 210496.9144661	total: 473ms	remaining: 1.11s
# 299:	learn: 210493.3134191	total: 475ms	remaining: 1.11s
# 300:	learn: 210479.0071280	total: 476ms	remaining: 1.1s
# 301:	learn: 210459.4825408	total: 478ms	remaining: 1.1s
# 302:	learn: 210452.6336967	total: 479ms	remaining: 1.1s
# 303:	learn: 210433.3049636	total: 481ms	remaining: 1.1s
# 304:	learn: 210431.6382546	total: 482ms	remaining: 1.1s
# 305:	learn: 210411.1717498	total: 483ms	remaining: 1.1s
# 306:	learn: 210398.1547462	total: 485ms	remaining: 1.09s
# 307:	learn: 210389.9396591	total: 486ms	remaining: 1.09s
# 308:	learn: 210381.0785545	total: 488ms	remaining: 1.09s
# 309:	learn: 210370.2580678	total: 489ms	remaining: 1.09s
# 310:	learn: 210361.9881201	total: 491ms	remaining: 1.09s
# 311:	learn: 210343.7524325	total: 492ms	remaining: 1.08s
# 312:	learn: 210327.5155261	total: 494ms	remaining: 1.08s
# 313:	learn: 210322.8364304	total: 495ms	remaining: 1.08s
# 314:	learn: 210315.5093728	total: 497ms	remaining: 1.08s
# 315:	learn: 210312.1163156	total: 498ms	remaining: 1.08s
# 316:	learn: 210292.4345943	total: 500ms	remaining: 1.08s
# 317:	learn: 210288.3175854	total: 501ms	remaining: 1.07s
# 318:	learn: 210268.9596690	total: 503ms	remaining: 1.07s
# 319:	learn: 210247.8709932	total: 504ms	remaining: 1.07s
# 320:	learn: 210244.7992168	total: 507ms	remaining: 1.07s
# 321:	learn: 210234.7134814	total: 509ms	remaining: 1.07s
# 322:	learn: 210228.6880883	total: 510ms	remaining: 1.07s
# 323:	learn: 210210.6527710	total: 512ms	remaining: 1.07s
# 324:	learn: 210197.8112965	total: 513ms	remaining: 1.06s
# 325:	learn: 210183.5304067	total: 515ms	remaining: 1.06s
# 326:	learn: 210168.6354021	total: 516ms	remaining: 1.06s
# 327:	learn: 210149.0406536	total: 518ms	remaining: 1.06s
# 328:	learn: 210140.5681239	total: 519ms	remaining: 1.06s
# 329:	learn: 210122.7506194	total: 520ms	remaining: 1.06s
# 330:	learn: 210102.0800100	total: 522ms	remaining: 1.05s
# 331:	learn: 210090.1870019	total: 523ms	remaining: 1.05s
# 332:	learn: 210059.9803908	total: 525ms	remaining: 1.05s
# 333:	learn: 210050.8236947	total: 526ms	remaining: 1.05s
# 334:	learn: 210043.1024370	total: 528ms	remaining: 1.05s
# 335:	learn: 210030.5078770	total: 529ms	remaining: 1.04s
# 336:	learn: 210015.0832771	total: 531ms	remaining: 1.04s
# 337:	learn: 210008.6553148	total: 532ms	remaining: 1.04s
# 338:	learn: 209996.8071413	total: 533ms	remaining: 1.04s
# 339:	learn: 209987.6136845	total: 535ms	remaining: 1.04s
# 340:	learn: 209981.5925451	total: 536ms	remaining: 1.04s
# 341:	learn: 209969.3175421	total: 538ms	remaining: 1.03s
# 342:	learn: 209950.0629539	total: 539ms	remaining: 1.03s
# 343:	learn: 209938.2879271	total: 541ms	remaining: 1.03s
# 344:	learn: 209930.1080628	total: 542ms	remaining: 1.03s
# 345:	learn: 209926.4219372	total: 544ms	remaining: 1.03s
# 346:	learn: 209920.9544236	total: 545ms	remaining: 1.02s
# 347:	learn: 209917.2634531	total: 547ms	remaining: 1.02s
# 348:	learn: 209900.8233358	total: 548ms	remaining: 1.02s
# 349:	learn: 209898.7883626	total: 549ms	remaining: 1.02s
# 350:	learn: 209892.5890633	total: 551ms	remaining: 1.02s
# 351:	learn: 209889.3344711	total: 552ms	remaining: 1.02s
# 352:	learn: 209869.5994013	total: 554ms	remaining: 1.01s
# 353:	learn: 209862.8167828	total: 555ms	remaining: 1.01s
# 354:	learn: 209850.0588010	total: 557ms	remaining: 1.01s
# 355:	learn: 209839.1494708	total: 558ms	remaining: 1.01s
# 356:	learn: 209825.2046278	total: 560ms	remaining: 1.01s
# 357:	learn: 209819.7497742	total: 561ms	remaining: 1.01s
# 358:	learn: 209814.4414453	total: 563ms	remaining: 1s
# 359:	learn: 209795.0239465	total: 564ms	remaining: 1s
# 360:	learn: 209792.7606427	total: 568ms	remaining: 1s
# 361:	learn: 209784.2497254	total: 569ms	remaining: 1s
# 362:	learn: 209775.1295038	total: 571ms	remaining: 1s
# 363:	learn: 209753.1381599	total: 572ms	remaining: 1000ms
# 364:	learn: 209743.7017076	total: 574ms	remaining: 998ms
# 365:	learn: 209733.9960846	total: 575ms	remaining: 996ms
# 366:	learn: 209725.1743285	total: 576ms	remaining: 994ms
# 367:	learn: 209721.4621803	total: 578ms	remaining: 992ms
# 368:	learn: 209701.7524972	total: 579ms	remaining: 991ms
# 369:	learn: 209676.0122442	total: 581ms	remaining: 989ms
# 370:	learn: 209670.3966085	total: 582ms	remaining: 987ms
# 371:	learn: 209668.2132819	total: 584ms	remaining: 985ms
# 372:	learn: 209664.4974028	total: 585ms	remaining: 984ms
# 373:	learn: 209649.7913414	total: 588ms	remaining: 984ms
# 374:	learn: 209645.5471038	total: 589ms	remaining: 982ms
# 375:	learn: 209637.9459863	total: 591ms	remaining: 980ms
# 376:	learn: 209629.2396793	total: 592ms	remaining: 978ms
# 377:	learn: 209620.0952097	total: 594ms	remaining: 977ms
# 378:	learn: 209606.8110155	total: 595ms	remaining: 975ms
# 379:	learn: 209601.6299782	total: 597ms	remaining: 973ms
# 380:	learn: 209592.1648485	total: 598ms	remaining: 972ms
# 381:	learn: 209586.6184675	total: 599ms	remaining: 970ms
# 382:	learn: 209565.5291551	total: 601ms	remaining: 968ms
# 383:	learn: 209558.4763203	total: 602ms	remaining: 966ms
# 384:	learn: 209553.7448168	total: 604ms	remaining: 964ms
# 385:	learn: 209532.1489796	total: 605ms	remaining: 963ms
# 386:	learn: 209520.3858036	total: 607ms	remaining: 961ms
# 387:	learn: 209505.9231553	total: 608ms	remaining: 959ms
# 388:	learn: 209494.4855975	total: 609ms	remaining: 957ms
# 389:	learn: 209487.7068817	total: 611ms	remaining: 956ms
# 390:	learn: 209485.9768366	total: 612ms	remaining: 954ms
# 391:	learn: 209478.8079720	total: 614ms	remaining: 952ms
# 392:	learn: 209467.3580701	total: 615ms	remaining: 950ms
# 393:	learn: 209465.4971158	total: 617ms	remaining: 948ms
# 394:	learn: 209456.6620945	total: 618ms	remaining: 947ms
# 395:	learn: 209440.7397047	total: 620ms	remaining: 945ms
# 396:	learn: 209437.9759036	total: 621ms	remaining: 943ms
# 397:	learn: 209432.2516875	total: 622ms	remaining: 941ms
# 398:	learn: 209427.2019140	total: 624ms	remaining: 940ms
# 399:	learn: 209422.8510344	total: 625ms	remaining: 938ms
# 400:	learn: 209411.8171600	total: 627ms	remaining: 936ms
# 401:	learn: 209398.5576907	total: 628ms	remaining: 934ms
# 402:	learn: 209394.4919419	total: 630ms	remaining: 933ms
# 403:	learn: 209384.4369127	total: 631ms	remaining: 931ms
# 404:	learn: 209374.8434718	total: 632ms	remaining: 929ms
# 405:	learn: 209370.7031527	total: 634ms	remaining: 927ms
# 406:	learn: 209366.5213918	total: 635ms	remaining: 926ms
# 407:	learn: 209363.7667057	total: 637ms	remaining: 924ms
# 408:	learn: 209353.8880155	total: 638ms	remaining: 922ms
# 409:	learn: 209346.1621361	total: 640ms	remaining: 920ms
# 410:	learn: 209343.4466556	total: 641ms	remaining: 919ms
# 411:	learn: 209339.2918757	total: 642ms	remaining: 917ms
# 412:	learn: 209330.2654703	total: 644ms	remaining: 915ms
# 413:	learn: 209318.6967073	total: 645ms	remaining: 914ms
# 414:	learn: 209306.5814890	total: 647ms	remaining: 912ms
# 415:	learn: 209287.4092063	total: 648ms	remaining: 910ms
# 416:	learn: 209279.0460195	total: 650ms	remaining: 909ms
# 417:	learn: 209277.0602229	total: 651ms	remaining: 907ms
# 418:	learn: 209270.6575266	total: 653ms	remaining: 905ms
# 419:	learn: 209262.6216292	total: 654ms	remaining: 904ms
# 420:	learn: 209253.5068744	total: 656ms	remaining: 902ms
# 421:	learn: 209246.0365130	total: 657ms	remaining: 900ms
# 422:	learn: 209228.1871975	total: 659ms	remaining: 899ms
# 423:	learn: 209222.8982823	total: 660ms	remaining: 897ms
# 424:	learn: 209211.9445094	total: 662ms	remaining: 895ms
# 425:	learn: 209204.5607172	total: 663ms	remaining: 894ms
# 426:	learn: 209197.1772558	total: 665ms	remaining: 892ms
# 427:	learn: 209177.4590282	total: 666ms	remaining: 890ms
# 428:	learn: 209165.7613150	total: 668ms	remaining: 889ms
# 429:	learn: 209158.8565044	total: 669ms	remaining: 887ms
# 430:	learn: 209152.7424393	total: 671ms	remaining: 885ms
# 431:	learn: 209142.8420159	total: 672ms	remaining: 884ms
# 432:	learn: 209140.7649389	total: 673ms	remaining: 882ms
# 433:	learn: 209131.9354349	total: 675ms	remaining: 880ms
# 434:	learn: 209120.3650601	total: 676ms	remaining: 879ms
# 435:	learn: 209113.9437400	total: 678ms	remaining: 877ms
# 436:	learn: 209107.8744275	total: 679ms	remaining: 875ms
# 437:	learn: 209098.5662361	total: 681ms	remaining: 873ms
# 438:	learn: 209088.9503536	total: 682ms	remaining: 872ms
# 439:	learn: 209080.8545152	total: 684ms	remaining: 870ms
# 440:	learn: 209076.5401632	total: 685ms	remaining: 868ms
# 441:	learn: 209066.0366938	total: 687ms	remaining: 867ms
# 442:	learn: 209060.3784776	total: 688ms	remaining: 865ms
# 443:	learn: 209060.0822353	total: 689ms	remaining: 863ms
# 444:	learn: 209053.8253195	total: 692ms	remaining: 863ms
# 445:	learn: 209049.4500061	total: 694ms	remaining: 862ms
# 446:	learn: 209046.8157073	total: 697ms	remaining: 862ms
# 447:	learn: 209039.7064408	total: 700ms	remaining: 862ms
# 448:	learn: 209029.4845678	total: 706ms	remaining: 866ms
# 449:	learn: 209025.8138064	total: 709ms	remaining: 866ms
# 450:	learn: 209021.7919478	total: 715ms	remaining: 870ms
# 451:	learn: 209020.5035558	total: 716ms	remaining: 868ms
# 452:	learn: 209009.2291330	total: 718ms	remaining: 867ms
# 453:	learn: 209004.5316982	total: 719ms	remaining: 865ms
# 454:	learn: 209001.5138004	total: 721ms	remaining: 863ms
# 455:	learn: 208997.5904708	total: 722ms	remaining: 862ms
# 456:	learn: 208986.7131538	total: 724ms	remaining: 860ms
# 457:	learn: 208974.0473019	total: 726ms	remaining: 859ms
# 458:	learn: 208967.8004422	total: 727ms	remaining: 857ms
# 459:	learn: 208963.7925794	total: 729ms	remaining: 855ms
# 460:	learn: 208962.9337401	total: 731ms	remaining: 855ms
# 461:	learn: 208954.2379867	total: 733ms	remaining: 853ms
# 462:	learn: 208950.8542364	total: 734ms	remaining: 851ms
# 463:	learn: 208944.4436285	total: 736ms	remaining: 850ms
# 464:	learn: 208942.2322088	total: 737ms	remaining: 848ms
# 465:	learn: 208934.5595291	total: 739ms	remaining: 847ms
# 466:	learn: 208930.1470243	total: 740ms	remaining: 845ms
# 467:	learn: 208924.9963018	total: 742ms	remaining: 843ms
# 468:	learn: 208922.7416616	total: 743ms	remaining: 841ms
# 469:	learn: 208916.4148936	total: 745ms	remaining: 840ms
# 470:	learn: 208913.9218182	total: 746ms	remaining: 838ms
# 471:	learn: 208906.2992825	total: 747ms	remaining: 836ms
# 472:	learn: 208904.6199711	total: 749ms	remaining: 834ms
# 473:	learn: 208898.9004297	total: 750ms	remaining: 833ms
# 474:	learn: 208896.6166474	total: 752ms	remaining: 831ms
# 475:	learn: 208892.3532140	total: 753ms	remaining: 829ms
# 476:	learn: 208882.6149791	total: 755ms	remaining: 828ms
# 477:	learn: 208879.4690471	total: 757ms	remaining: 826ms
# 478:	learn: 208870.5147070	total: 759ms	remaining: 825ms
# 479:	learn: 208861.9581651	total: 762ms	remaining: 826ms
# 480:	learn: 208854.5176706	total: 764ms	remaining: 824ms
# 481:	learn: 208850.8174836	total: 765ms	remaining: 823ms
# 482:	learn: 208848.9926998	total: 767ms	remaining: 821ms
# 483:	learn: 208840.4366569	total: 768ms	remaining: 819ms
# 484:	learn: 208837.4488883	total: 770ms	remaining: 818ms
# 485:	learn: 208834.9045250	total: 771ms	remaining: 816ms
# 486:	learn: 208826.5505062	total: 773ms	remaining: 814ms
# 487:	learn: 208820.8048136	total: 774ms	remaining: 812ms
# 488:	learn: 208807.2618523	total: 776ms	remaining: 811ms
# 489:	learn: 208792.1439850	total: 777ms	remaining: 809ms
# 490:	learn: 208783.1687088	total: 779ms	remaining: 808ms
# 491:	learn: 208768.2542037	total: 782ms	remaining: 807ms
# 492:	learn: 208756.7957124	total: 783ms	remaining: 805ms
# 493:	learn: 208752.7606885	total: 785ms	remaining: 804ms
# 494:	learn: 208744.7691117	total: 786ms	remaining: 802ms
# 495:	learn: 208737.2518600	total: 787ms	remaining: 800ms
# 496:	learn: 208733.1493133	total: 789ms	remaining: 798ms
# 497:	learn: 208720.9770637	total: 790ms	remaining: 797ms
# 498:	learn: 208716.3784687	total: 792ms	remaining: 795ms
# 499:	learn: 208698.7320226	total: 793ms	remaining: 793ms
# 500:	learn: 208689.2297107	total: 795ms	remaining: 792ms
# 501:	learn: 208685.6885969	total: 796ms	remaining: 790ms
# 502:	learn: 208683.2725156	total: 798ms	remaining: 788ms
# 503:	learn: 208681.7154543	total: 799ms	remaining: 787ms
# 504:	learn: 208679.9286628	total: 801ms	remaining: 785ms
# 505:	learn: 208679.0646893	total: 802ms	remaining: 783ms
# 506:	learn: 208674.2641760	total: 804ms	remaining: 781ms
# 507:	learn: 208666.3302733	total: 805ms	remaining: 780ms
# 508:	learn: 208664.8253371	total: 807ms	remaining: 778ms
# 509:	learn: 208662.8147649	total: 808ms	remaining: 776ms
# 510:	learn: 208657.2406290	total: 809ms	remaining: 775ms
# 511:	learn: 208655.6437407	total: 811ms	remaining: 773ms
# 512:	learn: 208651.3975261	total: 812ms	remaining: 771ms
# 513:	learn: 208651.1216657	total: 814ms	remaining: 769ms
# 514:	learn: 208647.9085437	total: 815ms	remaining: 768ms
# 515:	learn: 208644.1015370	total: 817ms	remaining: 766ms
# 516:	learn: 208640.4675622	total: 818ms	remaining: 764ms
# 517:	learn: 208637.2877332	total: 820ms	remaining: 763ms
# 518:	learn: 208624.8563547	total: 821ms	remaining: 761ms
# 519:	learn: 208622.7584462	total: 823ms	remaining: 759ms
# 520:	learn: 208617.9043357	total: 824ms	remaining: 758ms
# 521:	learn: 208616.2825963	total: 826ms	remaining: 756ms
# 522:	learn: 208613.3057030	total: 827ms	remaining: 754ms
# 523:	learn: 208610.2804816	total: 829ms	remaining: 753ms
# 524:	learn: 208604.4099554	total: 830ms	remaining: 751ms
# 525:	learn: 208602.4793500	total: 831ms	remaining: 749ms
# 526:	learn: 208597.9150163	total: 833ms	remaining: 747ms
# 527:	learn: 208592.6517566	total: 834ms	remaining: 746ms
# 528:	learn: 208590.6873874	total: 836ms	remaining: 744ms
# 529:	learn: 208579.2930815	total: 837ms	remaining: 743ms
# 530:	learn: 208578.8661135	total: 839ms	remaining: 741ms
# 531:	learn: 208577.4837436	total: 840ms	remaining: 739ms
# 532:	learn: 208577.1058181	total: 842ms	remaining: 737ms
# 533:	learn: 208569.4591527	total: 843ms	remaining: 736ms
# 534:	learn: 208563.2583011	total: 845ms	remaining: 734ms
# 535:	learn: 208562.2032707	total: 846ms	remaining: 732ms
# 536:	learn: 208560.8453073	total: 847ms	remaining: 731ms
# 537:	learn: 208556.0273116	total: 849ms	remaining: 729ms
# 538:	learn: 208550.3194228	total: 850ms	remaining: 727ms
# 539:	learn: 208542.5382967	total: 852ms	remaining: 726ms
# 540:	learn: 208541.2501073	total: 853ms	remaining: 724ms
# 541:	learn: 208538.5412269	total: 855ms	remaining: 722ms
# 542:	learn: 208532.7068550	total: 856ms	remaining: 721ms
# 543:	learn: 208530.9340106	total: 858ms	remaining: 719ms
# 544:	learn: 208528.2055091	total: 859ms	remaining: 717ms
# 545:	learn: 208527.3742784	total: 860ms	remaining: 715ms
# 546:	learn: 208518.1278798	total: 862ms	remaining: 714ms
# 547:	learn: 208511.5437815	total: 863ms	remaining: 712ms
# 548:	learn: 208508.7208821	total: 865ms	remaining: 711ms
# 549:	learn: 208501.8271164	total: 866ms	remaining: 709ms
# 550:	learn: 208497.4253015	total: 868ms	remaining: 707ms
# 551:	learn: 208495.1486523	total: 869ms	remaining: 706ms
# 552:	learn: 208478.9916290	total: 871ms	remaining: 704ms
# 553:	learn: 208476.2358459	total: 872ms	remaining: 702ms
# 554:	learn: 208471.6085733	total: 874ms	remaining: 701ms
# 555:	learn: 208464.2937426	total: 875ms	remaining: 699ms
# 556:	learn: 208458.9150548	total: 877ms	remaining: 697ms
# 557:	learn: 208456.0890224	total: 878ms	remaining: 696ms
# 558:	learn: 208450.9415844	total: 880ms	remaining: 694ms
# 559:	learn: 208449.0609314	total: 881ms	remaining: 692ms
# 560:	learn: 208438.5921878	total: 883ms	remaining: 691ms
# 561:	learn: 208432.4193030	total: 884ms	remaining: 689ms
# 562:	learn: 208424.8884493	total: 886ms	remaining: 687ms
# 563:	learn: 208419.2450929	total: 887ms	remaining: 686ms
# 564:	learn: 208418.8306238	total: 889ms	remaining: 684ms
# 565:	learn: 208412.4940842	total: 890ms	remaining: 683ms
# 566:	learn: 208403.2764639	total: 892ms	remaining: 681ms
# 567:	learn: 208402.1308839	total: 893ms	remaining: 679ms
# 568:	learn: 208397.2110240	total: 895ms	remaining: 678ms
# 569:	learn: 208394.8324262	total: 896ms	remaining: 676ms
# 570:	learn: 208394.3593652	total: 898ms	remaining: 674ms
# 571:	learn: 208390.2538117	total: 899ms	remaining: 673ms
# 572:	learn: 208385.8857544	total: 901ms	remaining: 671ms
# 573:	learn: 208380.3341561	total: 902ms	remaining: 670ms
# 574:	learn: 208379.1144617	total: 904ms	remaining: 668ms
# 575:	learn: 208376.0720078	total: 905ms	remaining: 666ms
# 576:	learn: 208374.6152496	total: 907ms	remaining: 665ms
# 577:	learn: 208370.1811598	total: 908ms	remaining: 663ms
# 578:	learn: 208364.7621694	total: 910ms	remaining: 661ms
# 579:	learn: 208360.9769415	total: 911ms	remaining: 660ms
# 580:	learn: 208348.2883903	total: 913ms	remaining: 658ms
# 581:	learn: 208344.3913870	total: 914ms	remaining: 656ms
# 582:	learn: 208340.3838417	total: 915ms	remaining: 655ms
# 583:	learn: 208337.1755330	total: 917ms	remaining: 653ms
# 584:	learn: 208334.9767503	total: 918ms	remaining: 651ms
# 585:	learn: 208333.9259603	total: 920ms	remaining: 650ms
# 586:	learn: 208332.2416959	total: 921ms	remaining: 648ms
# 587:	learn: 208329.4485741	total: 923ms	remaining: 647ms
# 588:	learn: 208320.8820017	total: 924ms	remaining: 645ms
# 589:	learn: 208316.6097894	total: 926ms	remaining: 643ms
# 590:	learn: 208308.3944546	total: 927ms	remaining: 642ms
# 591:	learn: 208296.1105254	total: 929ms	remaining: 640ms
# 592:	learn: 208294.7503432	total: 930ms	remaining: 638ms
# 593:	learn: 208291.4856531	total: 931ms	remaining: 637ms
# 594:	learn: 208288.8937747	total: 933ms	remaining: 635ms
# 595:	learn: 208284.7711022	total: 934ms	remaining: 633ms
# 596:	learn: 208282.1490741	total: 936ms	remaining: 632ms
# 597:	learn: 208277.6358662	total: 937ms	remaining: 630ms
# 598:	learn: 208275.2062727	total: 939ms	remaining: 629ms
# 599:	learn: 208274.6246241	total: 940ms	remaining: 627ms
# 600:	learn: 208273.1244631	total: 942ms	remaining: 625ms
# 601:	learn: 208272.4141766	total: 943ms	remaining: 624ms
# 602:	learn: 208270.1284335	total: 945ms	remaining: 622ms
# 603:	learn: 208269.7611663	total: 946ms	remaining: 620ms
# 604:	learn: 208267.1711601	total: 947ms	remaining: 619ms
# 605:	learn: 208262.4707283	total: 949ms	remaining: 617ms
# 606:	learn: 208259.1749671	total: 950ms	remaining: 615ms
# 607:	learn: 208255.5127598	total: 954ms	remaining: 615ms
# 608:	learn: 208251.3410756	total: 956ms	remaining: 614ms
# 609:	learn: 208246.2377763	total: 958ms	remaining: 612ms
# 610:	learn: 208240.2437153	total: 959ms	remaining: 611ms
# 611:	learn: 208238.9750305	total: 961ms	remaining: 609ms
# 612:	learn: 208237.5779750	total: 962ms	remaining: 607ms
# 613:	learn: 208235.8535700	total: 964ms	remaining: 606ms
# 614:	learn: 208235.6185020	total: 965ms	remaining: 604ms
# 615:	learn: 208233.6568034	total: 966ms	remaining: 602ms
# 616:	learn: 208230.5960030	total: 968ms	remaining: 601ms
# 617:	learn: 208223.0729402	total: 969ms	remaining: 599ms
# 618:	learn: 208216.1353705	total: 971ms	remaining: 598ms
# 619:	learn: 208211.2942317	total: 972ms	remaining: 596ms
# 620:	learn: 208210.1718623	total: 974ms	remaining: 594ms
# 621:	learn: 208208.3954653	total: 977ms	remaining: 594ms
# 622:	learn: 208205.5727982	total: 978ms	remaining: 592ms
# 623:	learn: 208204.9361680	total: 980ms	remaining: 590ms
# 624:	learn: 208204.0056519	total: 981ms	remaining: 589ms
# 625:	learn: 208201.6532626	total: 983ms	remaining: 587ms
# 626:	learn: 208199.1601505	total: 984ms	remaining: 585ms
# 627:	learn: 208187.3755157	total: 986ms	remaining: 584ms
# 628:	learn: 208185.5801613	total: 987ms	remaining: 582ms
# 629:	learn: 208184.1969252	total: 988ms	remaining: 580ms
# 630:	learn: 208181.2034163	total: 990ms	remaining: 579ms
# 631:	learn: 208177.7652748	total: 991ms	remaining: 577ms
# 632:	learn: 208174.1101293	total: 993ms	remaining: 576ms
# 633:	learn: 208173.4527294	total: 994ms	remaining: 574ms
# 634:	learn: 208171.7847080	total: 996ms	remaining: 572ms
# 635:	learn: 208169.7975361	total: 997ms	remaining: 571ms
# 636:	learn: 208165.7333613	total: 998ms	remaining: 569ms
# 637:	learn: 208159.3385915	total: 1000ms	remaining: 567ms
# 638:	learn: 208153.7500659	total: 1s	remaining: 566ms
# 639:	learn: 208148.8363943	total: 1s	remaining: 564ms
# 640:	learn: 208143.7709563	total: 1s	remaining: 563ms
# 641:	learn: 208141.2358069	total: 1s	remaining: 561ms
# 642:	learn: 208139.9745010	total: 1.01s	remaining: 559ms
# 643:	learn: 208136.8106117	total: 1.01s	remaining: 558ms
# 644:	learn: 208136.7403658	total: 1.01s	remaining: 556ms
# 645:	learn: 208129.1190549	total: 1.01s	remaining: 554ms
# 646:	learn: 208127.8780124	total: 1.01s	remaining: 553ms
# 647:	learn: 208124.1901306	total: 1.01s	remaining: 551ms
# 648:	learn: 208121.2662125	total: 1.02s	remaining: 549ms
# 649:	learn: 208114.3724231	total: 1.02s	remaining: 548ms
# 650:	learn: 208113.1999509	total: 1.02s	remaining: 546ms
# 651:	learn: 208113.1523337	total: 1.02s	remaining: 545ms
# 652:	learn: 208112.5448038	total: 1.02s	remaining: 543ms
# 653:	learn: 208108.3940979	total: 1.02s	remaining: 541ms
# 654:	learn: 208107.6123464	total: 1.02s	remaining: 540ms
# 655:	learn: 208102.5377220	total: 1.03s	remaining: 538ms
# 656:	learn: 208101.2796877	total: 1.03s	remaining: 537ms
# 657:	learn: 208096.3954329	total: 1.03s	remaining: 535ms
# 658:	learn: 208095.8372905	total: 1.03s	remaining: 533ms
# 659:	learn: 208093.9147242	total: 1.03s	remaining: 532ms
# 660:	learn: 208087.9919524	total: 1.03s	remaining: 530ms
# 661:	learn: 208085.7264323	total: 1.03s	remaining: 528ms
# 662:	learn: 208079.8947892	total: 1.04s	remaining: 527ms
# 663:	learn: 208078.4653229	total: 1.04s	remaining: 525ms
# 664:	learn: 208078.4226087	total: 1.04s	remaining: 524ms
# 665:	learn: 208071.8142801	total: 1.04s	remaining: 522ms
# 666:	learn: 208065.9342229	total: 1.04s	remaining: 520ms
# 667:	learn: 208058.4615805	total: 1.04s	remaining: 519ms
# 668:	learn: 208056.8967682	total: 1.04s	remaining: 517ms
# 669:	learn: 208050.7749313	total: 1.05s	remaining: 516ms
# 670:	learn: 208049.6536162	total: 1.05s	remaining: 514ms
# 671:	learn: 208042.9993601	total: 1.05s	remaining: 512ms
# 672:	learn: 208041.6516190	total: 1.05s	remaining: 511ms
# 673:	learn: 208039.3407689	total: 1.05s	remaining: 509ms
# 674:	learn: 208034.1463302	total: 1.05s	remaining: 508ms
# 675:	learn: 208031.2973367	total: 1.05s	remaining: 506ms
# 676:	learn: 208026.3988372	total: 1.06s	remaining: 504ms
# 677:	learn: 208024.3503542	total: 1.06s	remaining: 503ms
# 678:	learn: 208021.3630113	total: 1.06s	remaining: 501ms
# 679:	learn: 208017.8696037	total: 1.06s	remaining: 500ms
# 680:	learn: 208009.0615356	total: 1.06s	remaining: 498ms
# 681:	learn: 208007.6652296	total: 1.06s	remaining: 496ms
# 682:	learn: 208006.6290510	total: 1.06s	remaining: 495ms
# 683:	learn: 208006.3042677	total: 1.07s	remaining: 493ms
# 684:	learn: 208001.0651013	total: 1.07s	remaining: 491ms
# 685:	learn: 207999.8912886	total: 1.07s	remaining: 490ms
# 686:	learn: 207999.0251208	total: 1.07s	remaining: 488ms
# 687:	learn: 207996.3777211	total: 1.07s	remaining: 487ms
# 688:	learn: 207992.7231282	total: 1.07s	remaining: 485ms
# 689:	learn: 207990.1612384	total: 1.08s	remaining: 483ms
# 690:	learn: 207985.6429801	total: 1.08s	remaining: 482ms
# 691:	learn: 207984.1089452	total: 1.08s	remaining: 481ms
# 692:	learn: 207981.3081104	total: 1.08s	remaining: 479ms
# 693:	learn: 207973.7528278	total: 1.08s	remaining: 477ms
# 694:	learn: 207970.4816402	total: 1.08s	remaining: 476ms
# 695:	learn: 207961.6824915	total: 1.08s	remaining: 474ms
# 696:	learn: 207957.5476915	total: 1.09s	remaining: 473ms
# 697:	learn: 207956.2628462	total: 1.09s	remaining: 471ms
# 698:	learn: 207952.3805807	total: 1.09s	remaining: 469ms
# 699:	learn: 207946.3203510	total: 1.09s	remaining: 468ms
# 700:	learn: 207938.4701900	total: 1.09s	remaining: 467ms
# 701:	learn: 207937.9714125	total: 1.09s	remaining: 465ms
# 702:	learn: 207936.8475275	total: 1.1s	remaining: 463ms
# 703:	learn: 207932.2395864	total: 1.1s	remaining: 462ms
# 704:	learn: 207926.8889568	total: 1.1s	remaining: 460ms
# 705:	learn: 207921.5720096	total: 1.1s	remaining: 459ms
# 706:	learn: 207913.4591000	total: 1.1s	remaining: 457ms
# 707:	learn: 207910.7658574	total: 1.1s	remaining: 455ms
# 708:	learn: 207909.7226175	total: 1.1s	remaining: 454ms
# 709:	learn: 207900.4827030	total: 1.11s	remaining: 452ms
# 710:	learn: 207896.9414066	total: 1.11s	remaining: 451ms
# 711:	learn: 207895.6217342	total: 1.11s	remaining: 449ms
# 712:	learn: 207894.9779852	total: 1.11s	remaining: 447ms
# 713:	learn: 207892.7229979	total: 1.11s	remaining: 446ms
# 714:	learn: 207885.8186977	total: 1.11s	remaining: 444ms
# 715:	learn: 207885.1257091	total: 1.11s	remaining: 443ms
# 716:	learn: 207884.8194351	total: 1.12s	remaining: 441ms
# 717:	learn: 207881.3438008	total: 1.12s	remaining: 439ms
# 718:	learn: 207879.0231163	total: 1.12s	remaining: 438ms
# 719:	learn: 207878.8007702	total: 1.12s	remaining: 436ms
# 720:	learn: 207872.9629665	total: 1.12s	remaining: 435ms
# 721:	learn: 207872.1110936	total: 1.12s	remaining: 433ms
# 722:	learn: 207867.6500827	total: 1.13s	remaining: 431ms
# 723:	learn: 207865.5336519	total: 1.13s	remaining: 430ms
# 724:	learn: 207861.4140627	total: 1.13s	remaining: 428ms
# 725:	learn: 207858.4161472	total: 1.13s	remaining: 427ms
# 726:	learn: 207853.8387320	total: 1.13s	remaining: 425ms
# 727:	learn: 207850.8853952	total: 1.13s	remaining: 424ms
# 728:	learn: 207850.2723407	total: 1.14s	remaining: 422ms
# 729:	learn: 207843.8933767	total: 1.14s	remaining: 420ms
# 730:	learn: 207839.2029620	total: 1.14s	remaining: 419ms
# 731:	learn: 207834.3573812	total: 1.14s	remaining: 417ms
# 732:	learn: 207833.3551537	total: 1.14s	remaining: 416ms
# 733:	learn: 207832.1783541	total: 1.14s	remaining: 414ms
# 734:	learn: 207830.4042310	total: 1.14s	remaining: 412ms
# 735:	learn: 207830.2872122	total: 1.15s	remaining: 411ms
# 736:	learn: 207829.1652166	total: 1.15s	remaining: 409ms
# 737:	learn: 207828.1248773	total: 1.15s	remaining: 408ms
# 738:	learn: 207828.0433661	total: 1.15s	remaining: 407ms
# 739:	learn: 207826.6075277	total: 1.15s	remaining: 405ms
# 740:	learn: 207826.1593787	total: 1.15s	remaining: 404ms
# 741:	learn: 207825.3188107	total: 1.16s	remaining: 402ms
# 742:	learn: 207823.7003553	total: 1.16s	remaining: 400ms
# 743:	learn: 207821.6773180	total: 1.16s	remaining: 399ms
# 744:	learn: 207816.5798122	total: 1.16s	remaining: 397ms
# 745:	learn: 207812.2340892	total: 1.16s	remaining: 396ms
# 746:	learn: 207812.1374866	total: 1.16s	remaining: 394ms
# 747:	learn: 207810.9749730	total: 1.16s	remaining: 392ms
# 748:	learn: 207810.3945353	total: 1.17s	remaining: 391ms
# 749:	learn: 207806.3480765	total: 1.17s	remaining: 389ms
# 750:	learn: 207803.9799303	total: 1.17s	remaining: 388ms
# 751:	learn: 207802.9060966	total: 1.17s	remaining: 387ms
# 752:	learn: 207801.7895822	total: 1.17s	remaining: 385ms
# 753:	learn: 207798.1827679	total: 1.18s	remaining: 384ms
# 754:	learn: 207787.5228806	total: 1.18s	remaining: 382ms
# 755:	learn: 207787.0592878	total: 1.18s	remaining: 380ms
# 756:	learn: 207786.9221269	total: 1.18s	remaining: 379ms
# 757:	learn: 207780.5101712	total: 1.18s	remaining: 377ms
# 758:	learn: 207780.4693481	total: 1.18s	remaining: 376ms
# 759:	learn: 207776.2717402	total: 1.18s	remaining: 374ms
# 760:	learn: 207775.7467143	total: 1.19s	remaining: 372ms
# 761:	learn: 207773.5327665	total: 1.19s	remaining: 371ms
# 762:	learn: 207773.0952935	total: 1.19s	remaining: 369ms
# 763:	learn: 207771.1755554	total: 1.19s	remaining: 368ms
# 764:	learn: 207764.7847819	total: 1.19s	remaining: 366ms
# 765:	learn: 207762.5182403	total: 1.19s	remaining: 365ms
# 766:	learn: 207760.2056311	total: 1.19s	remaining: 363ms
# 767:	learn: 207756.8322621	total: 1.2s	remaining: 361ms
# 768:	learn: 207756.7901106	total: 1.2s	remaining: 360ms
# 769:	learn: 207755.1235454	total: 1.2s	remaining: 358ms
# 770:	learn: 207754.9893922	total: 1.2s	remaining: 357ms
# 771:	learn: 207754.3200586	total: 1.2s	remaining: 355ms
# 772:	learn: 207753.8851558	total: 1.2s	remaining: 353ms
# 773:	learn: 207748.3433980	total: 1.2s	remaining: 352ms
# 774:	learn: 207748.0763159	total: 1.21s	remaining: 350ms
# 775:	learn: 207742.2555737	total: 1.21s	remaining: 349ms
# 776:	learn: 207736.1365201	total: 1.21s	remaining: 347ms
# 777:	learn: 207733.2424231	total: 1.21s	remaining: 345ms
# 778:	learn: 207730.6134505	total: 1.21s	remaining: 344ms
# 779:	learn: 207725.6378725	total: 1.21s	remaining: 342ms
# 780:	learn: 207724.3111172	total: 1.22s	remaining: 341ms
# 781:	learn: 207720.3916154	total: 1.22s	remaining: 339ms
# 782:	learn: 207719.9853396	total: 1.22s	remaining: 338ms
# 783:	learn: 207717.4127250	total: 1.22s	remaining: 336ms
# 784:	learn: 207711.6076657	total: 1.22s	remaining: 334ms
# 785:	learn: 207710.3228531	total: 1.22s	remaining: 333ms
# 786:	learn: 207704.4452213	total: 1.22s	remaining: 331ms
# 787:	learn: 207702.1500534	total: 1.23s	remaining: 330ms
# 788:	learn: 207700.0518413	total: 1.23s	remaining: 328ms
# 789:	learn: 207699.5118988	total: 1.23s	remaining: 327ms
# 790:	learn: 207699.4152810	total: 1.23s	remaining: 325ms
# 791:	learn: 207693.6913063	total: 1.23s	remaining: 323ms
# 792:	learn: 207692.0830328	total: 1.23s	remaining: 322ms
# 793:	learn: 207691.6703307	total: 1.23s	remaining: 320ms
# 794:	learn: 207688.5065001	total: 1.24s	remaining: 319ms
# 795:	learn: 207684.5009469	total: 1.24s	remaining: 317ms
# 796:	learn: 207683.9546677	total: 1.24s	remaining: 316ms
# 797:	learn: 207682.9836033	total: 1.24s	remaining: 314ms
# 798:	learn: 207682.5446167	total: 1.24s	remaining: 312ms
# 799:	learn: 207679.5565454	total: 1.24s	remaining: 311ms
# 800:	learn: 207678.7057393	total: 1.24s	remaining: 309ms
# 801:	learn: 207673.3595343	total: 1.25s	remaining: 308ms
# 802:	learn: 207670.6608500	total: 1.25s	remaining: 306ms
# 803:	learn: 207669.2682822	total: 1.25s	remaining: 305ms
# 804:	learn: 207668.4877385	total: 1.25s	remaining: 303ms
# 805:	learn: 207665.2331664	total: 1.25s	remaining: 302ms
# 806:	learn: 207662.9827863	total: 1.25s	remaining: 300ms
# 807:	learn: 207661.8032748	total: 1.26s	remaining: 299ms
# 808:	learn: 207658.7487278	total: 1.26s	remaining: 297ms
# 809:	learn: 207656.6421031	total: 1.26s	remaining: 296ms
# 810:	learn: 207655.9992479	total: 1.26s	remaining: 294ms
# 811:	learn: 207653.4730767	total: 1.26s	remaining: 293ms
# 812:	learn: 207648.9857750	total: 1.26s	remaining: 291ms
# 813:	learn: 207647.7126498	total: 1.27s	remaining: 289ms
# 814:	learn: 207646.3153811	total: 1.27s	remaining: 288ms
# 815:	learn: 207645.0130752	total: 1.27s	remaining: 286ms
# 816:	learn: 207644.6108144	total: 1.27s	remaining: 285ms
# 817:	learn: 207641.3101603	total: 1.27s	remaining: 283ms
# 818:	learn: 207638.3706702	total: 1.27s	remaining: 281ms
# 819:	learn: 207636.6191974	total: 1.27s	remaining: 280ms
# 820:	learn: 207634.2744633	total: 1.28s	remaining: 278ms
# 821:	learn: 207634.1647390	total: 1.28s	remaining: 277ms
# 822:	learn: 207632.5050449	total: 1.28s	remaining: 275ms
# 823:	learn: 207631.6973723	total: 1.28s	remaining: 274ms
# 824:	learn: 207628.7086781	total: 1.28s	remaining: 272ms
# 825:	learn: 207625.8125121	total: 1.28s	remaining: 270ms
# 826:	learn: 207624.3812780	total: 1.28s	remaining: 269ms
# 827:	learn: 207624.0407061	total: 1.29s	remaining: 267ms
# 828:	learn: 207622.8212456	total: 1.29s	remaining: 266ms
# 829:	learn: 207622.1557744	total: 1.29s	remaining: 264ms
# 830:	learn: 207621.6946334	total: 1.29s	remaining: 263ms
# 831:	learn: 207620.7037953	total: 1.29s	remaining: 262ms
# 832:	learn: 207620.1667395	total: 1.3s	remaining: 260ms
# 833:	learn: 207619.2188973	total: 1.3s	remaining: 259ms
# 834:	learn: 207616.9768480	total: 1.3s	remaining: 258ms
# 835:	learn: 207616.8499215	total: 1.3s	remaining: 256ms
# 836:	learn: 207615.3377856	total: 1.31s	remaining: 255ms
# 837:	learn: 207610.7183014	total: 1.31s	remaining: 253ms
# 838:	learn: 207606.1094532	total: 1.31s	remaining: 252ms
# 839:	learn: 207605.2089856	total: 1.32s	remaining: 251ms
# 840:	learn: 207603.5499520	total: 1.32s	remaining: 250ms
# 841:	learn: 207601.9231802	total: 1.32s	remaining: 248ms
# 842:	learn: 207601.2777383	total: 1.33s	remaining: 247ms
# 843:	learn: 207598.1333412	total: 1.33s	remaining: 247ms
# ...
# 717:	learn: 25834.2972578	total: 3.57s	remaining: 1.4s
# 718:	learn: 25812.2550789	total: 3.57s	remaining: 1.4s
# 719:	learn: 25808.3986725	total: 3.57s	remaining: 1.39s
# 720:	learn: 25804.0881856	total: 3.58s	remaining: 1.38s
# 721:	learn: 25793.9227689	total: 3.58s	remaining: 1.38s
# 722:	learn: 25757.3319591	total: 3.59s	remaining: 1.37s
# 723:	learn: 25753.5078309	total: 3.59s	remaining: 1.37s
# 724:	learn: 25747.1038033	total: 3.59s	remaining: 1.36s
# 725:	learn: 25730.3685774	total: 3.6s	remaining: 1.36s
# 726:	learn: 25697.4847831	total: 3.6s	remaining: 1.35s
# 727:	learn: 25693.4355820	total: 3.61s	remaining: 1.35s
# 728:	learn: 25686.7101148	total: 3.61s	remaining: 1.34s
# 729:	learn: 25664.6030063	total: 3.61s	remaining: 1.34s
# 730:	learn: 25658.7056908	total: 3.62s	remaining: 1.33s
# 731:	learn: 25645.6546806	total: 3.62s	remaining: 1.33s
# 732:	learn: 25635.8114242	total: 3.63s	remaining: 1.32s
# 733:	learn: 25631.5870761	total: 3.63s	remaining: 1.31s
# 734:	learn: 25608.9247454	total: 3.63s	remaining: 1.31s
# 735:	learn: 25564.2866001	total: 3.64s	remaining: 1.3s
# 736:	learn: 25553.3474780	total: 3.65s	remaining: 1.3s
# 737:	learn: 25549.0834570	total: 3.65s	remaining: 1.29s
# 738:	learn: 25537.6063114	total: 3.65s	remaining: 1.29s
# 739:	learn: 25499.1528945	total: 3.66s	remaining: 1.28s
# 740:	learn: 25439.3935324	total: 3.66s	remaining: 1.28s
# 741:	learn: 25432.1915984	total: 3.67s	remaining: 1.27s
# 742:	learn: 25427.9671264	total: 3.67s	remaining: 1.27s
# 743:	learn: 25423.7867294	total: 3.68s	remaining: 1.26s
# 744:	learn: 25419.8849783	total: 3.68s	remaining: 1.26s
# 745:	learn: 25415.7583821	total: 3.69s	remaining: 1.25s
# 746:	learn: 25403.8323140	total: 3.69s	remaining: 1.25s
# 747:	learn: 25399.9559414	total: 3.69s	remaining: 1.24s
# 748:	learn: 25379.1734808	total: 3.7s	remaining: 1.24s
# 749:	learn: 25367.2751950	total: 3.7s	remaining: 1.23s
# 750:	learn: 25360.6154599	total: 3.71s	remaining: 1.23s
# 751:	learn: 25352.9323610	total: 3.71s	remaining: 1.22s
# 752:	learn: 25341.5686960	total: 3.71s	remaining: 1.22s
# 753:	learn: 25325.9589321	total: 3.72s	remaining: 1.21s
# 754:	learn: 25319.0935356	total: 3.72s	remaining: 1.21s
# 755:	learn: 25268.9971858	total: 3.73s	remaining: 1.2s
# 756:	learn: 25264.8831471	total: 3.73s	remaining: 1.2s
# 757:	learn: 25182.4535500	total: 3.73s	remaining: 1.19s
# 758:	learn: 25178.5662318	total: 3.74s	remaining: 1.19s
# 759:	learn: 25172.1151305	total: 3.74s	remaining: 1.18s
# 760:	learn: 25164.8536200	total: 3.75s	remaining: 1.18s
# 761:	learn: 25136.7965860	total: 3.75s	remaining: 1.17s
# 762:	learn: 25133.0994140	total: 3.75s	remaining: 1.17s
# 763:	learn: 25121.7665395	total: 3.76s	remaining: 1.16s
# 764:	learn: 25116.2377845	total: 3.76s	remaining: 1.16s
# 765:	learn: 25112.1930671	total: 3.77s	remaining: 1.15s
# 766:	learn: 25108.5194066	total: 3.77s	remaining: 1.15s
# 767:	learn: 25104.7303586	total: 3.77s	remaining: 1.14s
# 768:	learn: 25082.7186186	total: 3.78s	remaining: 1.13s
# 769:	learn: 25078.6911801	total: 3.78s	remaining: 1.13s
# 770:	learn: 25052.6870735	total: 3.79s	remaining: 1.12s
# 771:	learn: 25049.4038903	total: 3.79s	remaining: 1.12s
# 772:	learn: 25045.0760237	total: 3.79s	remaining: 1.11s
# 773:	learn: 25032.7391092	total: 3.8s	remaining: 1.11s
# 774:	learn: 25029.1426493	total: 3.8s	remaining: 1.1s
# 775:	learn: 25016.7873091	total: 3.81s	remaining: 1.1s
# 776:	learn: 24989.0203521	total: 3.81s	remaining: 1.09s
# 777:	learn: 24953.8235124	total: 3.81s	remaining: 1.09s
# 778:	learn: 24950.7006746	total: 3.82s	remaining: 1.08s
# 779:	learn: 24947.0158384	total: 3.82s	remaining: 1.08s
# 780:	learn: 24942.8568977	total: 3.83s	remaining: 1.07s
# 781:	learn: 24939.3867175	total: 3.83s	remaining: 1.07s
# 782:	learn: 24928.9037948	total: 3.83s	remaining: 1.06s
# 783:	learn: 24920.2805852	total: 3.84s	remaining: 1.06s
# 784:	learn: 24910.9050273	total: 3.84s	remaining: 1.05s
# 785:	learn: 24906.8896106	total: 3.85s	remaining: 1.05s
# 786:	learn: 24903.2350547	total: 3.85s	remaining: 1.04s
# 787:	learn: 24899.3843325	total: 3.85s	remaining: 1.04s
# 788:	learn: 24895.8812587	total: 3.86s	remaining: 1.03s
# 789:	learn: 24892.4121417	total: 3.86s	remaining: 1.03s
# 790:	learn: 24886.8359176	total: 3.87s	remaining: 1.02s
# 791:	learn: 24883.8806495	total: 3.87s	remaining: 1.02s
# 792:	learn: 24840.4886275	total: 3.88s	remaining: 1.01s
# 793:	learn: 24836.8310611	total: 3.88s	remaining: 1.01s
# 794:	learn: 24829.2133866	total: 3.88s	remaining: 1s
# 795:	learn: 24822.2988728	total: 3.89s	remaining: 996ms
# 796:	learn: 24787.9121440	total: 3.89s	remaining: 991ms
# 797:	learn: 24782.5885042	total: 3.9s	remaining: 986ms
# 798:	learn: 24779.9003702	total: 3.9s	remaining: 981ms
# 799:	learn: 24770.8436736	total: 3.9s	remaining: 976ms
# 800:	learn: 24723.0663798	total: 3.91s	remaining: 971ms
# 801:	learn: 24715.0713956	total: 3.91s	remaining: 966ms
# 802:	learn: 24708.9988319	total: 3.92s	remaining: 961ms
# 803:	learn: 24696.7962429	total: 3.92s	remaining: 956ms
# 804:	learn: 24649.5650203	total: 3.92s	remaining: 951ms
# 805:	learn: 24631.4879371	total: 3.93s	remaining: 945ms
# 806:	learn: 24610.9612998	total: 3.93s	remaining: 940ms
# 807:	learn: 24607.5249639	total: 3.94s	remaining: 935ms
# 808:	learn: 24604.2950982	total: 3.94s	remaining: 930ms
# 809:	learn: 24600.7655127	total: 3.94s	remaining: 925ms
# 810:	learn: 24586.5757505	total: 3.95s	remaining: 920ms
# 811:	learn: 24568.9340589	total: 3.95s	remaining: 915ms
# 812:	learn: 24565.1179875	total: 3.96s	remaining: 910ms
# 813:	learn: 24532.9748004	total: 3.96s	remaining: 905ms
# 814:	learn: 24523.4673526	total: 3.96s	remaining: 900ms
# 815:	learn: 24519.9791633	total: 3.97s	remaining: 895ms
# 816:	learn: 24508.6904146	total: 3.97s	remaining: 890ms
# 817:	learn: 24496.7759988	total: 3.98s	remaining: 885ms
# 818:	learn: 24493.3093580	total: 3.98s	remaining: 879ms
# 819:	learn: 24482.1006907	total: 3.98s	remaining: 874ms
# 820:	learn: 24393.5676663	total: 3.99s	remaining: 869ms
# 821:	learn: 24390.0816053	total: 3.99s	remaining: 864ms
# 822:	learn: 24387.5882581	total: 4s	remaining: 859ms
# 823:	learn: 24384.2576202	total: 4s	remaining: 854ms
# 824:	learn: 24372.4980135	total: 4s	remaining: 849ms
# 825:	learn: 24365.3529734	total: 4.01s	remaining: 844ms
# 826:	learn: 24354.8674466	total: 4.01s	remaining: 839ms
# 827:	learn: 24313.9289603	total: 4.01s	remaining: 834ms
# 828:	learn: 24308.4326578	total: 4.02s	remaining: 829ms
# 829:	learn: 24304.6983704	total: 4.02s	remaining: 824ms
# 830:	learn: 24301.2734886	total: 4.03s	remaining: 819ms
# 831:	learn: 24296.2060752	total: 4.03s	remaining: 814ms
# 832:	learn: 24293.1950559	total: 4.04s	remaining: 809ms
# 833:	learn: 24286.5161984	total: 4.04s	remaining: 804ms
# 834:	learn: 24276.5248118	total: 4.04s	remaining: 799ms
# 835:	learn: 24272.7736254	total: 4.05s	remaining: 794ms
# 836:	learn: 24268.8601816	total: 4.05s	remaining: 789ms
# 837:	learn: 24245.3920553	total: 4.05s	remaining: 784ms
# 838:	learn: 24232.5461653	total: 4.06s	remaining: 779ms
# 839:	learn: 24222.2197019	total: 4.07s	remaining: 775ms
# 840:	learn: 24209.2028590	total: 4.07s	remaining: 770ms
# 841:	learn: 24206.0566967	total: 4.08s	remaining: 765ms
# 842:	learn: 24202.7660269	total: 4.08s	remaining: 760ms
# 843:	learn: 24199.3161534	total: 4.08s	remaining: 755ms
# 844:	learn: 24196.0953130	total: 4.09s	remaining: 750ms
# 845:	learn: 24192.4908508	total: 4.09s	remaining: 745ms
# 846:	learn: 24188.9594517	total: 4.1s	remaining: 740ms
# 847:	learn: 24185.4858716	total: 4.1s	remaining: 735ms
# 848:	learn: 24182.3389134	total: 4.11s	remaining: 730ms
# 849:	learn: 24178.9913819	total: 4.11s	remaining: 725ms
# 850:	learn: 24171.2719276	total: 4.11s	remaining: 720ms
# 851:	learn: 24164.3267454	total: 4.12s	remaining: 715ms
# 852:	learn: 24157.2814110	total: 4.12s	remaining: 710ms
# 853:	learn: 24149.0614966	total: 4.13s	remaining: 705ms
# 854:	learn: 24146.0199982	total: 4.13s	remaining: 700ms
# 855:	learn: 24136.2907057	total: 4.13s	remaining: 695ms
# 856:	learn: 24128.3287580	total: 4.14s	remaining: 690ms
# 857:	learn: 24119.3903001	total: 4.14s	remaining: 686ms
# 858:	learn: 24108.7560894	total: 4.15s	remaining: 681ms
# 859:	learn: 24105.6511675	total: 4.15s	remaining: 676ms
# 860:	learn: 24096.4080830	total: 4.15s	remaining: 671ms
# 861:	learn: 24086.7287344	total: 4.16s	remaining: 666ms
# 862:	learn: 24083.7956860	total: 4.16s	remaining: 661ms
# 863:	learn: 24079.2815509	total: 4.17s	remaining: 656ms
# 864:	learn: 24030.3670028	total: 4.17s	remaining: 651ms
# 865:	learn: 24018.6725375	total: 4.17s	remaining: 646ms
# 866:	learn: 23969.3329515	total: 4.18s	remaining: 641ms
# 867:	learn: 23959.9445855	total: 4.18s	remaining: 636ms
# 868:	learn: 23956.3506250	total: 4.19s	remaining: 631ms
# 869:	learn: 23952.9797357	total: 4.19s	remaining: 627ms
# 870:	learn: 23949.4769173	total: 4.2s	remaining: 622ms
# 871:	learn: 23939.9386468	total: 4.2s	remaining: 617ms
# 872:	learn: 23931.7273285	total: 4.2s	remaining: 612ms
# 873:	learn: 23895.4290404	total: 4.21s	remaining: 607ms
# 874:	learn: 23883.5197903	total: 4.21s	remaining: 602ms
# 875:	learn: 23880.5027871	total: 4.22s	remaining: 597ms
# 876:	learn: 23873.9391599	total: 4.23s	remaining: 593ms
# 877:	learn: 23856.5824668	total: 4.24s	remaining: 589ms
# 878:	learn: 23853.4551208	total: 4.24s	remaining: 584ms
# 879:	learn: 23817.3568987	total: 4.25s	remaining: 579ms
# 880:	learn: 23812.1544431	total: 4.25s	remaining: 574ms
# 881:	learn: 23791.1532353	total: 4.25s	remaining: 569ms
# 882:	learn: 23786.1663297	total: 4.26s	remaining: 564ms
# 883:	learn: 23782.7043809	total: 4.26s	remaining: 559ms
# 884:	learn: 23757.0786885	total: 4.27s	remaining: 554ms
# 885:	learn: 23753.6353369	total: 4.27s	remaining: 550ms
# 886:	learn: 23750.5020367	total: 4.28s	remaining: 545ms
# 887:	learn: 23706.8557576	total: 4.28s	remaining: 540ms
# 888:	learn: 23703.3958763	total: 4.28s	remaining: 535ms
# 889:	learn: 23682.3960817	total: 4.29s	remaining: 530ms
# 890:	learn: 23679.4345925	total: 4.29s	remaining: 525ms
# 891:	learn: 23632.4300131	total: 4.3s	remaining: 520ms
# 892:	learn: 23603.4725544	total: 4.3s	remaining: 515ms
# 893:	learn: 23600.0306767	total: 4.3s	remaining: 510ms
# 894:	learn: 23594.0073950	total: 4.31s	remaining: 505ms
# 895:	learn: 23590.6229378	total: 4.31s	remaining: 501ms
# 896:	learn: 23587.3051368	total: 4.32s	remaining: 496ms
# 897:	learn: 23566.1966332	total: 4.32s	remaining: 491ms
# 898:	learn: 23542.5123175	total: 4.32s	remaining: 486ms
# 899:	learn: 23539.8110243	total: 4.33s	remaining: 481ms
# 900:	learn: 23535.2692802	total: 4.33s	remaining: 476ms
# 901:	learn: 23528.8284269	total: 4.33s	remaining: 471ms
# 902:	learn: 23521.3941398	total: 4.34s	remaining: 466ms
# 903:	learn: 23518.3855492	total: 4.34s	remaining: 461ms
# 904:	learn: 23505.3355752	total: 4.35s	remaining: 456ms
# 905:	learn: 23502.3816663	total: 4.35s	remaining: 451ms
# 906:	learn: 23497.2983019	total: 4.36s	remaining: 447ms
# 907:	learn: 23494.0098916	total: 4.36s	remaining: 442ms
# 908:	learn: 23484.3386416	total: 4.36s	remaining: 437ms
# 909:	learn: 23481.9001542	total: 4.37s	remaining: 432ms
# 910:	learn: 23468.4381604	total: 4.37s	remaining: 427ms
# 911:	learn: 23454.9778447	total: 4.38s	remaining: 422ms
# 912:	learn: 23404.6435554	total: 4.38s	remaining: 417ms
# 913:	learn: 23386.5740129	total: 4.38s	remaining: 412ms
# 914:	learn: 23360.1730772	total: 4.39s	remaining: 408ms
# 915:	learn: 23347.0416744	total: 4.39s	remaining: 403ms
# 916:	learn: 23342.6254590	total: 4.39s	remaining: 398ms
# 917:	learn: 23339.2719274	total: 4.4s	remaining: 393ms
# 918:	learn: 23311.9832280	total: 4.4s	remaining: 388ms
# 919:	learn: 23304.7327366	total: 4.41s	remaining: 383ms
# 920:	learn: 23293.0223859	total: 4.41s	remaining: 378ms
# 921:	learn: 23283.8126705	total: 4.42s	remaining: 374ms
# 922:	learn: 23280.9152014	total: 4.42s	remaining: 369ms
# 923:	learn: 23261.3916905	total: 4.42s	remaining: 364ms
# 924:	learn: 23256.8922596	total: 4.43s	remaining: 359ms
# 925:	learn: 23247.2618304	total: 4.43s	remaining: 354ms
# 926:	learn: 23238.1821898	total: 4.43s	remaining: 349ms
# 927:	learn: 23235.4128391	total: 4.44s	remaining: 344ms
# 928:	learn: 23231.3117870	total: 4.44s	remaining: 340ms
# 929:	learn: 23223.9092049	total: 4.45s	remaining: 335ms
# 930:	learn: 23201.3633596	total: 4.45s	remaining: 330ms
# 931:	learn: 23198.0567384	total: 4.46s	remaining: 325ms
# 932:	learn: 23163.4679688	total: 4.46s	remaining: 320ms
# 933:	learn: 23160.2208660	total: 4.46s	remaining: 315ms
# 934:	learn: 23141.2520687	total: 4.47s	remaining: 311ms
# 935:	learn: 23138.0417871	total: 4.48s	remaining: 306ms
# 936:	learn: 23131.2396997	total: 4.48s	remaining: 301ms
# 937:	learn: 23127.0951991	total: 4.48s	remaining: 296ms
# 938:	learn: 23123.9087857	total: 4.49s	remaining: 292ms
# 939:	learn: 23113.7713674	total: 4.49s	remaining: 287ms
# 940:	learn: 23067.0058929	total: 4.5s	remaining: 282ms
# 941:	learn: 23038.9497969	total: 4.5s	remaining: 277ms
# 942:	learn: 23034.3242831	total: 4.5s	remaining: 272ms
# 943:	learn: 23029.9205403	total: 4.51s	remaining: 267ms
# 944:	learn: 23016.1970651	total: 4.51s	remaining: 263ms
# 945:	learn: 23011.4880711	total: 4.52s	remaining: 258ms
# 946:	learn: 23008.2525292	total: 4.52s	remaining: 253ms
# 947:	learn: 22996.0783732	total: 4.52s	remaining: 248ms
# 948:	learn: 22992.8979716	total: 4.53s	remaining: 243ms
# 949:	learn: 22990.1284271	total: 4.53s	remaining: 239ms
# 950:	learn: 22982.8648572	total: 4.54s	remaining: 234ms
# 951:	learn: 22972.9759954	total: 4.54s	remaining: 229ms
# 952:	learn: 22942.7783898	total: 4.54s	remaining: 224ms
# 953:	learn: 22937.0531285	total: 4.55s	remaining: 219ms
# 954:	learn: 22933.3026105	total: 4.55s	remaining: 214ms
# 955:	learn: 22929.8750980	total: 4.56s	remaining: 210ms
# 956:	learn: 22927.0443504	total: 4.56s	remaining: 205ms
# 957:	learn: 22924.2216926	total: 4.56s	remaining: 200ms
# 958:	learn: 22921.5030410	total: 4.57s	remaining: 195ms
# 959:	learn: 22904.3003825	total: 4.57s	remaining: 191ms
# 960:	learn: 22901.4396393	total: 4.58s	remaining: 186ms
# 961:	learn: 22893.3321301	total: 4.58s	remaining: 181ms
# 962:	learn: 22890.1750208	total: 4.58s	remaining: 176ms
# 963:	learn: 22887.0850958	total: 4.59s	remaining: 171ms
# 964:	learn: 22884.0468651	total: 4.59s	remaining: 167ms
# 965:	learn: 22881.2424705	total: 4.6s	remaining: 162ms
# 966:	learn: 22878.5340502	total: 4.6s	remaining: 157ms
# 967:	learn: 22872.8193629	total: 4.61s	remaining: 152ms
# 968:	learn: 22870.0696652	total: 4.61s	remaining: 147ms
# 969:	learn: 22867.6755175	total: 4.61s	remaining: 143ms
# 970:	learn: 22859.1387468	total: 4.62s	remaining: 138ms
# 971:	learn: 22856.2473048	total: 4.62s	remaining: 133ms
# 972:	learn: 22853.6175594	total: 4.63s	remaining: 128ms
# 973:	learn: 22850.8338682	total: 4.63s	remaining: 124ms
# 974:	learn: 22848.5628040	total: 4.64s	remaining: 119ms
# 975:	learn: 22840.0294945	total: 4.64s	remaining: 114ms
# 976:	learn: 22811.8588992	total: 4.64s	remaining: 109ms
# 977:	learn: 22793.9657678	total: 4.65s	remaining: 105ms
# 978:	learn: 22784.3397505	total: 4.65s	remaining: 99.8ms
# 979:	learn: 22772.9053621	total: 4.66s	remaining: 95.1ms
# 980:	learn: 22765.7614669	total: 4.66s	remaining: 90.3ms
# 981:	learn: 22703.6052634	total: 4.67s	remaining: 85.6ms
# 982:	learn: 22695.6439212	total: 4.67s	remaining: 80.9ms
# 983:	learn: 22686.5387237	total: 4.68s	remaining: 76.1ms
# 984:	learn: 22678.5600061	total: 4.68s	remaining: 71.3ms
# 985:	learn: 22675.7906496	total: 4.69s	remaining: 66.6ms
# 986:	learn: 22668.6982251	total: 4.69s	remaining: 61.8ms
# 987:	learn: 22612.1197027	total: 4.7s	remaining: 57ms
# 988:	learn: 22596.5994105	total: 4.7s	remaining: 52.3ms
# 989:	learn: 22594.0561839	total: 4.7s	remaining: 47.5ms
# 990:	learn: 22585.8681632	total: 4.71s	remaining: 42.8ms
# 991:	learn: 22553.7827003	total: 4.71s	remaining: 38ms
# 992:	learn: 22543.9221535	total: 4.72s	remaining: 33.3ms
# 993:	learn: 22535.5332306	total: 4.72s	remaining: 28.5ms
# 994:	learn: 22531.1163475	total: 4.72s	remaining: 23.7ms
# 995:	learn: 22522.6751454	total: 4.73s	remaining: 19ms
# 996:	learn: 22519.6424225	total: 4.73s	remaining: 14.2ms
# 997:	learn: 22502.1644449	total: 4.74s	remaining: 9.49ms
# 998:	learn: 22495.4913766	total: 4.74s	remaining: 4.75ms
# 999:	learn: 22465.8166367	total: 4.74s	remaining: 0us
#     Library Dataset     Train MAE       Test MAE
# 0  CatBoost       B  99789.276036  121533.351949
# 1  CatBoost       C  15690.508472   24004.901910

# %%
parameters = {
    'n_estimators': [500, 1000],
    'max_depth': [5, 7, 9],
    'learning_rate': [1e-2, 1e-1],
}

lib = 'GradientBoostingRegressor'
for data in ['B', 'C']:
  grid = GridSearchCV(estimator=GradientBoostingRegressor(), param_grid=parameters, scoring='neg_mean_absolute_error', n_jobs=-1, cv=4)
  t = time.time()
  grid.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  time_fit = time.time() - t
  model = GradientBoostingRegressor(**grid.best_params_)
  model.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  pred_train = model.predict(datasets[data]['X_train'])
  pred_test = model.predict(datasets[data]['X_test'])
  mae_train = mean_absolute_error(datasets[data]['y_train'], pred_train)
  mae_test = mean_absolute_error(datasets[data]['y_test'], pred_test)
  result = [lib, data, time_fit, mae_train, mae_test]
  df_optimized.loc[len(df_optimized)] = result
  print(f'{lib} best params on {data}: {grid.best_params_}')
# Out:
# GradientBoostingRegressor best params on B: {'learning_rate': 0.01, 'max_depth': 7, 'n_estimators': 500}
# GradientBoostingRegressor best params on C: {'learning_rate': 0.1, 'max_depth': 9, 'n_estimators': 500}

# %%
df_sklearn = pd.DataFrame(columns=['Library', 'Dataset','Train MAE', 'Test MAE'])

lib = 'Sklearn'
for data in ['B', 'C']:
  model = GradientBoostingRegressor(**test_parameters)
  model.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  pred_train = model.predict(datasets[data]['X_train'])
  pred_test = model.predict(datasets[data]['X_test'])
  mae_train = mean_absolute_error(datasets[data]['y_train'], pred_train)
  mae_test = mean_absolute_error(datasets[data]['y_test'], pred_test)
  result = [lib, data, mae_train, mae_test]
  df_sklearn.loc[len(df_sklearn)] = result

df_sklearn
# Out:
#    Library Dataset     Train MAE       Test MAE
# 0  Sklearn       B  91885.188873  123336.677748
# 1  Sklearn       C   8832.296441   21853.373296

# %%
df_optimized
# Out:
#                      Library Dataset  Training time      Train MAE  \
# 0              LGBMRegressor       B      55.603656  101259.054313
# 1              LGBMRegressor       C      70.510745    3553.080652
# 2               XGBRegressor       B      87.464163   98999.037739
# 3               XGBRegressor       C     772.703233    4529.487308
# 4          CatBoostRegressor       B     699.494360  107137.441919
# 5          CatBoostRegressor       C    1644.806402    3271.112027
# 6  GradientBoostingRegressor       B     299.501190  105944.778011
# 7  GradientBoostingRegressor       C    2557.159277    3228.584021
#
#         Test MAE
# 0  122961.471818
# 1   26635.403039
# 2  121811.095211
# 3   18065.853661
# 4  120661.323664
# 5   16722.840777
# 6  122084.460819
# 7   17493.876167

# %%
df_lgbm = pd.DataFrame(columns=['Library', 'Dataset','Train MAE', 'Test MAE'])

lib = 'LGBMRegressor'
for data in ['B', 'C']:
  model = LGBMRegressor(**test_parameters)
  model.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  pred_train = model.predict(datasets[data]['X_train'])
  pred_test = model.predict(datasets[data]['X_test'])
  mae_train = mean_absolute_error(datasets[data]['y_train'], pred_train)
  mae_test = mean_absolute_error(datasets[data]['y_test'], pred_test)
  result = [lib, data, mae_train, mae_test]
  df_lgbm.loc[len(df_lgbm)] = result

df_lgbm
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000688 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2065
# [LightGBM] [Info] Number of data points in the train set: 3420, number of used features: 14
# [LightGBM] [Info] Start training from score 151584.135380
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#          Library Dataset     Train MAE       Test MAE
# 0  LGBMRegressor       B  97464.815217  122524.868492
# 1  LGBMRegressor       C  21020.383955   31347.700217

# %%
df_xgb = pd.DataFrame(columns=['Library', 'Dataset','Train MAE', 'Test MAE'])

lib = 'XGBRegressor'
for data in ['B', 'C']:
  model = XGBRegressor(**test_parameters)
  model.fit(datasets[data]['X_train'], datasets[data]['y_train'])
  pred_train = model.predict(datasets[data]['X_train'])
  pred_test = model.predict(datasets[data]['X_test'])
  mae_train = mean_absolute_error(datasets[data]['y_train'], pred_train)
  mae_test = mean_absolute_error(datasets[data]['y_test'], pred_test)
  result = [lib, data, mae_train, mae_test]
  df_xgb.loc[len(df_xgb)] = result

df_xgb
# Out:
#         Library Dataset     Train MAE       Test MAE
# 0  XGBRegressor       B  92598.835913  122902.749596
# 1  XGBRegressor       C  10801.013651   22193.706098

# %% [markdown]
# <font color='MediumOrchid'>**Ваши пояснения для проверяющих (опционально):**</font>
#
# Перебор параметров для XGBRegressor и LGBMRegressor уже был в предыдущем задании, так что возьмем оттуда оптимальные параметры. Подбор гиперпараметров помог улучшить результаты. Таблица, где все библиотеки, содержит результаты с подобранными параметрами. Таблицы, где только одна библиотека, содержит результаты с тестовыми параметрами.

# %% [markdown]
# ---

# %% [markdown]
# Обычнно перебор параметров и поиск по сетке это самая скучная часть работы, поскольку занимает много времени, но не гарантирует воспроизведение результата при небольшом изменении датасета, да и сетку надо переосмысливать при каждом обновлении.
#
# Но сейчас мы поймём, что этого можно избежать, поскольку есть библиотека, которая всё сделает за нас!

# %% [markdown]
# Эмоции выполняющего в этот момент.png
#
# ![index.png](data:image/png;base64,...)

# %% [markdown]
# Нашего спасителя зовут `HyperOpt`. На первый взгляд `hyperopt` делает всё то же самое, что и `grid search`, а именно перебирает параметры. По факту же hyperopt превращает это в задачу оптимизации, используя некоторые эвристики для ускорения сходимости процесса. К тому же, он требует лишь информацию о границе интервалов, а не сами сетки. В теории это должно помочь нам добиться лучших результатов за более короткое время. Давайте попробуем это сделать.
#
# Для данного эксперимента я рекомендую использовать `lightgbm`, поскольку она быстрее и с ней удобнее играться, но Вы можете воспользоваться любой библиотекой из представленных выше.

# %% [markdown]
# ### <font color='MediumSeaGreen'> **Задание 2 [Bonus][3 балла]** </font>
# **Данные**: датасет со стоимостью поддержанных автомобилей
#
# **Метрика**: MAE
#
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. Взять `любую библиотеку` градиентного бустинга (можете взять самую быструю)
# 2. Составить сетку перебора в `hyperopt`, включающую параметры `n_estimators`, `max_depth` и `learning_rate` в hyperopt. Вам могут понадобиться такие типы данных, как `hp.choise`, `hp.qloguniform`, `hp.uniform` и `hp.quniform `(можно также пользоваться `np.arange`). Также для округления значения типа float до целых чисел (4.0 -> 4) используйте `scope.int`.
# 3. Реализуйте функцию, которая принимает на вход словарь параметров для регрессора, и при помощи cv оценивает его качество `на датасете A` (можно воспользоваться cross_val_score, а для ускорения поставить cv=3). Не забудьте о том, в каком виде lightgbm принимает категориальные признаки в numpy и что также надо передавать индексы категориальных признаков.
# 4. Создайте объект `trials=Trials()`, который будет хранить информацию о процессе оптимизации.
# 5. Используя функцию `fmin`, оптимизируйте Вашу функцию. Установите `algo=tpe.suggest, trials=trials` и `max_evals`, по крайней мере, 50. `verbose=1` позволит видеть прогресс-бар по типу tqdm.
# 6. `Выведите` получившиеся параметры. Нарисуйте `график`, показывающий значение `loss` в ходе оптимизации. Посчитайте качество на `тесте` при использовании лучших параметров (возвращаются после использования fmin). Сделайте выводы по результату.

# %%
from hyperopt import hp
from hyperopt import STATUS_OK

def loss_reg(parameters):
    model = LGBMRegressor(**parameters)
    score = cross_val_score(model, X=datasets['A']['X_train'], y=datasets['A']['y_train'], scoring='neg_mean_absolute_error', cv=3, n_jobs=-1)
    return   {'loss': -score.mean(), 'params': parameters, 'status': STATUS_OK}

space = {
    'n_estimators': hp.choice('n_estimators', [50, 100, 200, 500, 1000]),
    'learning_rate': hp.qloguniform('learning_rate', np.log(0.001), np.log(0.5), 0.001),
    'num_leaves': scope.int(hp.quniform('num_leaves', 10, 200, 10)),
    'max_depth': scope.int(hp.quniform('max_depth', 3, 15, 1)),
    'subsample': hp.uniform('subsample', 0.5, 1.0)
}
trials = Trials()
best_parameters = fmin(fn=loss_reg,space=space,algo=tpe.suggest,max_evals=50,trials=trials,verbose=1)
print('Best params LGBM: ', best_parameters)
# Out:
# 100%|██████████| 50/50 [01:34<00:00,  1.89s/trial, best loss: 30023.695654975698]
# Best params LGBM:  {'learning_rate': 0.031, 'max_depth': 11.0, 'n_estimators': 4, 'num_leaves': 40.0, 'subsample': 0.6562680336085781}

# %%
best_parameters['num_leaves'] = int(best_parameters['num_leaves'])
best_parameters['max_depth'] = int(best_parameters['max_depth'])
model = LGBMRegressor(**best_parameters, n_jobs=-1)
model.fit(datasets['A']['X_train'], datasets['A']['y_train'])
pred = model.predict(datasets['A']['X_test'])
print('MAE =', mean_absolute_error(datasets['A']['y_test'], pred))
# Out:
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000763 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2687
# [LightGBM] [Info] Number of data points in the train set: 3420, number of used features: 21
# [LightGBM] [Info] Start training from score 151584.135380
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# MAE = 117802.28258057933

# %%
plt.figure(figsize=(10, 6))
plt.title('График loss в ходе оптимизации')
plt.plot(trials.losses())
plt.grid()
plt.xlabel('Шаги оптимизации')
plt.ylabel('loss')
plt.show()

# %% [markdown]
# **<font color='MediumOrchid'>Ваши выводы:</font>**
#
# Выбор параметров через hyperopt очень быстрый. На получившихся параметрах MAE получился меньше, чем на параметрах которые мы искали через GridSearch.

# %% [markdown]
# ---

# %% [markdown]
# ## Предсказание зрительских симпатий
#
# Ну что, детишки, а теперь перейдём к действительно важным вопросам.
#
# <font color='OrangeRed'>**Обратите внимание!**</font> Следующее задание сдается в системе `cv-gml.ru`. Для выполнения этого задания необходимо скачать датасет из задания. Здесь вы можете немного почитать про датасет и, при желании, поэкспериментировать. На cv-gml.ru загружайте уже готовый скрипт `с подобранными параметрами` для обучаемого регрессора. Релизовать код необходимо в шаблонном файле `awards_prediction.py`, который вы можете найти в проверяющей системе.
#
# В некотором царстве, некотором государстве была развита кинопромышленность. Новые фильмы в этом государстве показывают по интернету, а пользователи после просмотра могут дать фильму некоторую "награду". Наша цель - предсказать число наград для фильма.
#
# В нашем распоряжении имеются следующие данные:
#
# **awards** - количество наград, полученных фильмом от пользователей (целевое значение)
# **potions** - количество магических зелий, потраченных на создание спец-эффектов
# **genres** - жанры созданного фильма
# **questions** - количество вопросов, заданных пользователями на соответствующих форумах об этом фильме до премьеры
# **directors** - режиссеры фильма (если неизвестны, то unknown)
# **filming_locations** - области, в которых снимался фильм
# **runtime** - продолжительность фильма в некоторых единицах, принятых в этом государстве
# **critics_liked** - количество критиков из 100, присудивших награды фильму на предварительных закрытых показах
# **pre-orders** - количество зрителей, заранее купивших билеты на первый показ
# **keywords** - ключевые слова, описывающие содержание фильма
# **release_year** - год, во котором фильм был показан (конечно, в летоисчислении этого государства)
#
# Следующие поля появляются несколько раз с разными значениями i:
#
# **actor_i_known_movies** - количество известных фильмов актера i (i от 0 до 2)
#
# **actor_i_postogramm** - количество подписчиков в социальной сети "по сто грамм" актера i (i от 0 до 2)
#
# **actor_i_gender** - пол актера i (i от 0 до 2)
#
# **actor_i_age** - возраст актера i (i от 0 до 2)
#
# -----
# <font color='OrangeRed'>**Обратите внимание!**</font> Учтите, что при OHE кодировании признаки на обучении и тестировании должны совпадать! Если вы примените простое .get_dummies() или что-то подобное, то признаки на трейне и тесте получатся разные! Так что вам, вероятно, придётся придумать способ для того, чтобы сохранить их :)
#
# <font color='LightSteelBlue'>**Подсказка**</font> для работы с текстом можно воспользоваться методом TF-IDF (ключевые слова: `TfIdfTransformer`). Также может быть полезен `CountVectorizer`. Только учтите, что никто не гарантирует улучшение результата с использованием данных методов  ;)
#
# <font color='OrangeRed'>**Обратите внимание!**</font> В проверяющей системе имеется проблема с catboost. При использовании этой библиотеки, в скрипте с решением необходимо инициализировать метод с использованием `train_dir` как показано тут:
# `CatBoostRegressor(train_dir='/tmp/catboost_info')`

# %% [markdown]
# ### <font color='DarkOrange'>**Задание 3 [6 баллов, ML-решение, не проверяется на кросс-проверке]**</font>
# **Данные**: датасет с ценами поддержанных автомобилей
# **Метрика**: MAE
# **Цели**: В данном задании следует выполнить следующие пункты:
# 1. Взять любую библиотеку градиентного бустинга
# 2. Используя предложенный датасет, обучить регрессор для предсказания awards (предоставляем полную свободу в настройках и выборе методов)
# 3. Загрузить решение и получить качество на закрытой выборке больше порогового значения

# %%
## your efficient code here

# %% [markdown]
# ## Конец
#
# Ну что детишки... Можете добавлять еще 4 библиотеки в своё резюме датасаентиста!

# %% [markdown]
# ```
# (╯°□°)╯︵ ┻━┻ FLIP THAT TABLE.
#
# ┻━┻ ︵ ヽ(°□°ヽ) FLIP THIS TABLE.
#
# ┻━┻ ︵ ＼\('0')/／ ︵ ┻━┻ FLIP ALL THE TABLES
#
# ಠ_ಠ Son... ಠ_ಠ Put. ಠ__ಠ The tables. ಠ___ಠ Back.
#
# (╮°-°)╮┳━┳
#
# (╯°□°)╯︵ ┻━┻ NEVER!!!!
# ```
